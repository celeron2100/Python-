# %% [markdown]
# # 初見網路爬蟲
#
# ## 以但開始學習採集網路上的數據，就會感受到網頁瀏覽器為我們做得所以細節。
#
# ## 首先會學習如何使用GET請求來向網路伺服器還獲取網頁。在從網頁中讀取HTML內容，最後做一些簡單的訊息抽取，把我們要尋找的內容分離出來。
#
# ## 假設今天我們要使用電腦來瀏覽Booking.com的網站，找看看這次旅行要下榻的飯店有哪些可以選擇。對電腦來說，我們人類操作電腦來做這項工作時，以電腦的觀點來看這是一項機器與機器之間的對話。以下的事情將會發生。
#
# ## 1.我的電腦會發送一段由0和1組成的bit值，表示電路上的高低電壓，這些bit值代表著某一種訊息，包括「Request Header」和「Information Body」。「Request Header」包含我的網路路由器的MAC地址和Booking.com網站的IP位址(IP是在TCP/IP協定中網路層的主要協定)。「Information Body」則包含我的電腦對Booking.com網站應用的請求。
#
# ## 2.網路路由器會收到我所有的0和1的bit值，把它解讀為「封包 Packet」，在替這些封包加上路由器自己的IP位址來作為「發件」的地址，然後通過網際網路發送出去。
#
# ## 3.我送出的封包會在網際網路經過一些中介的伺服器，沿著一些正確的電路路徑前進，直到Booking.com的伺服器。
#
# ## 4.Booking.com在他的IP位址收到了封包。
#
# ## 5.Booking.com伺服器會讀取封包的「Request Header」帶有的目標端口(例如 80/TCP	HTTP（超文字傳輸協定）- 用於傳輸網頁)，然後把它傳遞到對應的應用，「網頁伺服器Web Server」上。
#
# ## 6.網頁伺服器處理後得到兩串的數據:
# ### (1)一個GET的請求。
# ### (2)請求的文件 index.html
#
# ## 7.網路伺服器找到的相對應的HTML文件，把他打包成一個新的封包傳送到Booking.com自己的路由器，路由器再透過同樣的過程回傳到我的電腦上。
#
#
#
#
#
# # 該選擇 urllib 還是 urllib2 ?
#
# ## 在python 2.x的版本，是用urllib2，而在python 3.x的版本，改用urllib，兩者的功能其實很相似。
#
# ## 如果你用過python 2.x 的 urllib2 ，你可能會發現urllib2 和 urllib有些不同。但是在python 3裡，urllib2改名為urllib，兩者個差異則改由使用子模組來實作，例如:urllib.request、urllib.parse 和 urllib.error。
#
# ## 簡而言之，python 3 中的 urllib 已經整了 python 2 的 urllib 和 urllib2。
#
# ## urllib可以存取網頁、下載資料、剖析資料、修改表頭(header)、執行GET與POST的請求…。
#
# ## 使用較新的python 3 來實作。

# %%
# -*- coding: utf-8 -*-

import nltk
from bs4 import BeautifulSoup
import lxml
import urllib
from urllib import parse
from urllib import request

# %% [markdown]
# ### 執行nltk.download()時，會開啟一個新的視窗，在視窗中選擇要下載的NLTK相關套件包()，下載路徑和其餘的設定基本上保持預設狀態即可。

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
web = "http://www.booking.com/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.zh-tw.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=83349c9f35261a2ee9abd0d1c30202bc"

# %% [markdown]
# ## 呈現發出請求後的結果，會出現網頁的HTML原始碼。
#
# ## urlopen()函式是用來打開並讀取一個從網際網路上獲取到的對象。urllib是一個非常通用的函式庫，可以輕鬆的讀取HTML文件，圖像，或其他任何的文件流。

# %%
request_urlopen = request.urlopen(web)
print(request_urlopen.read())
# Out:
# b'<!DOCTYPE html>\n<!--\nYou know you could be getting paid to poke around in our code?\nWe\'re hiring designers and developers to work in Amsterdam:\nhttp://www.workingatbooking.com/\n-->\n<!-- wdot-802 -->\n<html\nlang="zh-tw"\nprefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# booking_com: http://ogp.me/ns/fb/booking_com#"\nclass="noJS b_bot b_bot   supports_fontface "\n>\n<head profile="http://a9.com/-/spec/opensearch/1.1/">\n<meta http-equiv="content-type" content="text/html; charset=utf-8" />\n<link rel="stylesheet" href="http://r-ec.bstatic.com/static/css/main_edgecast.iq/8571e11db8e9ab6791b5f586aa26b38ebd869e48.css" data-main-css="1" />\n<link rel="stylesheet" href="http://r-ec.bstatic.com/static/css/main_exps_edgecast.iq/71ffd8622a42554a1eea25fd6a1882e70613b056.css" />\n<link rel="stylesheet" href="http://q-ec.bstatic.com/static/css/gprof_icons_edgecast.iq/837727ec301ff48a8853424036e79eeb6ef9326f.css" /> \n<link rel="stylesheet" type="text/css" href="http://q-ec.bstatic.com/static/css/hotel_base_edgecast.iq/675c1e7b26dfaa7937678c4a0f925ec63ee82607.css" media="screen" />\n<link rel="stylesheet" type="text/css" href="http://r-ec.bstatic.com/static/css/hotel_experiments_edgecast.iq/6620d7baa4c798600399e43569236a01986109c3.css" media="screen" />\n<link rel="stylesheet" type="text/css" href="http://q-ec.bstatic.com/static/css/reviews_standalone_edgecast.iq/55eafd6c53566991e016fb8013f6db2b4e6b325e.css" media="screen" />\n <!--[if IE 9]> <link rel="stylesheet" href="http://r-ec.bstatic.com/static/css/ie9lte/883f9ea1c58a3c3f440b17d92b198ae72c8ecb80.css" media="screen" /> <![endif]--> <!--[if IE 8]> <link rel="stylesheet" href="http://r-ec.bstatic.com/static/css/ie8lte_bundle/9fa138da41d7fc0649d893032c8714aea5a8dc3a.css" media="screen" /> <![endif]--> <!--[if IE 7]> <link rel="stylesheet" href="http://r-ec.bstatic.com/static/css/ie7lte_bundle/429229365051802e0100c327150eab66a29f9adf.css" media="screen" /> <![endif]-->  \n <style> #basiclayout { margin: 0px 0 0 0; } .breadcrumb { padding-left:7px; } #special_actions { margin: 3px 15px 3px 0; } .ticker_space { margin-top: 3px !important; } #logo_no_globe_new_logo { top: 14px; } .b_msie_6 #top, .b_msie_6 body.header_reshuffle #top {height:61px !important;} .b_msie_6 #special_actions { margin: 3px 15px 3px 0; overflow:visible; } body.header_reshuffle #top { min-height: 50px !important; height: 50px !important; } .nobg { background: #fff url("http://r-ec.bstatic.com/static/img/nobg_all_blue/85a874c5ee518d80b2ec6025d2a8379511a72172.png") repeat-x; background-image: url("http://r-ec.bstatic.com/static/img/nobg_all_blue_iq/b700d9e3067c1186a3364012df4fe1c48ae6da44.png"); background-position: 0 -50px; } </style> <link rel="stylesheet" href="http://q-ec.bstatic.com/static/css/cjk/692ef46a0fea731d9c8dd350eac353cba65e1133.css" /> \n<link rel="stylesheet" type="text/css" href="http://r-ec.bstatic.com/static/css/iq_overrides_edgecast/66e0615fb87fae0ac310d6b3e230a6fb62175a4c.css" />\n<script> if( window.performance && performance.measure && \'b-stylesheets\') { performance.measure(\'b-stylesheets\'); } </script> \n<meta name="robots" content="index,follow" />\n<link rel="canonical" href="http://www.booking.com/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.zh-tw.html" />\n<meta name="twitter:app:id:iphone" content="367003839" />\n<meta name="twitter:app:name:ipad" content="Booking.com Hotel Reservations Worldwide & Hotel Deals" />\n<meta name="twitter:app:id:ipad" content="367003839" />\n<meta name="twitter:app:name:googleplay" content="Booking.com Hotel Reservations" />\n<meta name="twitter:app:id:googleplay" content="com.booking" />\n<meta property="al:ios:app_store_id" content="367003839">\n<meta property="al:ios:app_name" content="Booking.com Hotel Reservations">\n<meta property="al:android:app_name" content="Booking.com Hotel Reservation">\n<meta property="al:android:package" content="com.booking">\n<meta name="p:domain_verify" content="ff7f0b90ebb93e5bf7c7cafe77640ec1"/>\n<meta http-equiv ...

# %% [markdown]
# ### 上述的HTML碼在內文顯示的部分是使用了utf-8格式的編碼，所以我們接下來要使用正確的decode()來解碼成我們能理解的文字符號。

# %% [markdown]
# ## 嘗試使用utf-8編碼來解析網頁的資料。

# %%
values = {"s":"basic",
         "submit":"search"}

data = urllib.parse.urlencode(values)
print(data)
# Out:
# submit=search&s=basic

# %%
data = data.encode("utf-8")
print(data)
# Out:
# b'submit=search&s=basic'

# %%
request_urlopen = request.Request(web,data)
print(request_urlopen)
# Out:
# <urllib.request.Request object at 0x0000000009DD1C50>

# %%
request_urlopen = request.urlopen(request_urlopen)
print(request_urlopen.read())
# Out:
# b'<!DOCTYPE html>\n<!--\nYou know you could be getting paid to poke around in our code?\nWe\'re hiring designers and developers to work in Amsterdam:\nhttp://www.workingatbooking.com/\n-->\n<!-- wdot-802 -->\n<html\nlang="zh-tw"\nprefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# booking_com: http://ogp.me/ns/fb/booking_com#"\nclass="noJS b_bot b_bot   supports_fontface "\n>\n<head profile="http://a9.com/-/spec/opensearch/1.1/">\n<meta http-equiv="content-type" content="text/html; charset=utf-8" />\n<link rel="stylesheet" href="http://r-ec.bstatic.com/static/css/main_edgecast.iq/8571e11db8e9ab6791b5f586aa26b38ebd869e48.css" data-main-css="1" />\n<link rel="stylesheet" href="http://r-ec.bstatic.com/static/css/main_exps_edgecast.iq/71ffd8622a42554a1eea25fd6a1882e70613b056.css" />\n<link rel="stylesheet" href="http://q-ec.bstatic.com/static/css/gprof_icons_edgecast.iq/837727ec301ff48a8853424036e79eeb6ef9326f.css" /> \n<link rel="stylesheet" type="text/css" href="http://q-ec.bstatic.com/static/css/hotel_base_edgecast.iq/675c1e7b26dfaa7937678c4a0f925ec63ee82607.css" media="screen" />\n<link rel="stylesheet" type="text/css" href="http://r-ec.bstatic.com/static/css/hotel_experiments_edgecast.iq/6620d7baa4c798600399e43569236a01986109c3.css" media="screen" />\n<link rel="stylesheet" type="text/css" href="http://q-ec.bstatic.com/static/css/reviews_standalone_edgecast.iq/55eafd6c53566991e016fb8013f6db2b4e6b325e.css" media="screen" />\n <!--[if IE 9]> <link rel="stylesheet" href="http://r-ec.bstatic.com/static/css/ie9lte/883f9ea1c58a3c3f440b17d92b198ae72c8ecb80.css" media="screen" /> <![endif]--> <!--[if IE 8]> <link rel="stylesheet" href="http://r-ec.bstatic.com/static/css/ie8lte_bundle/9fa138da41d7fc0649d893032c8714aea5a8dc3a.css" media="screen" /> <![endif]--> <!--[if IE 7]> <link rel="stylesheet" href="http://r-ec.bstatic.com/static/css/ie7lte_bundle/429229365051802e0100c327150eab66a29f9adf.css" media="screen" /> <![endif]-->  \n <style> #basiclayout { margin: 0px 0 0 0; } .breadcrumb { padding-left:7px; } #special_actions { margin: 3px 15px 3px 0; } .ticker_space { margin-top: 3px !important; } #logo_no_globe_new_logo { top: 14px; } .b_msie_6 #top, .b_msie_6 body.header_reshuffle #top {height:61px !important;} .b_msie_6 #special_actions { margin: 3px 15px 3px 0; overflow:visible; } body.header_reshuffle #top { min-height: 50px !important; height: 50px !important; } .nobg { background: #fff url("http://r-ec.bstatic.com/static/img/nobg_all_blue/85a874c5ee518d80b2ec6025d2a8379511a72172.png") repeat-x; background-image: url("http://r-ec.bstatic.com/static/img/nobg_all_blue_iq/b700d9e3067c1186a3364012df4fe1c48ae6da44.png"); background-position: 0 -50px; } </style> <link rel="stylesheet" href="http://q-ec.bstatic.com/static/css/cjk/692ef46a0fea731d9c8dd350eac353cba65e1133.css" /> \n<link rel="stylesheet" type="text/css" href="http://r-ec.bstatic.com/static/css/iq_overrides_edgecast/66e0615fb87fae0ac310d6b3e230a6fb62175a4c.css" />\n<script> if( window.performance && performance.measure && \'b-stylesheets\') { performance.measure(\'b-stylesheets\'); } </script> \n<meta name="robots" content="index,follow" />\n<link rel="canonical" href="http://www.booking.com/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.zh-tw.html" />\n<meta name="twitter:app:id:iphone" content="367003839" />\n<meta name="twitter:app:name:ipad" content="Booking.com Hotel Reservations Worldwide & Hotel Deals" />\n<meta name="twitter:app:id:ipad" content="367003839" />\n<meta name="twitter:app:name:googleplay" content="Booking.com Hotel Reservations" />\n<meta name="twitter:app:id:googleplay" content="com.booking" />\n<meta property="al:ios:app_store_id" content="367003839">\n<meta property="al:ios:app_name" content="Booking.com Hotel Reservations">\n<meta property="al:android:app_name" content="Booking.com Hotel Reservation">\n<meta property="al:android:package" content="com.booking">\n<meta name="p:domain_verify" content="ff7f0b90ebb93e5bf7c7cafe77640ec1"/>\n<meta http-equiv ...

# %% [markdown]
# ## 如果再送出請求時，回傳錯誤為HTTP Error 403: Forbidden
# ## 便可以嘗試在送出請求時在headers上加入User-Agent。

# %%
headers = {"User-Agent":"Mozilla/5.0 (X11; Linux i686) AppleWebKit/537.17 (KHTML, like Gecko) Chrome/24.0. 1312.27 Safari/537.17"}
print(headers)
# Out:
# {'User-Agent': 'Mozilla/5.0 (X11; Linux i686) AppleWebKit/537.17 (KHTML, like Gecko) Chrome/24.0. 1312.27 Safari/537.17'}

# %% [markdown]
# ## 在使用read()函數時，必須要解碼為正確的編碼(例如.utf-8)才可以順利解讀網頁資料。

# %%
request_urlopen = request.Request(web,headers=headers)
request_urlopen = request.urlopen(request_urlopen)
simple_page = request_urlopen.read().decode("utf-8")
print(simple_page)
# Out:
# <!DOCTYPE html>
# <!--
# You know you could be getting paid to poke around in our code?
# We're hiring designers and developers to work in Amsterdam:
# http://www.workingatbooking.com/
# -->
# <!-- wdot-802 -->
# <html
# lang="zh-tw"
# prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# booking_com: http://ogp.me/ns/fb/booking_com#"
# class="noJS b_chrome b_chrome_24   supports_inline-block supports_fontface "
# >
# <head profile="http://a9.com/-/spec/opensearch/1.1/">
# <meta http-equiv="content-type" content="text/html; charset=utf-8" />
# <link rel="stylesheet" href="http://t-ec.bstatic.com/static/css/main_ecv6.iq2/63ee9a2426982754104e88be7c2369323db9dfa1.css" data-main-css="1" />
# <link rel="stylesheet" href="http://t-ec.bstatic.com/static/css/main_exps_ecv6.iq2/83970d412a458c5c3c958a2b9dfc1f4ee4e1ee16.css" />
# <link rel="stylesheet" href="http://t-ec.bstatic.com/static/css/gprof_icons_ecv6.iq2/afa93bf7b3e8e7ddd51d5da0957769be80e321dd.css" />
# <link rel="stylesheet" type="text/css" href="http://s-ec.bstatic.com/static/css/hotel_base_ecv6.iq2/252f0dcb2dbf35a4940edad1c0b101f0f190080f.css" media="screen" />
# <link rel="stylesheet" type="text/css" href="http://s-ec.bstatic.com/static/css/hotel_experiments_ecv6.iq2/6a502a4b0b788374b0b8a1b0eeb0015b3aa5dc5a.css" media="screen" />
# <link rel="stylesheet" type="text/css" href="http://t-ec.bstatic.com/static/css/reviews_standalone_ecv6.iq2/5b328b95d5cda2a78f935a1f20a6f43998ddb0f4.css" media="screen" />
#  <!--[if IE 9]> <link rel="stylesheet" href="http://t-ec.bstatic.com/static/css/ie9lte/883f9ea1c58a3c3f440b17d92b198ae72c8ecb80.css" media="screen" /> <![endif]--> <!--[if IE 8]> <link rel="stylesheet" href="http://t-ec.bstatic.com/static/css/ie8lte_bundle/9fa138da41d7fc0649d893032c8714aea5a8dc3a.css" media="screen" /> <![endif]--> <!--[if IE 7]> <link rel="stylesheet" href="http://t-ec.bstatic.com/static/css/ie7lte_bundle/429229365051802e0100c327150eab66a29f9adf.css" media="screen" /> <![endif]-->
#  <style> #basiclayout { margin: 0px 0 0 0; } .breadcrumb { padding-left:7px; } #special_actions { margin: 3px 15px 3px 0; } .ticker_space { margin-top: 3px !important; } #logo_no_globe_new_logo { top: 14px; } .b_msie_6 #top, .b_msie_6 body.header_reshuffle #top {height:61px !important;} .b_msie_6 #special_actions { margin: 3px 15px 3px 0; overflow:visible; } body.header_reshuffle #top { min-height: 50px !important; height: 50px !important; } .nobg { background: #fff url("http://t-ec.bstatic.com/static/img/nobg_all_blue/85a874c5ee518d80b2ec6025d2a8379511a72172.png") repeat-x; background-image: url("http://t-ec.bstatic.com/static/img/nobg_all_blue_iq/b700d9e3067c1186a3364012df4fe1c48ae6da44.png"); background-position: 0 -50px; } </style> <link rel="stylesheet" href="http://s-ec.bstatic.com/static/css/cjk/692ef46a0fea731d9c8dd350eac353cba65e1133.css" />
# <link rel="stylesheet" type="text/css" href="http://s-ec.bstatic.com/static/css/iq_overrides_ecv6/66e0615fb87fae0ac310d6b3e230a6fb62175a4c.css" />
# <script> if( window.performance && performance.measure && 'b-stylesheets') { performance.measure('b-stylesheets'); } </script>
# <meta name="robots" content="index,follow" />
# <link rel="canonical" href="http://www.booking.com/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.zh-tw.html" />
# <meta name="twitter:app:id:iphone" content="367003839" />
# <meta name="twitter:app:name:ipad" content="Booking.com Hotel Reservations Worldwide & Hotel Deals" />
# <meta name="twitter:app:id:ipad" content="367003839" />
# <meta name="twitter:app:name:googleplay" content="Booking.com Hotel Reservations" />
# <meta name="twitter:app:id:googleplay" content="com.booking" />
# <meta property="al:ios:app_store_id" content="367003839">
# <meta property="al:ios:app_name" content="Booking.com Hotel Reservations">
# <meta property="al:android:app_name" content="Booking.com Hotel Reservation">
# <meta property="al:android:package" content="com.booking">
# <meta name="p:domain_verify" content="ff7f0b90ebb93e5bf7c7cafe77640ec1"/>
# <meta http-equiv="content-language" content="zh-tw" />
# <meta http-equiv="content-script-type" content="text/javascript" />
# <meta http-equiv="content-style-type" content="text/css" />
# <meta http-equiv="window-target" content="_top" />
# <meta property="wb:webmaster" content="48970bbca45d28c2" />
# <meta name="twitter:card" content="summary_large_image">
# <meta name="twitter:site" content="@bookingcom">
# <meta name="twitter:creator" content="@bookingcom">
# <meta name="twitter:image" content="http://s-ec.bstatic.com/static/img/twitter-image-else/566c7081f1deeaca39957e96365c3908f83b95af.jpg">
# <meta name="twitter:title" content="Booking.com: 最豐富的飯店、民宿及度假住所選擇">
# <meta name="twitter:description" content="不論您預訂的是飯店、民宿或度假住所，訂房保證最低價！快來我們的網站瀏覽超過 85,000 個目的地的  間住宿選擇。">
# <meta property="og:type" content="company" />
# <meta property="og:title" content="Booking.com: 最豐富的飯店、民宿及度假住所選擇" />
# <meta property="og:image" content="http://t-ec.bstatic.com/static/img/facebook-image-else/566c7081f1deeaca39957e96365c3908f83b95af.jpg" />
# <meta property="og:description" content="不論您預訂的是飯店、民宿或度假住所，訂房保證最低價！快來我們的網站瀏覽超過 85,000 個目的地的  間住宿選擇。" />
# <meta property="og:locale" content="zh-tw" />
# <meta property="og:url" content="http://www.booking.com/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.zh-tw.html" />
# <meta property="og:site_name" content="Booking.com" />
# <meta property="fb:app_id" content="145362478954725" />
# <link rel="alternate" type="text/html" hreflang="en-gb" href="http://www.booking.com/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.en-gb.html" title="English (UK)" />
# <link rel="alternate" type="text/html" hreflang="en-us" href="http://www.booking.com/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.html" title="English (US)" />
# <link rel="alternate" type="text/html" hreflang="ja" href="http://www.booking.com/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.ja.html" title="日本語" />
# <link rel="alternate" type="text/html" hreflang="zh-cn" href="http://www.booking.com/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.zh-cn.html" title="简体中文" />
# <link rel="alternate" type="text/html" hreflang="zh-tw" href="http://www.booking.com/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.zh-tw.html" title="繁體中文" />
# <link rel="alternate" type="text/html" hreflang="ko" href="http://www.booking.com/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.ko.html" title="한국어" />
# <link rel="shortcut icon" href="http://s-ec.bstatic.com/static/img/b25logo/favicon/ebc77706da3aae4aee7b05dadf182390f0d26d11.ico" />
# <link rel="apple-touch-icon" href="http://t-ec.bstatic.com/static/img/apple-touch-icon/c9b35bf29a75cac2f430f80a5d4bc7fd961d21a7.png" />
# <link rel="help" href="/faq.zh-tw.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;" />
# <link rel="search" type="application/opensearchdescription+xml" href="http://t-ec.bstatic.com/static/opensearch/zh-tw/debbe66f64fc96062ab17e891ece73c79727c0d7.xml" title="Booking.com網路飯店訂房" />
# <link href="https://plus.google.com/105443419075154950489" rel="publisher" />
# <script>
# /*
# */
# (function avoidingXSSviaLocationHash() {
# var location = window.location,
# hash = location.hash,
# xss = /[<>'"]/;
# if (
# xss.test( decodeURIComponent( hash ) ) ||
# xss.test( hash )
# ) {
# location.hash = '';
# }
# })();
# document.documentElement.className = document.documentElement.className.replace('noJS', '') + ' hasJS';
# var sNSExperiments = 'experiments',
# sNSStartup = 'startup',
# sNSExperimentsLoad = 'experiments_load',
# sNSStartupLoad = 'startup_load';
# var b_experiments = {}, WIDTH, B = window.booking = {
# _onfly: [], // "on the fly" functions, will be executed as soon as external js files were loaded
# track: {
# queue: [],
# exp: function(value){
# if(!value) { return false; }
# this.queue.push(value);
# }
# },
# devTools: {
# trackedExperiments: []
# },
# user: {
# },
# env : {
# "b_gtt": 'dLYAeZFVJfNTBdAHUdPcUJBXVJfcbWYZedVWPFXO',
# "b_action" : 'reviews_hotel',
# "b_secure_domain" : 'https://secure.booking.com',
# "b_site_type" : 'www',
# "b_site_type_id": '1',
# "b_query_params_with_lang_no_ext": '?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554',
# "b_query_params_with_lang_no_ext_enforce_lang_aid_currency": '?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;lang=zh-tw;aid=397642;selected_currency=TWD',
# "b_calendar2" : '1',
# /*
# */
# "b_partner_channel_id": '17',
# "b_bookings_owned": '1',
# "b_real_action" : 'reviews_hotel',
# "b_google_maps_key_params" : 'key=ABQIAAAAEG168dBcRndNV70R9mDglhSZn_smZpFKc3SoS1v7FyDshy3QMxSgeH0qWTH24Gc7je-iJ9DSXiNmcA&amp;client=gme-booking&indexing=true',
# "b_lang" : 'zh',
# "b_has_valid_dates": '',
# "b_countrycode" : 'tw',
# "b_guest_country" : 'tw',
# "b_locale" : 'zh-tw',
# "date_format_locale" : 'DDD, DD MMMM YYYY',
# "b_lang_for_url" : 'zh-tw',
# "b_this_urchin" : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.zh-tw.html?label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo&amp;customer_type=total&amp;hp_nav=0&amp;order=featuredreviews&amp;page=1&amp;r_lang=zh-tw&amp;rows=75&&amp;',
# "b_flag_to_suggest" : 'tw',
# "b_companyname" : 'Booking.com',
# b_date_format: {"from_month_with_year":"自 {full_year} {month_name_from}","date_without_year":"{month_name} {day_of_month} 日","date_with_weekday_time_from":"{full_year} 年 {begin_marker}{month_name} {day_of_month} 日{end_marker}，{weekday}（{time} 起）","date_with_weekday_time_until":"{full_year} 年 {begin_marker}{month_name} {day_of_month} 日{end_marker}，{weekday}（{time} 前）","short_month_only":"{short_month_name}","month_with_year":"{full_year} 年 {month_name_with_year_only}","short_date_with_weekday_without_year":"{short_month_name} {day_of_month} 日（{short_weekday}）","date_with_short_weekday_with_year":"{full_year} 年 {month_name} {day_of_month} 日{short_weekday}","numeric_date_range_both_years":"{full_year}/{month}/{day_of_month}－{full_year_until}/{month_until}/{day_of_month_until}","date_with_weekday_to":"{full_year} 年 {month_name_to} {day_of_month} 日（{weekday_to}）","day_of_month_only":"{day_of_month}","numeric_date":"{full_year}/{num_month}/{day_of_month}","date_with_short_weekday_without_year":"{month_name} {day_of_month} 日{short_weekday}","short_date":"{full_year} 年 {short_month_name} {day_of_month} 日","long_date_range_both_years":"{full_year} 年 {month_name} {day_of_month} 日 － {full_year_until} 年 {day_of_month_until} {month_name_until} 日","in_month_with_year":"於 {full_year} {month_name_in}","date_with_weekday":"{full_year} 年 {month_name} {day_of_month} 日（{weekday}）","numeric_date_range":"{month}/{day_of_month}－{month_until}/{day_of_month_until}","short_date_without_year_range":"{short_month_name} {day_of_month} 日 - {short_month_name_until} {day_of_month_until} 日","range_from_long_date_time_until_long_date_time":"自 {full_year} 年 {month_name} {day_of_month} 日 {time} 至 {full_year_until} 年{month_name_until}   {day_of_month_until} 日 {time_until}","short_weekday_only":"{short_weekday}","short_month_with_year":"{full_year} 年 {short_month_name}","month_name_only":"{month_name_nom}","short_date_with_weekday":"{full_year} 年 {short_month_name} {day_of_month} 日（{short_weekday}）","short_date_without_year":"{short_month_name} {day_of_month} 日","date_with_year":"{full_year} 年 {month_name} {day_of_month} 日","date_with_weekday_with_markers":"{full_year} 年 {begin_marker}{short_month_name} {day_of_month} 日{end_marker} {weekday}","date_with_weekday_from":"{full_year} 年 {month_name_from} {day_of_month} 日（{weekday_from}）"},
# b_month_for_formatted_date: {"5":{"name_to":"5 月","name_only":"5 月","name_from":"5 月","name":"5 月","short_name":"5 月","name_with_year_only":"5 月","name_in":"5 月"},"4":{"name_to":"4 月","name_only":"4 月","name_from":"4 月","name":"4 月","short_name":"4 月","name_with_year_only":"4 月","name_in":"4 月"},"1":{"name_to":"1 月","name_only":"1 月","name_from":"1 月","name":"1 月","short_name":"1 月","name_with_year_only":"1 月","name_in":"1 月"},"11":{"name_to":"11 月","name_only":"11 月","name_from":"11 月","name":"11 月","short_name":"11 月","name_with_year_only":"11 月","name_in":"11 月"},"8":{"name_to":"8 月","name_only":"8 月","name_from":"8 月","name":"8 月","short_name":"8 月","name_with_year_only":"8 月","name_in":"8 月"},"3":{"name_to":"3 月","name_only":"3 月","name_from":"3 月","name":"3 月","short_name":"3 月","name_with_year_only":"3 月","name_in":"3 月"},"6":{"name_to":"6 月","name_only":"6 月","name_from":"6 月","name":"6 月","short_name":"6 月","name_with_year_only":"6 月","name_in":"6 月"},"7":{"name_to":"7 月","name_only":"7 月","name_from":"7 月","name":"7 月","short_name":"7 月","name_with_year_only":"7 月","name_in":"7 月"},"9":{"name_to":"9 月","name_only":"9 月","name_from":"9 月","name":"9 月","short_name":"9 月","name_with_year_only":"9 月","name_in":"9 月"},"10":{"name_to":"10 月","name_only":"10 月","name_from":"10 月","name":"10 月","short_name":"10 月","name_with_year_only":"10 月","name_in":"10 月"},"2":{"name_to":"2 月","name_only":"2 月","name_from":"2 月","name":"2 月","short_name":"2 月","name_with_year_only":"2 月","name_in":"2 月"},"12":{"name_to":"12 月","name_only":"12 月","name_from":"12 月","name":"12 月","short_name":"12 月","name_with_year_only":"12 月","name_in":"12 月"}},
# b_weekday_formatted_date: {"2":{"short":"週二","name_to":"星期二","name_from":"星期二","name":"星期二","shortest":"週二"},"3":{"short":"週三","name_to":"星期三","name_from":"星期三","name":"星期三","shortest":"週三"},"4":{"short":"週四","name_to":"星期四","name_from":"星期四","name":"星期四","shortest":"週四"},"7":{"short":"週日","name_to":"星期日","name_from":"星期日","name":"星期日","shortest":"週日"},"6":{"short":"週六","name_to":"星期六","name_from":"星期六","name":"星期六","shortest":"週六"},"1":{"short":"週一","name_to":"星期一","name_from":"星期一","name":"星期一","shortest":"週一"},"5":{"short":"週五","name_to":"星期五","name_from":"星期五","name":"星期五","shortest":"週五"}},
# b_time_format: {"PM_symbol":{"name":"PM"},"AM_symbol":{"name":"AM"},"time":{"name":"{hour_24h}:{minutes}"}},
# "b_protocol": 'http',
# auth_level : "0",
# b_user_auth_level_is_none : 1,
# b_run_redirect_from_app_to_book_for_login: 1,
# b_login_page_url: 'https://secure.booking.com/mysettings.zh-tw.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;aru=http%3A%2F%2Fwww.booking.com%2Freviews%2Ftw%2Fhotel%2Ftai-bei-fa-xian-qing-lu.zh-tw.html%3Faid%3D397642%3Blabel%3Dgog235jc-index-XX-XX-XX-unspec-tw-com-L%253Axt-O%253Aabn-B%253Aunk-N%253Ayes-S%253Abo-U%253Asalo%3Bsid%3D83349c9f35261a2ee9abd0d1c30202bc',
# bb: {
# ibb: "",
# uibb: "",
# ibbta: "",
# itp: "0",
# iuibb: "",
# bme: "",
# euibb: "0",
# tp: "0"
# },
# b_growls_close_fast: 1,
# asyncLoader: {
# empty: ''
# },
# b_email_validation_regex : /^([\w-\.\+]+@([\w-]+\.)+[\w-]{2,14})?$/,
# b_domain_end : '.booking.com',
# b_original_url : 'http:&#47;&#47;www.booking.com&#47;reviews&#47;tw&#47;hotel&#47;tai-bei-fa-xian-qing-lu.zh-tw.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=83349c9f35261a2ee9abd0d1c30202bc',
# b_this_url : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.zh-tw.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&',
# b_this_url_without_lang : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&',
# b_switch_language_url : {
# 'en-gb' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.en-gb.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=en-gb',
# 'en-us' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.en-us.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=en-us',
# 'de' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.de.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=de',
# 'nl' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.nl.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=nl',
# 'fr' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.fr.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=fr',
# 'es' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.es.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=es',
# 'es-ar' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.es-ar.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=es-ar',
# 'ca' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.ca.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=ca',
# 'it' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.it.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=it',
# 'pt-pt' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.pt-pt.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=pt-pt',
# 'pt-br' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.pt-br.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=pt-br',
# 'no' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.no.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=no',
# 'fi' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.fi.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=fi',
# 'sv' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.sv.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=sv',
# 'da' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.da.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=da',
# 'cs' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.cs.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=cs',
# 'hu' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.hu.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=hu',
# 'ro' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.ro.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=ro',
# 'ja' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.ja.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=ja',
# 'zh-cn' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.zh-cn.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=zh-cn',
# 'zh-tw' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.zh-tw.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=zh-tw',
# 'pl' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.pl.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=pl',
# 'el' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.el.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=el',
# 'ru' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.ru.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=ru',
# 'tr' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.tr.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=tr',
# 'bg' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.bg.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=bg',
# 'ar' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.ar.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=ar',
# 'ko' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.ko.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=ko',
# 'he' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.he.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=he',
# 'lv' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.lv.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=lv',
# 'uk' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.uk.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=uk',
# 'id' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.id.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=id',
# 'ms' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.ms.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=ms',
# 'th' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.th.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=th',
# 'et' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.et.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=et',
# 'hr' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.hr.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=hr',
# 'lt' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.lt.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=lt',
# 'sk' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.sk.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=sk',
# 'sr' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.sr.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=sr',
# 'sl' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.sl.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=sl',
# 'vi' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.vi.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=vi',
# 'tl' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.tl.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=tl',
# 'is' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.is.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=is'
# },
# b_referrer : '',
# b_acc_type : '',
# b_req_login: '',
# jst : {'loading': true},
# keep_day_month: true,
# b_timestamp : 1487156599,
# referal_tab: true,
# scripts_tracking : {
# },
# enable_scripts_tracking : 1,
# b_ufi : '-2637882',
# "setvar_affiliate_is_bookings2" : 1,
# transl_close_x : '关闭',
# transl_checkin_title: '入住日期',
# transl_checkout_title: '退房日期',
# browser_lang: '',
# b_lang_is_cjk: true,
# b_hijri_calendar_available: false,
# b_aid: '397642',
# b_label: 'gog235jc-index-XX-XX-XX-unspec-tw-com-L:xt-O:abn-B:unk-N:yes-S:bo-U:salo',
# b_sid: 'a69dc815b256b32729409bba84f65554',
# ip_country: 'tw',
# country_currency: 'TWD',
# b_selected_currency: 'TWD',
# b_selected_language: 'zh-tw',
# pageview_id: '5b5c4dbbaa1202a3',
# aid: '397642',
# b_csrf_token: 't22kWAAAAAA=O9IjX3pikqDJvJQ5vDvlarNYJuJOlUHoXuUhNzLGcaG5m4ebKVntuOUl0dWFmS7FRvU5U3BUnzDh4MaKZjdrY7rq2fZGKupw5nKwRQeqXl829bfCBVOuUZJTzPFjqOHKhI6byBGRIkpfWRvU5LoGPSD85EYkO6w5H5YS-nITii5yhdmkamZgCtvMHd8',
# b_show_user_accounts_features: 1,
# b_browser: 'chrome',
# b_browser_version: '24',
# b_run_loc_ce_update_timer_v2: true,
# et_debug_level: '0',
# et_deprecation_warnings: false,
# icons: '/static/img',
# b_static_images: 'http://t-ec.bstatic.com/images/',
# b_currency_url: '/general.zh-tw.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;tmpl=currency_foldout;cur_currency=TWD;cc1=tw',
# b_languages_url: '/general.zh-tw.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;tmpl=language_foldout',
# b_weekdays: [
# {"b_is_weekend": parseInt( '' ),
# "b_number": parseInt('1'),
# "name": '星期一',
# "short": '週一',
# "shorter": '週一',
# "shortest": '週一'},
# {"b_is_weekend": parseInt( '' ),
# "b_number": parseInt('2'),
# "name": '星期二',
# "short": '週二',
# "shorter": '週二',
# "shortest": '週二'},
# {"b_is_weekend": parseInt( '' ),
# "b_number": parseInt('3'),
# "name": '星期三',
# "short": '週三',
# "shorter": '週三',
# "shortest": '週三'},
# {"b_is_weekend": parseInt( '' ),
# "b_number": parseInt('4'),
# "name": '星期四',
# "short": '週四',
# "shorter": '週四',
# "shortest": '週四'},
# {"b_is_weekend": parseInt( '' ),
# "b_number": parseInt('5'),
# "name": '星期五',
# "short": '週五',
# "shorter": '週五',
# "shortest": '週五'},
# {"b_is_weekend": parseInt( '1' ),
# "b_number": parseInt('6'),
# "name": '星期六',
# "short": '週六',
# "shorter": '週六',
# "shortest": '週六'},
# {"b_is_weekend": parseInt( '1' ),
# "b_number": parseInt('7'),
# "name": '星期日',
# "short": '週日',
# "shorter": '週日',
# "shortest": '週日'},
# {}],
# b_group: [],
# b_simple_weekdays: ['週一','週二','週三','週四','週五','週六','週日'],
# b_simple_weekdays_for_js: ['週一','週二','週三','週四','週五','週六','週日'],
# b_long_weekdays: ['星期一','星期二','星期三','星期四','星期五','星期六','星期日'],
# b_short_months: ['1 月','2 月','3 月','4 月','5 月','6 月','7 月','8 月','9 月','10 月','11 月','12 月'],
# b_short_months_abbr: ['1 月','2 月','3 月','4 月','5 月','6 月','7 月','8 月','9 月','10 月','11 月','12 月'],
# b_year_months: {
# '2017-2': {'name': '2017 年 2 月' },
# '2017-3': {'name': '2017 年 3 月' },
# '2017-4': {'name': '2017 年 4 月' },
# '2017-5': {'name': '2017 年 5 月' },
# '2017-6': {'name': '2017 年 6 月' },
# '2017-7': {'name': '2017 年 7 月' },
# '2017-8': {'name': '2017 年 8 月' },
# '2017-9': {'name': '2017 年 9 月' },
# '2017-10': {'name': '2017 年 10 月' },
# '2017-11': {'name': '2017 年 11 月' },
# '2017-12': {'name': '2017 年 12 月' },
# '2018-1': {'name': '2018 年 1 月' },
# '2018-2': {'name': '2018 年 2 月' },
# '2018-3': {'name': '2018 年 3 月' },
# '2018-4': {'name': '2018 年 4 月' },
# '2018-5': {'name': '2018 年 5 月' }
# },
# b_is_landing : 1,
# b_user_auth_level_is_none: 1,
# b_is_fb_safe: 1,
# b_is_app: 1,
# first_page_of_results: true,
# b_partner_id: '488150',
# b_is_destination_finder_supported: 1,
# b_is_dsf: 0,
# b_pr_param: '',
# /*
# */
# hotelAction: {
# showReviews: parseInt("503", 10),
# minReviews: parseInt("5", 10),
# hotelName: "tai-bei-fa-xian-qing-lu",
# pageLang: "zh-tw",
# hotelCountry: "tw"
# },
# inandaround_more: "更多",
# b_signup_iframe_url: 'https://secure.booking.com' + '/login.html?tmpl=profile/signup_after_subscribe' + '&lang=zh-tw' ,
# b_exclude_lang_firstname: 0,
# view_prices_enter_dates: '請輸入日期以查看房價和空房情況。',
# autocomplete_categories: {
# city: '城市',
# region: '區域',
# airport: '機場',
# hotel: '飯店',
# landmark: '地標',
# country: '國家',
# district: '區',
# theme: '主題'
# },
# autocomplete_skip_suggestions: '搜尋更多選項',
# autocomplete_counter_label: '附近的飯店',
# autocomplete : {
# property_nearby: '家附近的飯店',
# properties_nearby: '家附近的飯店',
# hotel: '住宿',
# hotels: '住宿',
# hotels_nearby: '附近的飯店'
# },
# lists: {
# collection: [
# {
# id: "0",
# name: "我的旅行口袋",
# hotels_count: "0"
# }
# ]
# },
# touch_os: false,
# calendar_days_allowed_number: 350,
# b_search_max_months: 16,
# b_password_strength_msg: ['長度不夠','弱','一般','良好','強','很強'],
# b_passwd_min_length_error: '密碼至少需要8個字符',
# b_password_must_be_numeric: '預訂密碼應為 4 位數字，請重新輸入。',
# b_bkng_nr_must_be_numeric: '訂單編號應為 9 位數字，請重新輸入。',
# b_blank_numeric_pin: '請輸入您的預訂密碼。',
# b_blank_bkng_nr: '請輸入您的訂單編號。',
# password_cant_be_username: '您的密碼不能與郵箱地址相同',
# b_show_passwd: '查看密碼',
# b_passwd_tooltip: '請以大寫字母、特別字符和數字設定密碼以增強密碼安全性',
# account_error_add_password: '請新增密碼',
# password_needs_8: '密碼至少需要8個字符',
# error_sign_up_password_email_combo_01: '請檢查您的電子郵件地址或密碼並重新嘗試。',
# social_plugins_footer: 1,
# b_site_experiment_lazy_load_print_css: 1,
# print_css_href: 'http://t-ec.bstatic.com/static/css/print/8482b8c447a826a23a70d47152c4e86e9f4a5438.css',
# b_hostname_signup: "www.booking.com",
# b_nonsecure_hostname: "http://www.booking.com",
# b_nonsecure_hostname_signup: "http://www.booking.com",
# b_fd_searchresults_url_signup: "",
# translation_customer_service_which_booking_no_specific: '不針對某項預訂',
# stored_past_and_upcoming_bookings: [
# ],
# global_translation_tags: {"rlm":"\u200f","nbsp":"&nbsp;","lrm":"\u200e","line_break":"\u003cbr\u003e"},
# b_photo_pid: (488150).toString(),
# b_wishlist_referrer : '',
# b_reg_user_last_used_wishlist: "",
# b_reg_user_wishlist_remaining: 1,
# is_user_center_bar: 1,
# b_site_experiment_user_center_bar: 1,
# b_reg_user_is_genius : "",
# 'social-connect': [
# {
# state: "",
# provider: "facebook"
# }
# ,
# {
# state: "",
# provider: "google"
# }
# ],
# b_run_social_connect: 1,
# profile_menu: {
# b_site_info: {"is_bookings_owned":1},
# b_site_type: "www",
# b_companyname: "Booking.com",
# b_is_genius_branded: "0",
# b_reg_user_is_genius: "",
# b_genius_dashboard_expiry_destfinder_url: "http://www.booking.com/destinationfinderdeals.zh-tw.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;genius_deals_mode=1&genius_next_weekend=1",
# b_run_bb_pb_reports: "",
# b_reg_user_last_used_wishlist: "",
# b_ge_num_stays: "",
# b_ge_num_stays_left: "",
# b_genius_product_page_url: "http://www.booking.com/genius.zh-tw.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554",
# b_ge_aspiring_profile_menu: "",
# b_ge_aspiring_profile_menu_for_all: "",
# b_ge_is_aspiring_genius_for_all: "",
# b_reg_user_qualify_genius_challenge: "",
# b_reg_user_five_bookings_challenge: "",
# b_ge_is_aspiring_genius: "",
# b_ge_reg_user_personal_details: "",
# b_is_bbtool_admin: "",
# b_is_bbtool_user: "",
# fe_bbtool_permission_can_use_generic_bbtool_features: "",
# fe_bbtool_permission_can_use_admin_bbtool_features: "",
# fe_bbtool_permission_can_use_only_booker_bbtool_features: "",
# fe_bbtool_permission_is_connected_to_bbtool: "",
# fe_bbtool_can_see_tool_promos: "1",
# fe_bbtool_blackout_user: "",
# fe_bbtool_blackout_user_company: "",
# b_reg_user_company_name: "",
# b_reg_user_company_name_escaped: "",
# b_reg_user_companyjoin_url: "",
# b_bbtool_product_page_url: "http://www.booking.com/business.zh-tw.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;stid=934592",
# b_is_ie7: "",
# b_this_url: "/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.zh-tw.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&",
# b_lang_for_url: "zh-tw",
# b_is_villa_site: 0,
# b_secure_hostname: "https://secure.booking.com",
# b_nonsecure_hostname: "http://www.booking.com",
# b_query_params_with_lang: ".zh-tw.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554",
# b_query_params_delimiter: ";",
# b_reg_user_detail_dashboard_url: "",
# b_is_reg_user_city_guide_in_lang_available: "0",
# b_reg_user_aspiring_data: "",
# b_dummy_var_for_trailing_comma: false,
# b_ip_country: "tw",
# b_guest_country: "tw",
# b_raf_multiple_campaigns: true,
# b_agent_is_no_robot: "1",
# b_page_name : "reviews_hotel",
# b_landingpage_theme_type: "",
# b_messaging_available: "",
# b_messaging_url: "",
# b_messaging_entry_point_data_config: "\n\n",
# },
# accounting_config: {"decimal_separator":{"default":"."},"symbol_position":{"default":"before","CZK":"after","RON":"after","PLN":"after"},"currency_separator":{"default":"&nbsp;","JPY":"","GBP":"","USD":""},"group_separator":{"default":","},"num_decimals":{"XPF":"0","TWD":"0","CLP":"0","BHD":"3","MGA":"0","IDR":"0","VND":"0","IQD":"3","TND":"3","KMF":"0","HUF":"0","OMR":"3","RUB":"0","MZM":"0","LYD":"3","TMM":"0","XOF":"0","JPY":"0","PYG":"0","KWD":"3","BYR":"0","DJF":"0","JOD":"3","ISK":"0","GNF":"0","ECS":"0","COP":"0","VUV":"0","UGX":"0","KRW":"0","LAK":"0","AFA":"0","TJR":"0","default":2,"BIF":"0","RWF":"0","XAF":"0"},"html_symbol":{"PLN":"z&#x0142;","RON":"lei","SGD":"S$","HKD":"HK$","BRL":"R$","CZK":"K&#269;","IDR":"Rp","GBP":"&#163;","JPY":"&#165;","TRY":"TL","ARS":"AR$","EUR":"&#x20AC;","CLP":"CL$","USD":"US$","INR":"Rs.","ILS":"&#x20AA;"}},
# distance_config: "metric",
# b_run_tfl_move_away_from_lightbox: true,
# b_wishlist_singlepage_url: 'https://secure.booking.com/mywishlist.zh-tw.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554',
# is_listview_page: true,
# b_this_weekend_checkin: "",
# b_this_weekend_checkout: "",
# b_next_weekend_checkin: "",
# b_next_weekend_checkout: "",
# b_official_continent: "",
# b_deals_continents : "",
# b_condition_login_with_bn_pin: 1,
# b_site_experiment_login_with_bn_pin: 1,
# b_is_villa_site : 0,
# b_messenger_url: '',
# b_open_messenger: false,
# b_extra_ajax_headers: {},
# b_run_loc_ce_update_timer_v2: true,
# et_debug_level: '0',
# et_deprecation_warnings: false,
# trackExperiment : function () {},
# "error" : {}
# },
# ensureNamespaceExists: function (namespaceString) {
# if (!booking[namespaceString]) {
# booking[namespaceString] = {};
# }
# }, hotel: {}, experiments: {}, startup: {}, experiments_load: {}, startup_load: {}, promotions: {}, timestamp: new Date()};
# function Tip() {};
# (function (scope) {
# booking.env.b_sb_autocomplete_predictions_url = '/autocomplete_2';
# var params = scope.search_autocomplete_params = {};
# params.v = '1';
# params.lang = 'zh-tw';
# params.sid = 'a69dc815b256b32729409bba84f65554';
# params.aid = '397642';
# params.pid = '5b5c4dbbaa1202a3';
# params.stype = '1';
# params.src = 'reviews_hotel';
# params.eb = '4';
# params.e_obj_labels = '1';
# params.at = 1;
# params.e_tclm = 1;
# params.add_themes = '1';
# params.themes_match_start = '1';
# params.include_synonyms = '1';
# })(window.autocomplete_vars || booking.env);
# </script>
# <script>var _gaq = _gaq || [];</script>
# <!--[if IE]> <script> document.createElement('time'); </script> <![endif]-->
# <script>
# booking.jset = {"f":{"ZCDSDVCXdUFDeTLbQVAHAbWTKe":1,"OLFYMZTUMKeacWXT":2,"ABbFTOTOOMSYeJBDdKIJRLT":1,"bPSELUXXRePeRBDYeFPbOGeNfRJbRWe":1,"VObLMOLSWFMfaADWe":1,"ZCDFGTOKTfGCfWfecNfdQHT":1,"adUdWHeQZbNLNIfNSBYHe":1,"eRQFFZVAGdSYO":1,"VObLMbNXGDJESWFMacWIVYCFaO":1,"adUdWHYZbIFOWGJNBZAKe":1,"VMKIbEXROEcMCdYIYdETfRdadYO":1,"BIUJLMJIYSaJRbAAPMNUJTKaT":1,"eDUfHbcGRcbQGWRVKaMUHXdRT":1,"fEDSFAHNXKeZKVUNHFAPTPWOGATNSeKdRe":2,"VMKIaYPMSJLdCbHe":1,"eIabKeVBSCOOSHJVYLCBRe":1,"cPJJWEEdJRIcOcNVBUKcKe":1,"BUZdfbGbEESLEcXO":1,"OMHBafWbBMRVDVfdBADWaO":1,"YdVPYKDcdDVfdBNeURJLNFET":1,"BUZdffQBRPXdAOVYJKMOKe":1,"fEJdDBKWeDORadYbeQMIbGNYO":1,"OMOLNYJKAaNCWQeFTZUFPIbYO":2,"ABbFTEOADNBdTZbJIIIKe":1,"VMKIbaeaNVTZHT":1,"bPSELSRSdVRPBfAJdcRAcIaTcDCXe":1,"PYNYeCIObTEcYWRbHJQPYQQZRO":1,"cQZKZJAQPeMFcDcQUAEXcGKCQMWUC":1,"VMKIbVSBBfFHZHT":1,"OMOQUQZWTNJGOaT":1,"ZOBUYLMcITDTbYFcYEHSUeKe":1,"ABbFCFbWeWGVeNBRUDfEQYKe":1,"BKbVZdEYaRBdMFPLT":1,"ZOCDMEOUNMdbDHT":1,"PNHafDcaRDPNZJQAZFO":1,"BUaWODTPZANUOcIScdMbSMATBWe":1,"ZOICXWVYDSfSLdXFNPIIaeaGVfQHO":1,"cPJJWfMOBcMdBfMPSXPKVXFC":1,"ZCDSWSLYDbRbWLKVHFO":1,"NAFQVaPEbBBcfFdHMdeUbLFcLJHO":1,"PYTbJAEcMEdaWNMcdBNTXT":1,"fESCFPNSAJSWXeLDDSC":1,"IZVEEJPVdEPeSMfbHJIYSaWe":1,"dddYIQFIMNWUSUSDRBdFO":1,"YPNBYbIGbUKZTFNefFHe":1,"PNFBfQYZPaIEHBEfIPPSfDcNeC":1,"AEJPMbHAcUVFccSTKe":1,"AEJPCCdQIXYQEBfKCGGORe":1,"VOaNPAJHOHRCTeMIRBPKJXIIKe":1,"ZOdQHYfBQWDVaKbYO":1,"VMKIaHPMSJLRJAXaaO":1,"ZCDSJIJUZIKGYBRAOAcEUC":1,"BIUJLMWeDfBAFFWeVQOSRKAZJScWcDaWe":1,"YPNOKFHMPfQDIbCNKBBO":1,"ZCRAOAcEUJfObCCKSFBIUJLMJIYSaJRKe":1,"AEJPVZMYCMTXbfRSGdePAZZbYHYO":1,"HMeTYUUPJeGdXbVAANLT":1,"OMZOOTVbCOaBdeUfBQWEeJHOWYO":1,"OMZOXTbdBcXOVIWSUPIHPcCJNbKBAcFASVVC":1,"eDdJFHBZYfefbEKSccdZWOJNET":1,"dddYIQFNSebRaTKBGfNaT":1,"adUAABYQKXSPDGXLMdSSHT":1,"bZWOXGBbLPNEVdZBAFQJIHTPBYHe":1,"NAZSNMGEfEDdWQUeWIbUWe":1,"TAeKPWPDSJMDERXDbEbeOWdCNKbdLOLOLMO":1,"adUAAKTVeBKeYEGHKRSLMJUALFLeSXT":1,"OMBUcJHcWCcdbLMaCffZFLWC":1,"PNcbdGBUHaZFdTPeeFGbFC":1,"eRYZYTEDUSANfYO":1,"ABbFTOTdfdPIHAEeUOHSeEDRVOZXQae":1,"OMOQZWKETBUADCLdaWeae":1,"eDUfHbcGRcbQGWRVKaMUPbHe":1,"NAZSNMGdRWSdSdceUPUUHVPHXe":1,"AEJPMbHAcUVFccSTfMPSXWe":1,"VOaNZTZIAESSIBaQcSdVLT":1,"ZCDRSLQKLKfPBDOQSGeFfTTKe":1,"OMOLcbGUEZGZdMIZDHTIYAZae":2,"PYJPOYJRHHaUC":1,"OMBUcFaRdMDAHae":2,"bQEafDeDFCJPUSOYVHFDAUTBaQDfBQJbLTJADUKe":1,"PYGYSOTOFZYHUC":1,"fEJdDBKDTBOPFBPFUZXeUZEUZC":1,"ebcNQKAENeNZdJOVBSbEQWe":1,"fESeCXYWLAMO":1,"cPJJFKeFbAcfWET":1,"ABcLYSIZDVLLITWWCQSLT":1,"AEJPELZHWEYZLPNMQMLZBRYLWcDaWe":1,"cQZVDZOKZdKNWYKe":1,"fESfMRaHVIWVZfC":1,"BfaLEXAGCBKC":1,"OMOQQBFNKPfOZZAWe":2,"PYTbdWGAMWXKYSSTMSBXe":1,"MKMBYNYScXQOVZbObSVHLeNBLLT":1,"ebcOQZWBbLOXNSZBeRe":1,"OMOQHNJFNWSJcCIOSCFGPfECIAaKLWe":1,"OMTLEKXJYINNPaGMYVVPBNaDSKKMfQcUNC":1,"OMaDUIFacYdEKfPBDORe":1,"bPSELVRNQcedZQXbLVReQMMfOROJGcYZVIXe":1,"eWRbceDTANZVCMILDDRNSTNSbZebYZTNSAJeRe":1,"OMZXVKZMSHUTYcbWTNFbUC":1,"VOGcZdZfAWQIAPPeae":1,"OMHBaOMZDBdZRO":1,"ebcOQPIHAdLVBHVJFWJcdHbFeKe":1,"adUAAMVZALOEaJPGAAQeccVT":1,"adUdWHOdDFIMNSdTFJZSdVT":1,"OMbLYAbZZBLQZDC":1,"cPWbVdBceEUVTZHT":2,"AEJPCCKdJMbfdSKfXFNHC":1,"PYNYYNRZYDTeRT":1,"TULQWXSaVbBdPdUVNFBNHC":1,"adUdWHYSdFYHDEFRYEFDVVGcVT":1,"TDXbdFSOefFYATKBTBTC":1,"IZVXOeFWFPWe":1,"OMNHJAWCZdTTXZabGMKZePPGKVT":1,"adUdWHYHNNNAcfQPVYLXC":1,"BIUJLMWeDfBAFGbJdZNVUIRe":1,"PYFGeNBLFEZeaPLeQETC":1,"ABbDSFLFNHDYEaNdNFKGbedJJYDYO":1,"TULQWPRVKaMUHSQFUUPXCYO":1,"BCOELUONCGVKe":2,"adUAVGPJceVccVeCIObTETZHT":1,"PNFOOTXGBUbRSdDaORe":1,"HMeOIEeUefJZPELBOXQDBae":1,"ZCDSSVCHCTeVeNBPOdCLSeRIdeYWe":1,"OMOQRWSENWMeAcKBTC":1,"ZCFRURURYNYeaHbEOTOCacWCcHVHYQC":1,"OMOLUBBCcMZLOAAPCBUKcC":1,"OMHBbOcYSRbKCBZAWe":1,"NVNUdBQMdIKGYBFbUFQLNHNfLae":1,"ZCWPDSDIDeQcJZbLcKTLO":1,"PNFOOTXGBUaRcBNSGffeTRe":1,"PNFBBUIDJGOGdBKe":1,"OMBUNGSEBVEHJebSXT":1,"cPWbVdMFHSUTIcMVNLdcJC":1,"OMNHJAWCZdTTXZabGMKWe":1,"ZOOCeLFdCQFOMOabBTKYbdfdaT":1,"OMHBbOcYaMDfDbfGYYT":1,"bHVNNSTUOIPNBdCMVZAeYAae":1,"OMGWCMcDWe":1,"OMOQJJSVHcOUfFZMfWe":1,"BIUJLMDPBJSGbHT":1,"OMebcOQPBRYZVXVFPWHT":1,"bHVNYTfGTJJGGZJARGPHBGDHT":1,"OMOQSTYRAQFZDDUZeEdaWYO":1,"HBbMWcaWOHVULFGO":1,"VOaNZ ...
# booking.jst = {"ZOMFJQPNLTLLCBRe":0,"beKMDNdEeKe":2,"HMeIFGKSGTaNFOeBDHC":1,"ZOOPRAFGKSGdeUabBeUNSIOYDMdbDHT":0,"eIBbFYLCBLFJYbVAGeMeIKEOYC":0,"AEJPVZMYCVLBQRWSEaEIVDaXe":0,"TAeKPWbVLBQScADDbdEScXQOVWe":0,"HSCQQOcZQPPeae":1,"deeXGKeePPZSeHT":1,"IZGNCAXZQAXVASOWKEOYC":1,"ZOTWOAZBEERFCUbLOLHT":0,"VMKIfaMNfWJfQYZPaXQC":1};
# booking.jsdt = {"HMeIFGKSGTaNFOeBDHC":1,"beKMDNdEeKe":2,"IZGNCAXZQAXVASOWKEOYC":1,"deeXGKeePPZSeHT":1,"HSCQQOcZQPPeae":1};
# booking.env.b_fragment_url_html = "/fragment.zh-tw.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554";
# booking.env.b_fragment_url_json = "/fragment.zh-tw.json?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554";
# booking.ensureNamespaceExists('affiliate');
# booking.affiliate.platform = {
# isHybrid: 0,
# isCobrand: 0
# };
# booking.affiliate.settings = {
# showSignUpPrompt: 0
# };
# booking.affiliate.variables = {
# userLoggedIn: 0
# };
# booking.affiliate.params = {
# destinationFinderSignUpPrompt: 0
# };
# </script>
# <title>1057條青年旅舍真實住客點評 - Taipei Discovery Hostel - Booking.com</title>
# <meta name="description" content="閱讀 1057 則入住台北市「台北發現青旅」真實住客評語，Booking.com 顧客評分 9.2（滿分 10）。">
# <link rel="next" href="http://www.booking.com/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.zh-tw.html"/>
# <meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=2">
# </head>
# <body
# id="b2reviews_hotelPage"
# class="bookings2 b2 reviews_hotel zh lang_is_cjk header_reshuffle nobg user_center app_user_center b-sprite-3 lt bigblue_std_sm bigblue_std_lg arial_to_helvetica
# iconfont_is_loading  reviews_new palette-1 ">
# <script>(function(){
# 'use strict';
# var stats = window.ttiStats = {};
# var addListener = function (name, fn) {
# if ('addEventListener' in document) {
# document.addEventListener(name, fn);
# } else {
# document.attachEvent('on' + name, fn);
# }
# };
# var removeListener = function (name, fn) {
# if ('removeEventListener' in document) {
# document.removeEventListener(name, fn);
# } else {
# document.detachEvent('on' + name, fn);
# }
# };
# var baseTimeStamp = (new Date()).getTime();
# var onClick = function onClick() {
# stats.click = (new Date()).getTime() - baseTimeStamp;
# removeListener('click', onClick);
# };
# var onScroll = function onScroll() {
# stats.scroll = (new Date()).getTime() - baseTimeStamp;
# removeListener('scroll', onScroll);
# };
# addListener('click', onClick);
# addListener('scroll', onScroll);
# })();
# </script>
# <script type="text/javascript">
# window.utag_data = {
# site: 'bookings2',
# stypeid: '1',
# action: 'reviews_hotel',
# crt: '1',
# trg: '0',
# fbp: '1',
# exp1: '',
# exp2: '0',
# alev: '0',
# atid: '',
# atnm: '',
# biz_s: '0',
# biz_p: '',
# bo: '1',
# browser: 'chrome',
# browser_ver: '24',
# bstage: '',
# clkid: '',
# emksho: '1',
# genis: '',
# genasp: '',
# n_b: '',
# sid: 'a69dc815b256b32729409bba84f65554',
# ui: '',
# hotel_name: '台北發現青旅',
# channel_id: '',
# partner_id: '',
# ai: '',
# adults: '',
# book_window: '',
# children: '',
# district_name: '',
# city_name: '',
# region_name: '',
# country_name: '',
# currency: '',
# date_in: '',
# date_out: '',
# dayofwk: '',
# depth: '',
# dest_type: '',
# dest_id: '',
# dest_cc: '',
# dest_ufi: '',
# dest_name: '',
# hotel_count: '',
# hotel_id: '',
# hotel_id_list: '',
# hr: '',
# i1: '',
# i2: '',
# i3: '',
# isfd: '',
# isnl: '',
# label: '',
# language: '',
# logged_in: '',
# nights: '',
# cv: '',
# ordv: '',
# rooms: '',
# seed: '',
# srord: '',
# sub: '',
# ui_a: '',
# user_location: '',
# wkend: '',
# q1: ''
# };
# (function(a,b,c,d){
# var w = window || {};
# function loadTagContainer(){
# a='//tags.tiqcdn.com/utag/booking.com/main/prod/utag.js';
# b=document;c='script';d=b.createElement(c);d.src=a;d.type='text/java'+c;d.async=true;
# a=b.getElementsByTagName(c)[0];a.parentNode.insertBefore(d,a);
# };
# if(w.addEventListener){
# w.addEventListener('load', loadTagContainer, false);
# } else if(w.attachEvent){
# w.attachEvent('onload', loadTagContainer);
# }
# })();
# </script>
# <div id="bodyconstraint" class=" clearfix "> <div id="bodyconstraint-inner">
# <div id="top" role="banner" >
# <a
# class="js-header__logo"
# href="http://www.booking.com/index.zh-tw.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;click_from_logo=1"
# style="text-decoration: none;"
# >
# <img id="logo_no_globe_new_logo"
# class=" "
# src="http://s-ec.bstatic.com/static/img/b26logo/booking_logo_retina/22615963add19ac6b6d715a97c8d477e8b95b7ea.png"
# alt="Booking.com：線上訂房專家" />
# </a>
# <div id="user_form" class="ticker_space smaller_booking_nr_login user_center_bar">
# <div data-component="track" data-track="view" data-hash="GCaRZEGcCSRPLSGSZKe" data-stage="1"></div>
# <ul class="user_center_nav"
# >
# ...
# </script>
# <script type='text/javascript'>
# booking.jstmpl('rt_availability_soldout', (function () { var T = ["\n","\n\u003ch4 class=\"rt_availability_soldout__header\"\u003e","\u003c/h4\u003e\n\u003cul class=\"rt_soldout_list\"\u003e\n","\n\u003cli class=\"rt_soldout_list__item\"\u003e\n\u003ca class=\"rt_soldout_list__link js-rt-availability-soldout-link\" href=\"","\" data-component=\"track\" data-track=\"click\" data-hash=\"","\" data-custom-goal=\"1\"\u003e\n\u003cspan class=\"rt_soldout_list__dates\"\u003e"," – ","\u003c/span\u003e\n\u003cspan class=\"rt_soldout_list__price\"\u003e","\u003c/span\u003e\n\u003c/a\u003e\n\u003c/li\u003e\n","\n\u003c/ul\u003e\n"], V = ["ppd_hp_sold_out_next_available","b_data","b_url","b_checkin","b_checkout","b_from_price_text","b_success"], WV, LV, VA; return function (VS) { var s = '', r = this.fn; function hotel_rooms_table_experiment_droom_rt_soldout_date_suggestions_cta_inc1(s) { s += [ '', T[0] ].join( '' ); if (r.MD(V[6])) { s += [ T[1], r.MB(V[0]), T[2] ].join( '' ); { var LA= ( r.MC(V[1]) || [] ); VS.unshift(null); for(var LC=1, LM= LA.length; LC <= LM; LC++) { VS[0]= LA[LC - 1]; s += [ T[3], r.MC(V[2]), T[4], 'BUZdfbGbELSVHJPJCQfUC', T[5], r.MC(V[3]), T[6], r.MC(V[4]), T[7], r.MC(V[5]), T[8] ].join( '' ); } VS.shift(); } s += T[9]; } s += [ T[0], '' ].join( '' ); return s; } s += T[0]; s = hotel_rooms_table_experiment_droom_rt_soldout_date_suggestions_cta_inc1(s); s += T[0]; return s; }; } )());
# </script>
# <script type='text/javascript'>
# booking.jstmpl('bpg_module_overlay', (function () { var T = ["\n","\u003cdiv class=\"bpg-overlay--wrapper\"\u003e\n\u003cdiv class=\"bpg-overlay--content\"\u003e\n\u003ch1\u003e\n","\n\u003c/h1\u003e\n\u003cp\u003e\n","\n\u003c/p\u003e\n\u003ca href=\"javascript:void(0);\" class=\"bpg-overlay--close\"\u003e","/private/close/name","\u003c/a\u003e\n\u003ch2 class=\"hd\"\u003e\n","\n\u003c/h2\u003e\n\u003cul style=\"list-style-type: none;\"\u003e\n\u003cli class=\"first_lev\"\u003e\n","\n\u003c/li\u003e\n\u003cli class=\"first_lev\"\u003e\n","\n\u003c/li\u003e\n\u003cli class=\"first_lev\"\u003e","\u003c/li\u003e\n\u003cli class=\"first_lev\"\u003e\n\u003cul\u003e\n\u003cli class=\"second_lev\"\u003e","\u003c/li\u003e\n\u003cli class=\"second_lev\"\u003e","\u003c/li\u003e\n\u003c/ul\u003e\n\u003c/li\u003e\n\u003cli class=\"first_lev\"\u003e","\u003c/li\u003e\n\u003c/ul\u003e\n\u003cp\u003e","\u003c/p\u003e\n\u003ch2 class=\"hd\"\u003e\n","\n\u003c/h2\u003e\n\u003cul style=\"list-style-type: none;\"\u003e\n\u003cli class=\"first_lev\"\u003e","\u003c/li\u003e\n\u003cli class=\"first_lev\"\u003e","\u003c/li\u003e\n\u003c/ul\u003e\n\u003c/div\u003e\n\u003c/div\u003e\n"], V = ["pp_index_popup_bpg_we_price_match","pp_index_popup_bpg_quick_desc","bpg_terms_popup_03","bpg_terms_popup_04","bpg_terms_popup_05","bpg_terms_popup_06","bpg_terms_popup_07","bpg_terms_popup_08","bpg_terms_popup_09","bpg_terms_popup_10","bpg_terms_popup_11","bpg_terms_popup_12","bpg_terms_popup_13","pdi_index_wpm_popup_cant_claim","bpg_terms_popup_15","bpg_terms_popup_16","bpg_terms_popup_17","bpg_terms_popup_18","bpg_terms_popup_19","bpg_terms_popup_20","bpg_terms_popup_21"], WV, LV, VA; return function (VS) { var s = '', r = this.fn; function bookings2tmpl_inc_bpg_popup_content_inc1(s) { s += [ T[1], r.MB(V[0]), T[2], r.MB(V[1]), T[3], r.ME(T[4], r.MB, r.MN, null), T[5], r.MB(V[2]), T[0], r.MB(V[3]), T[6], r.MB(V[4]), T[7], r.MB(V[5]), T[8], r.MB(V[6]), T[9], r.MB(V[7]), T[10], r.MB(V[8]), T[10], r.MB(V[9]), T[10], r.MB(V[10]), T[11], r.MB(V[11]), T[12], r.MB(V[12]), T[13], r.MB(V[13]), T[14], r.MB(V[14]), T[15], r.MB(V[15]), T[9], r.MB(V[16]), T[10], r.MB(V[17]), T[10], r.MB(V[18]), T[10], r.MB(V[19]), T[11], r.MB(V[20]), T[16] ].join( '' ); return s; } s += T[0]; s = bookings2tmpl_inc_bpg_popup_content_inc1(s); s += T[0]; return s; }; } )());
# </script>
# <script>
# (function(B){
# var tmp = B._onfly || [], fn;
# for (var i = 0, l = tmp.length; i < l; i++) {
# if (typeof tmp[i] === 'function') tmp[i].call(B);
# }
# B._onfly = null;
# }(booking));
# </script>
# <script>
# (function(B){
# var jstmpl = B && B.jstmpl,
# translations = jstmpl && jstmpl.translations;
# translations && translations.set && translations.set({"error":{"checkin_date_to_far_in_the_future":{"name":"您的入住日期離現在太久，請重新試訂"},"checkout_date_invalid":{"name":"您的退房日期不存在"},"checkin_date_invalid":{"name":"您的入住日期不存在"}},"private":{"list_dropdown_email_example":"name@example.com.tw; name@example.com.tw","list_show_prices_of_all":"查看所有住宿價格","bbse_pretrip_email_feedback_yes":"送出","filter_hide":"隱藏","deals_deal_of_day_countdown_timer":"{hours_remain}：{minutes_remain}：{seconds_remain}","lists_map_see_more":"查看更多","list_check_availability_of_all":"查看所有住宿的客房供應情況","bpg_terms_popup_16":"2. 您預訂時使用了：","lists_email_success_message":"太棒了！你的訊息已送出","please_enter_your_check_in_date":"請輸入您的入住日期","sxp_calendar_starting_prices_with_dates_error":"選擇日期並點選 {start_bold}搜索{end_bold}以查看價格","my_list_date_button_v2":"套用日期以查看房況","hours":"小時","pb_google_place_convenience_store":"便利商店","review_adj_average_okay":"可以","deals_price_watch6":"開始追蹤","language_exception_bdot_x_rooms_left_urgency_1":"本站僅剩 {num_left} 間客房！","lists_endorsement_perfect_stay":"尋找理想住宿！","dsf_rename_list_dialogue":"為此清單輸入新名稱","pb_google_place_florist":"花店","review_adj_good":"好","pb_google_place_park":"公園","lists_compare_got_it":"知道了，謝謝！","bpg_terms_popup_06":"2. 其他網站的更低價格優惠在我們核查時仍然可以預訂。","destination_finder_theme_endorsements":"{start_style}{num_endorsement_guests}{end_style}位客人將此地標記為{start_style}“{theme_name}”{end_style}","review_helpful_vote_you_and_others_bold":"{start_bold}你和其他 {number_people} 位客人{end_bold}認為此則評論有幫助","list_icon_tooltip_list_view":"清單檢視","ar_islamic_calendar_ramadan":"Ramadan","sbox_dates_num_nights_1":"入住 {num_nights} 晚","name":"姓名","book_button_now":"立即預訂","list_dropdown_email_last_name_example":"周","pb_google_place_art_gallery":"藝廊","list_dropdown_send_button":"傳送","sbox_num_adults":"{num_adults} 位成人，","lists_sign_in_to_see_click_here":"登入","pb_room_disclaimer":"此房型例圖僅供參考，實際狀況視個別客房而定。","book_from_list_select_dates":"選擇入住日期","price_watch_sorry_1":"抱歉，每人最多僅可追蹤 {max_number_properties} 項價格。","top_3_reasons_to_visit":"造訪此地三大理由：{theme_01}、{theme_02}、{theme_03}","language_exception_sbox_num_children_1":"1 位孩童","m_sr_distance_from_centre_city":"距{city_name}中心 {distanceInKmFromCentre}","free_capitals_cancellation":"免費取消","bpg_terms_popup_20":"住宿場所提供的其他類型的獎勵計劃或特別促銷","search_guest_type_children":"兒童","pb_google_place_spa":"SPA 中心","pb_google_place_meal_takeaway":"外帶店","list_my_lists_onbaording_box_save":"儲存","loc_hp_reviews_see_translation":"查看翻譯版本","ppd_hp_rt_filter_non_ref_num":"不可退款 ({num})","ppd_hp_rt_filter_no_prepayment":"無需訂金","clear_urgency_only_x_rooms_left":"本站僅剩 {amountRooms} 間客房！","bpg_terms_popup_18":"常客特價","df_sold_out_hotels_explain":"所選日期內，網站上此住宿的所有空房已售完。","minutes":"分鐘","deals_price_watch5":"檢視範例","pdi_index_wpm_popup_cant_claim":"什麼情況無法申請退差價？","language_exception_clear_urgency_only_x_rooms_left_1":"本站僅剩 {amountRooms} 間客房！","bpg_terms_popup_10":"相同的入住及退房日期","pb_google_place_shopping_mall":"購物中心","vp_hp_growl_recommendation_head":"特別為您推薦{property_name}","ppd_hp_sold_out_next_available":"選擇其他日期：","pb_google_place_night_club":"夜店","ar_islamic_calendar_two_years":"{first_hijri_month} {first_year}/{second_hijri_month} {second_year}","list_dropdown_email_first_name_example":"廷宣","header_my_lists":"我的清單","lists_room_type_lightbox_room":"其他 {number_of_rooms} 種房型","sbox_age_of_child_popup_best_price":"填入此選項，查看團體出遊最優惠房價！","please_take_a_few_seconds":"懇請您花幾分鐘時間在此 {quick_surveyLink}快速問卷調查{endLink}中提出您的寶貴意見。","days":"天","close":"關閉","seo_country_lp_read_more":"顯示全部","list_percent_off_value":"{percent_off_value}% OFF","list_dropdown_header":"你可將住宿分類存入清單","last_chance":"最後機會！","bpg_terms_popup_04":"如果符合下列條件要求，我們將讓您享受相同的價格：","bpg_terms_popup_07":"3. 其他網站的更低價格優惠與您在{b_companyname}預訂的優惠擁有相同的預訂條款，即：","language_exception_ng_map_price_for_x_nights_1":"1 晚房價","lists_undo_option_basic":"還原","msg_entry_meet_assistant_subheader":"Need a parking space, extra bed, different check-in time or just want to ask if your pet can come? I’m here to help.","clear_urgency_list_not_available":"本網站於下 ...
# }(window.booking));
# </script>
# <script>
# booking.env.priceWatch = {
# b_price_alert_canceled: "",
# b_price_alert_all_canceled: ""
# };
# </script>
# <script> if( window.performance && performance.measure && 'b-post-scripts') { performance.measure('b-post-scripts'); } </script>
# <div style="display: none;" id="logo-not-document-write"></div>
# <script type="text/javascript">
# setTimeout(function(){
# var img = new Image(1,1);
# img.src = '/logo?ver=1&sid=a69dc815b256b32729409bba84f65554&t='+1487156599+1;
# },0);
# </script>
# <noscript>
# <img style="display:none" src="/logo?ver=0&sid=a69dc815b256b32729409bba84f65554&t=1487156599">
# </noscript>
#
# <script type="text/javascript">
# (function(){
# window.lightningjs||function(c){function g(b,d){d&&(d+=(/\?/.test(d)?"&":"?")+"lv=1");c[b]||function(){var i=window,h=document,j=b,g=h.location.protocol,l="load",k=0;(function(){function b(){a.P(l);a.w=1;c[j]("_load")}c[j]=function(){function m(){m.id=e;return c[j].apply(m,arguments)}var b,e=++k;b=this&&this!=i?this.id||0:0;(a.s=a.s||[]).push([e,b,arguments]);m.then=function(b,c,h){var d=a.fh[e]=a.fh[e]||[],j=a.eh[e]=a.eh[e]||[],f=a.ph[e]=a.ph[e]||[];b&&d.push(b);c&&j.push(c);h&&f.push(h);return m};return m};var a=c[j]._={};a.fh={};a.eh={};a.ph={};a.l=d?d.replace(/^\/\//,(g=="https:"?g:"http:")+"//"):d;a.p={0:+new Date};a.P=function(b){a.p[b]=new Date-a.p[0]};a.w&&b();i.addEventListener?i.addEventListener(l,b,!1):i.attachEvent("on"+l,b);var q=function(){function b(){return["\u003Chead\u003E\u003C/head\u003E\u003C",c,' onload="var d=',n,";d.getElementsByTagName('head')[0].",d,"(d.",g,"('script')).",i,"='",a.l,"'\"></",c,">"].join("")}var c="body",e=h[c];if(!e)return setTimeout(q,100);a.P(1);var d="appendChild",g="createElement",i="src",k=h[g]("div"),l=k[d](h[g]("div")),f=h[g]("iframe"),n="document",p;k.style.display="none";e.insertBefore(k,e.firstChild).id=o+"-"+j;f.frameBorder="0";f.id=o+"-frame-"+j;/MSIE[ ]+6/.test(navigator.userAgent)&&(f[i]="javascript:false");f.allowTransparency="true";l[d](f);try{f.contentWindow[n].open()}catch(s){a.domain=h.domain,p="javascript:var d="+n+".open();d.domain='"+h.domain+"';",f[i]=p+"void(0);"}try{var r=f.contentWindow[n];r.write(b());r.close()}catch(t){f[i]=p+'d.write("'+b().replace(/"/g,String.fromCharCode(92)+'"')+'");d.close();'}a.P(2)};a.l&&q()})()}();c[b].lv="1";return c[b]}var o="lightningjs",k=window[o]=g(o);k.require=g;k.modules=c}({});
# function preloadUsabilla(){
# window.usabilla_live = lightningjs.require("usabilla_live", "//w.usabilla.com/78826ff9ad8b.js");
# }
# function onUsabillaClick(event){
# B[sNSStartup].lightbox.hide();
# if (event) {
# $(event.target).closest('.user_center_popover').hide()
# event.preventDefault();
# }
# if (!window.usabilla_live) {
# preloadUsabilla();
# }
# window.usabilla_live('data', { custom: { user_id: ""} });
# window.usabilla_live('data', { custom: { action: "reviews_hotel"} });
# window.usabilla_live('click');
# }
# $('.provide_website_feedback').click(onUsabillaClick);
# (booking.eventEmitter || $( window )).bind('uc_popover_showed', function(event, options){
# if (options.id === 'uc_feedbacklink_box') {
# preloadUsabilla();
# }
# });
# }());
# </script>
# <script type="text/javascript">
# booking.ensureNamespaceExists('env');
# booking.env.google_analytics_tracking_enabled = 1;
# booking.env.b_label = 'gog235jc-index-XX-XX-XX-unspec-tw-com-L:xt-O:abn-B:unk-N:yes-S:bo-U:salo';
# booking.env.b_availability_checked = '';
# booking.env.b_multiple_destinations_found = '';
# if (typeof _gaq == 'object' || (window.ga && typeof window.ga === 'function')) {
# booking.ensureNamespaceExists('google');
# if (typeof booking.google.returnAnalyticsTrackingString != 'undefined') {
# booking.google.analyticsTrackingString = booking.google.returnAnalyticsTrackingString();
# }
# try {
# (function(q,u,i,c,k){window['GoogleAnalyticsObject']=q;
# window[q]=window[q]||function(){(window[q].q=window[q].q||[]).push(arguments)},
# window[q].l=1*new Date();c=i.createElement(u),k=i.getElementsByTagName(u)[0];
# c.async=true;c.src='//www.google-analytics.com/analytics.js';
# k.parentNode.insertBefore(c,k)})('ga','script',document);
# ga('create', 'UA-116109-18' ,{
# 'cookieDomain': '.booking.com'
# });
# ga('set', 'location', String(document.location.href).replace(/(auth_key|bn|pin|reset_hash)([^;&]+.)/gi, ''));
# ga('require', 'displayfeatures');
# ga('set', 'anonymizeIp', true);
# (function(){
# if (booking.env.b_group && booking.env.b_group.length) {
# var group = booking.env.b_group,
# g, i, length = group && group.length,
# value = {
# rooms: 1,
# adults: 0,
# children: 0,
# childrenAges: []
# },
# isGroupPresent = length > 1 || ( length === 1 && ( group[0].guests > 2 || group[0].ages.length > 0 ) ) || booking.env.b_group_rooms_wanted > 1;
# for ( i = 0; i < length; i += 1 ) {
# g = group[i];
# value.adults += parseInt(g.guests, 10);
# if (g.ages) for (var j = 0, jc = g.ages.length; j < jc; j++) value.childrenAges.push(g.ages[j].age);
# }
# value.rooms = booking.env.b_group_rooms_wanted || booking.env.bs_room_num || length;
# value.children = value.childrenAges.length;
# value.childrenAges = value.childrenAges.sort(function(a, b){return a - b;});
# booking.env.sGroupConfig = (value.rooms || '1') + ' rooms | ' + (value.adults || '1') + ' adults | ' + value.children + ' kids' + (
# value.children ? ' (' + value.childrenAges.join(' | ') + ')' : ''
# );
# booking.env.isGroupPresent = isGroupPresent;
# if (value.children || value.childrenAges.length > 0) {
# booking.env.ga_group_string = 'Family';
# } else if (value.adults === 1) {
# booking.env.ga_group_string = 'Solo';
# } else if (value.adults === 2) {
# booking.env.ga_group_string = 'Couple';
# } else {
# booking.env.ga_group_string = 'Group';
# }
# }
# var pageviewInfo = {
# page: booking.google.analyticsTrackingString || '/',
# dimension17: "reviews_hotel|",
# dimension4: "A69DC81",
# dimension5: "397642",
# dimension6: "17",
# dimension7: "488150",
# dimension8: "gog235jc-index-XX-XX-XX-unspec-tw-com-L:xt-O:abn-B:unk-N:yes-S:bo-U:salo",
# dimension44: "",
# dimension9: booking.env.sGroupConfig || '',
# dimension11: "desktop",
# dimension12: "zh-tw",
# dimension10: "0",
# dimension29: "0",
# dimension84: "0",
# dimension31: "unknown",
# dimension45: 'tw->tw',
# dimension37: (booking.env.b_guest_country == booking.env.b_countrycode) ? 'domestic' : 'international',
# dimension61: "0",
# dimension62: "null",
# dimension63: "null",
# dimension64: '',
# dimension66: 0,
# dimension72: "None",
# dimension85: booking.env.ga_group_string || '',
# dimension99: "null"
# }
# setTimeout(function() {
# if (typeof ga !== 'function') return;
# try {
# ga(function(tracker) {
# ga('set', 'dimension60', tracker.get('clientId'));
# });
# ga('send', 'pageview', pageviewInfo);
# } catch (e) {}
# });
# })();
# } catch (err) {
# }
# } else {
# pageTracker = {
# _initData : function () { },
# _trackPageview : function () { },
# _setDomainName : function () { },
# _setAllowLinker : function () { },
# _link : function () { },
# _linkByPost : function () { },
# _addTrans : function () { },
# _addItem : function () { },
# _trackTrans : function () { },
# _addOrganic : function () { },
# _setVar : function () { },
# _setCookiePath : function () { },
# _setClientInfo : function () { },
# _setAllowHash : function () { },
# _setDetectFlash : function () { },
# _setDetectTitle : function () { },
# _setSessionTimeout : function () { },
# _setCookieTimeout : function () { },
# _setCampNameKey : function () { },
# _setCampMediumKey : function () { },
# _setCampSourceKey : function () { },
# _setCampTermKey : function () { },
# _setCampContentKey : function () { },
# _setCampIdKey : function () { },
# _setCampNOKey : function () { },
# _setAllowAnchor : function () { },
# _addIgnoredOrganic : function () { },
# _addIgnoredRef : function () { },
# _setSampleRate : function () { },
# _setLocalRemoteServerMode : function () { }
# };
# }
# </script>
# <span id="req_info" style="display:none;">204727,195650,205682,206395,203107,200864,204536,203303,204321,199447,200087,202861,202861|2,196662,205512,203290,206373,205232,185503,206395|1</span>
# </body>
# </html>

# %% [markdown]
# ## BeautifulSoup 簡介
#
# ### BeautifulSoup函式庫的名字取自Lewis Carroll在「Alice's Adventures in Wonderland」裡的同名詩歌，函式庫的功能就和詩歌一樣，嘗試化平淡為神奇。他通過定位HTML標籤來格式化和組織複雜的網路訊息，用簡單易用的Python語言來已存取XML的方式來存取HTML。
#
#
# ### BeautifulSoup提供一些簡單的、python式的函數用來處理導航、搜索、修改分析樹等功能。它是一個工具箱，通過解析文檔為用戶提供需要抓取的數據，因為簡單，所以不需要多少代碼就可以寫出一個完整的應用程序。
#
# ### BeautifulSoup自動將輸入文檔轉換為Unicode編碼，輸出文檔轉換為utf-8編碼。你不需要考慮編碼方式，除非文檔沒有指定一個編碼方式，這時BeautifulSoup就不能自動識別編碼方式了。
#
# ### 然後，你僅僅需要說明一下原始編碼方式就可以了。BeautifulSoup已成為和lxml、html6lib一樣出色的python解釋器，為用戶靈活地提供不同的解析策略或強勁的速度。
#
#
# ###  解析器                 使用方法                 優勢
# ###  html.parser       BeautifulSoup(markup, “html.parser”)          Python的內置標準庫
# ###  lxml                   BeautifulSoup(markup, “html.parser”)          速度快
# ###  xml                    BeautifulSoup(markup, “xml”)                       唯一支持XML的解析器
# ###  html5lib            BeautifulSoup(markup, “html5lib”)	              以瀏覽器的方式解析文檔
#
#
#
# ### 由於BeautifulSoup不是Python內建的標準函式庫，所以需要再額外安裝
# ### 下載網址如右 https://pypi.python.org/pypi/beautifulsoup4
# ###  如果有安裝pip套件管理器，則可以下指令 pip install beautifulsoup4 來安裝函式庫。
#
# ### 安裝完成後可以在python裡執行右側敘述 from bs4 import BeautifulSoup ，如果沒有出現錯誤，就代表安裝成功了。

# %% [markdown]
# ## 下半段開始使用BeautifulSoup來解析定址網頁原始碼
#
# ### 先把網頁的原始碼建立成BeautifulSoup的物件。
# ### 選擇使用內建的html.parser來作為解析時的解釋器。

# %%
simple_page = BeautifulSoup(simple_page,"html.parser")

# %% [markdown]
# #### BeautifulSoup對象和它的tag節點都可以調用 prettify()方法，prettify()方法將Beautiful Soup的文檔樹格式化後以Unicode編碼輸出,每個XML/HTML標籤都獨占一行。

# %%
print(simple_page.prettify())
# Out:
# <!DOCTYPE html>
# <!--
# You know you could be getting paid to poke around in our code?
# We're hiring designers and developers to work in Amsterdam:
# http://www.workingatbooking.com/
# -->
# <!-- wdot-802 -->
# <html class="noJS b_chrome b_chrome_24 supports_inline-block supports_fontface " lang="zh-tw" prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# booking_com: http://ogp.me/ns/fb/booking_com#">
#  <head profile="http://a9.com/-/spec/opensearch/1.1/">
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <link data-main-css="1" href="http://t-ec.bstatic.com/static/css/main_ecv6.iq2/63ee9a2426982754104e88be7c2369323db9dfa1.css" rel="stylesheet"/>
#   <link href="http://t-ec.bstatic.com/static/css/main_exps_ecv6.iq2/83970d412a458c5c3c958a2b9dfc1f4ee4e1ee16.css" rel="stylesheet"/>
#   <link href="http://t-ec.bstatic.com/static/css/gprof_icons_ecv6.iq2/afa93bf7b3e8e7ddd51d5da0957769be80e321dd.css" rel="stylesheet"/>
#   <link href="http://s-ec.bstatic.com/static/css/hotel_base_ecv6.iq2/252f0dcb2dbf35a4940edad1c0b101f0f190080f.css" media="screen" rel="stylesheet" type="text/css"/>
#   <link href="http://s-ec.bstatic.com/static/css/hotel_experiments_ecv6.iq2/6a502a4b0b788374b0b8a1b0eeb0015b3aa5dc5a.css" media="screen" rel="stylesheet" type="text/css"/>
#   <link href="http://t-ec.bstatic.com/static/css/reviews_standalone_ecv6.iq2/5b328b95d5cda2a78f935a1f20a6f43998ddb0f4.css" media="screen" rel="stylesheet" type="text/css"/>
#   <!--[if IE 9]> <link rel="stylesheet" href="http://t-ec.bstatic.com/static/css/ie9lte/883f9ea1c58a3c3f440b17d92b198ae72c8ecb80.css" media="screen" /> <![endif]-->
#   <!--[if IE 8]> <link rel="stylesheet" href="http://t-ec.bstatic.com/static/css/ie8lte_bundle/9fa138da41d7fc0649d893032c8714aea5a8dc3a.css" media="screen" /> <![endif]-->
#   <!--[if IE 7]> <link rel="stylesheet" href="http://t-ec.bstatic.com/static/css/ie7lte_bundle/429229365051802e0100c327150eab66a29f9adf.css" media="screen" /> <![endif]-->
#   <style>
#    #basiclayout { margin: 0px 0 0 0; } .breadcrumb { padding-left:7px; } #special_actions { margin: 3px 15px 3px 0; } .ticker_space { margin-top: 3px !important; } #logo_no_globe_new_logo { top: 14px; } .b_msie_6 #top, .b_msie_6 body.header_reshuffle #top {height:61px !important;} .b_msie_6 #special_actions { margin: 3px 15px 3px 0; overflow:visible; } body.header_reshuffle #top { min-height: 50px !important; height: 50px !important; } .nobg { background: #fff url("http://t-ec.bstatic.com/static/img/nobg_all_blue/85a874c5ee518d80b2ec6025d2a8379511a72172.png") repeat-x; background-image: url("http://t-ec.bstatic.com/static/img/nobg_all_blue_iq/b700d9e3067c1186a3364012df4fe1c48ae6da44.png"); background-position: 0 -50px; }
#   </style>
#   <link href="http://s-ec.bstatic.com/static/css/cjk/692ef46a0fea731d9c8dd350eac353cba65e1133.css" rel="stylesheet"/>
#   <link href="http://s-ec.bstatic.com/static/css/iq_overrides_ecv6/66e0615fb87fae0ac310d6b3e230a6fb62175a4c.css" rel="stylesheet" type="text/css"/>
#   <script>
#    if( window.performance && performance.measure && 'b-stylesheets') { performance.measure('b-stylesheets'); }
#   </script>
#   <meta content="index,follow" name="robots"/>
#   <link href="http://www.booking.com/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.zh-tw.html" rel="canonical"/>
#   <meta content="367003839" name="twitter:app:id:iphone"/>
#   <meta content="Booking.com Hotel Reservations Worldwide &amp; Hotel Deals" name="twitter:app:name:ipad"/>
#   <meta content="367003839" name="twitter:app:id:ipad"/>
#   <meta content="Booking.com Hotel Reservations" name="twitter:app:name:googleplay"/>
#   <meta content="com.booking" name="twitter:app:id:googleplay"/>
#   <meta content="367003839" property="al:ios:app_store_id">
#    <meta content="Booking.com Hotel Reservations" property="al:ios:app_name">
#     <meta content="Booking.com Hotel Reservation" property="al:android:app_name">
#      <meta content="com.booking" property="al:android:package">
#       <meta content="ff7f0b90ebb93e5bf7c7cafe77640ec1" name="p:domain_verify"/>
#       <meta content="zh-tw" http-equiv="content-language"/>
#       <meta content="text/javascript" http-equiv="content-script-type"/>
#       <meta content="text/css" http-equiv="content-style-type"/>
#       <meta content="_top" http-equiv="window-target"/>
#       <meta content="48970bbca45d28c2" property="wb:webmaster"/>
#       <meta content="summary_large_image" name="twitter:card">
#        <meta content="@bookingcom" name="twitter:site">
#         <meta content="@bookingcom" name="twitter:creator">
#          <meta content="http://s-ec.bstatic.com/static/img/twitter-image-else/566c7081f1deeaca39957e96365c3908f83b95af.jpg" name="twitter:image">
#           <meta content="Booking.com: 最豐富的飯店、民宿及度假住所選擇" name="twitter:title">
#            <meta content="不論您預訂的是飯店、民宿或度假住所，訂房保證最低價！快來我們的網站瀏覽超過 85,000 個目的地的  間住宿選擇。" name="twitter:description">
#             <meta content="company" property="og:type"/>
#             <meta content="Booking.com: 最豐富的飯店、民宿及度假住所選擇" property="og:title"/>
#             <meta content="http://t-ec.bstatic.com/static/img/facebook-image-else/566c7081f1deeaca39957e96365c3908f83b95af.jpg" property="og:image"/>
#             <meta content="不論您預訂的是飯店、民宿或度假住所，訂房保證最低價！快來我們的網站瀏覽超過 85,000 個目的地的  間住宿選擇。" property="og:description"/>
#             <meta content="zh-tw" property="og:locale"/>
#             <meta content="http://www.booking.com/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.zh-tw.html" property="og:url"/>
#             <meta content="Booking.com" property="og:site_name"/>
#             <meta content="145362478954725" property="fb:app_id"/>
#             <link href="http://www.booking.com/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.en-gb.html" hreflang="en-gb" rel="alternate" title="English (UK)" type="text/html"/>
#             <link href="http://www.booking.com/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.html" hreflang="en-us" rel="alternate" title="English (US)" type="text/html"/>
#             <link href="http://www.booking.com/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.ja.html" hreflang="ja" rel="alternate" title="日本語" type="text/html"/>
#             <link href="http://www.booking.com/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.zh-cn.html" hreflang="zh-cn" rel="alternate" title="简体中文" type="text/html"/>
#             <link href="http://www.booking.com/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.zh-tw.html" hreflang="zh-tw" rel="alternate" title="繁體中文" type="text/html"/>
#             <link href="http://www.booking.com/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.ko.html" hreflang="ko" rel="alternate" title="한국어" type="text/html"/>
#             <link href="http://s-ec.bstatic.com/static/img/b25logo/favicon/ebc77706da3aae4aee7b05dadf182390f0d26d11.ico" rel="shortcut icon"/>
#             <link href="http://t-ec.bstatic.com/static/img/apple-touch-icon/c9b35bf29a75cac2f430f80a5d4bc7fd961d21a7.png" rel="apple-touch-icon"/>
#             <link href="/faq.zh-tw.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;" rel="help"/>
#             <link href="http://t-ec.bstatic.com/static/opensearch/zh-tw/debbe66f64fc96062ab17e891ece73c79727c0d7.xml" rel="search" title="Booking.com網路飯店訂房" type="application/opensearchdescription+xml"/>
#             <link href="https://plus.google.com/105443419075154950489" rel="publisher"/>
#             <script>
#              /*
# */
# (function avoidingXSSviaLocationHash() {
# var location = window.location,
# hash = location.hash,
# xss = /[<>'"]/;
# if (
# xss.test( decodeURIComponent( hash ) ) ||
# xss.test( hash )
# ) {
# location.hash = '';
# }
# })();
# document.documentElement.className = document.documentElement.className.replace('noJS', '') + ' hasJS';
# var sNSExperiments = 'experiments',
# sNSStartup = 'startup',
# sNSExperimentsLoad = 'experiments_load',
# sNSStartupLoad = 'startup_load';
# var b_experiments = {}, WIDTH, B = window.booking = {
# _onfly: [], // "on the fly" functions, will be executed as soon as external js files were loaded
# track: {
# queue: [],
# exp: function(value){
# if(!value) { return false; }
# this.queue.push(value);
# }
# },
# devTools: {
# trackedExperiments: []
# },
# user: {
# },
# env : {
# "b_gtt": 'dLYAeZFVJfNTBdAHUdPcUJBXVJfcbWYZedVWPFXO',
# "b_action" : 'reviews_hotel',
# "b_secure_domain" : 'https://secure.booking.com',
# "b_site_type" : 'www',
# "b_site_type_id": '1',
# "b_query_params_with_lang_no_ext": '?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554',
# "b_query_params_with_lang_no_ext_enforce_lang_aid_currency": '?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;lang=zh-tw;aid=397642;selected_currency=TWD',
# "b_calendar2" : '1',
# /*
# */
# "b_partner_channel_id": '17',
# "b_bookings_owned": '1',
# "b_real_action" : 'reviews_hotel',
# "b_google_maps_key_params" : 'key=ABQIAAAAEG168dBcRndNV70R9mDglhSZn_smZpFKc3SoS1v7FyDshy3QMxSgeH0qWTH24Gc7je-iJ9DSXiNmcA&amp;client=gme-booking&indexing=true',
# "b_lang" : 'zh',
# "b_has_valid_dates": '',
# "b_countrycode" : 'tw',
# "b_guest_country" : 'tw',
# "b_locale" : 'zh-tw',
# "date_format_locale" : 'DDD, DD MMMM YYYY',
# "b_lang_for_url" : 'zh-tw',
# "b_this_urchin" : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.zh-tw.html?label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo&amp;customer_type=total&amp;hp_nav=0&amp;order=featuredreviews&amp;page=1&amp;r_lang=zh-tw&amp;rows=75&&amp;',
# "b_flag_to_suggest" : 'tw',
# "b_companyname" : 'Booking.com',
# b_date_format: {"from_month_with_year":"自 {full_year} {month_name_from}","date_without_year":"{month_name} {day_of_month} 日","date_with_weekday_time_from":"{full_year} 年 {begin_marker}{month_name} {day_of_month} 日{end_marker}，{weekday}（{time} 起）","date_with_weekday_time_until":"{full_year} 年 {begin_marker}{month_name} {day_of_month} 日{end_marker}，{weekday}（{time} 前）","short_month_only":"{short_month_name}","month_with_year":"{full_year} 年 {month_name_with_year_only}","short_date_with_weekday_without_year":"{short_month_name} {day_of_month} 日（{short_weekday}）","date_with_short_weekday_with_year":"{full_year} 年 {month_name} {day_of_month} 日{short_weekday}","numeric_date_range_both_years":"{full_year}/{month}/{day_of_month}－{full_year_until}/{month_until}/{day_of_month_until}","date_with_weekday_to":"{full_year} 年 {month_name_to} {day_of_month} 日（{weekday_to}）","day_of_month_only":"{day_of_month}","numeric_date":"{full_year}/{num_month}/{day_of_month}","date_with_short_weekday_without_year":"{month_name} {day_of_month} 日{short_weekday}","short_date":"{full_year} 年 {short_month_name} {day_of_month} 日","long_date_range_both_years":"{full_year} 年 {month_name} {day_of_month} 日 － {full_year_until} 年 {day_of_month_until} {month_name_until} 日","in_month_with_year":"於 {full_year} {month_name_in}","date_with_weekday":"{full_year} 年 {month_name} {day_of_month} 日（{weekday}）","numeric_date_range":"{month}/{day_of_month}－{month_until}/{day_of_month_until}","short_date_without_year_range":"{short_month_name} {day_of_month} 日 - {short_month_name_until} {day_of_month_until} 日","range_from_long_date_time_until_long_date_time":"自 {full_year} 年 {month_name} {day_of_month} 日 {time} 至 {full_year_until} 年{month_name_until}   {day_of_month_until} 日 {time_until}","short_weekday_only":"{short_weekday}","short_month_with_year":"{full_year} 年 {short_month_name}","month_name_only":"{month_name_nom}","short_date_with_weekday":"{full_year} 年 {short_month_name} {day_of_month} 日（{short_weekday}）","short_date_without_year":"{short_month_name} {day_of_month} 日","date_with_year":"{full_year} 年 {month_name} {day_of_month} 日","date_with_weekday_with_markers":"{full_year} 年 {begin_marker}{short_month_name} {day_of_month} 日{end_marker} {weekday}","date_with_weekday_from":"{full_year} 年 {month_name_from} {day_of_month} 日（{weekday_from}）"},
# b_month_for_formatted_date: {"5":{"name_to":"5 月","name_only":"5 月","name_from":"5 月","name":"5 月","short_name":"5 月","name_with_year_only":"5 月","name_in":"5 月"},"4":{"name_to":"4 月","name_only":"4 月","name_from":"4 月","name":"4 月","short_name":"4 月","name_with_year_only":"4 月","name_in":"4 月"},"1":{"name_to":"1 月","name_only":"1 月","name_from":"1 月","name":"1 月","short_name":"1 月","name_with_year_only":"1 月","name_in":"1 月"},"11":{"name_to":"11 月","name_only":"11 月","name_from":"11 月","name":"11 月","short_name":"11 月","name_with_year_only":"11 月","name_in":"11 月"},"8":{"name_to":"8 月","name_only":"8 月","name_from":"8 月","name":"8 月","short_name":"8 月","name_with_year_only":"8 月","name_in":"8 月"},"3":{"name_to":"3 月","name_only":"3 月","name_from":"3 月","name":"3 月","short_name":"3 月","name_with_year_only":"3 月","name_in":"3 月"},"6":{"name_to":"6 月","name_only":"6 月","name_from":"6 月","name":"6 月","short_name":"6 月","name_with_year_only":"6 月","name_in":"6 月"},"7":{"name_to":"7 月","name_only":"7 月","name_from":"7 月","name":"7 月","short_name":"7 月","name_with_year_only":"7 月","name_in":"7 月"},"9":{"name_to":"9 月","name_only":"9 月","name_from":"9 月","name":"9 月","short_name":"9 月","name_with_year_only":"9 月","name_in":"9 月"},"10":{"name_to":"10 月","name_only":"10 月","name_from":"10 月","name":"10 月","short_name":"10 月","name_with_year_only":"10 月","name_in":"10 月"},"2":{"name_to":"2 月","name_only":"2 月","name_from":"2 月","name":"2 月","short_name":"2 月","name_with_year_only":"2 月","name_in":"2 月"},"12":{"name_to":"12 月","name_only":"12 月","name_from":"12 月","name":"12 月","short_name":"12 月","name_with_year_only":"12 月","name_in":"12 月"}},
# b_weekday_formatted_date: {"2":{"short":"週二","name_to":"星期二","name_from":"星期二","name":"星期二","shortest":"週二"},"3":{"short":"週三","name_to":"星期三","name_from":"星期三","name":"星期三","shortest":"週三"},"4":{"short":"週四","name_to":"星期四","name_from":"星期四","name":"星期四","shortest":"週四"},"7":{"short":"週日","name_to":"星期日","name_from":"星期日","name":"星期日","shortest":"週日"},"6":{"short":"週六","name_to":"星期六","name_from":"星期六","name":"星期六","shortest":"週六"},"1":{"short":"週一","name_to":"星期一","name_from":"星期一","name":"星期一","shortest":"週一"},"5":{"short":"週五","name_to":"星期五","name_from":"星期五","name":"星期五","shortest":"週五"}},
# b_time_format: {"PM_symbol":{"name":"PM"},"AM_symbol":{"name":"AM"},"time":{"name":"{hour_24h}:{minutes}"}},
# "b_protocol": 'http',
# auth_level : "0",
# b_user_auth_level_is_none : 1,
# b_run_redirect_from_app_to_book_for_login: 1,
# b_login_page_url: 'https://secure.booking.com/mysettings.zh-tw.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;aru=http%3A%2F%2Fwww.booking.com%2Freviews%2Ftw%2Fhotel%2Ftai-bei-fa-xian-qing-lu.zh-tw.html%3Faid%3D397642%3Blabel%3Dgog235jc-index-XX-XX-XX-unspec-tw-com-L%253Axt-O%253Aabn-B%253Aunk-N%253Ayes-S%253Abo-U%253Asalo%3Bsid%3D83349c9f35261a2ee9abd0d1c30202bc',
# bb: {
# ibb: "",
# uibb: "",
# ibbta: "",
# itp: "0",
# iuibb: "",
# bme: "",
# euibb: "0",
# tp: "0"
# },
# b_growls_close_fast: 1,
# asyncLoader: {
# empty: ''
# },
# b_email_validation_regex : /^([\w-\.\+]+@([\w-]+\.)+[\w-]{2,14})?$/,
# b_domain_end : '.booking.com',
# b_original_url : 'http:&#47;&#47;www.booking.com&#47;reviews&#47;tw&#47;hotel&#47;tai-bei-fa-xian-qing-lu.zh-tw.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=83349c9f35261a2ee9abd0d1c30202bc',
# b_this_url : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.zh-tw.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&',
# b_this_url_without_lang : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&',
# b_switch_language_url : {
# 'en-gb' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.en-gb.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=en-gb',
# 'en-us' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.en-us.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=en-us',
# 'de' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.de.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=de',
# 'nl' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.nl.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=nl',
# 'fr' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.fr.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=fr',
# 'es' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.es.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=es',
# 'es-ar' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.es-ar.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=es-ar',
# 'ca' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.ca.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=ca',
# 'it' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.it.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=it',
# 'pt-pt' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.pt-pt.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=pt-pt',
# 'pt-br' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.pt-br.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=pt-br',
# 'no' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.no.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=no',
# 'fi' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.fi.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=fi',
# 'sv' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.sv.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=sv',
# 'da' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.da.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=da',
# 'cs' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.cs.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=cs',
# 'hu' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.hu.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=hu',
# 'ro' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.ro.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=ro',
# 'ja' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.ja.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=ja',
# 'zh-cn' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.zh-cn.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=zh-cn',
# 'zh-tw' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.zh-tw.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=zh-tw',
# 'pl' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.pl.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=pl',
# 'el' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.el.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=el',
# 'ru' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.ru.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=ru',
# 'tr' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.tr.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=tr',
# 'bg' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.bg.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=bg',
# 'ar' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.ar.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=ar',
# 'ko' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.ko.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=ko',
# 'he' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.he.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=he',
# 'lv' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.lv.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=lv',
# 'uk' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.uk.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=uk',
# 'id' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.id.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=id',
# 'ms' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.ms.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=ms',
# 'th' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.th.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=th',
# 'et' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.et.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=et',
# 'hr' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.hr.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=hr',
# 'lt' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.lt.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=lt',
# 'sk' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.sk.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=sk',
# 'sr' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.sr.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=sr',
# 'sl' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.sl.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=sl',
# 'vi' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.vi.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=vi',
# 'tl' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.tl.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=tl',
# 'is' : '/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.is.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&;lang=is'
# },
# b_referrer : '',
# b_acc_type : '',
# b_req_login: '',
# jst : {'loading': true},
# keep_day_month: true,
# b_timestamp : 1487156599,
# referal_tab: true,
# scripts_tracking : {
# },
# enable_scripts_tracking : 1,
# b_ufi : '-2637882',
# "setvar_affiliate_is_bookings2" : 1,
# transl_close_x : '关闭',
# transl_checkin_title: '入住日期',
# transl_checkout_title: '退房日期',
# browser_lang: '',
# b_lang_is_cjk: true,
# b_hijri_calendar_available: false,
# b_aid: '397642',
# b_label: 'gog235jc-index-XX-XX-XX-unspec-tw-com-L:xt-O:abn-B:unk-N:yes-S:bo-U:salo',
# b_sid: 'a69dc815b256b32729409bba84f65554',
# ip_country: 'tw',
# country_currency: 'TWD',
# b_selected_currency: 'TWD',
# b_selected_language: 'zh-tw',
# pageview_id: '5b5c4dbbaa1202a3',
# aid: '397642',
# b_csrf_token: 't22kWAAAAAA=O9IjX3pikqDJvJQ5vDvlarNYJuJOlUHoXuUhNzLGcaG5m4ebKVntuOUl0dWFmS7FRvU5U3BUnzDh4MaKZjdrY7rq2fZGKupw5nKwRQeqXl829bfCBVOuUZJTzPFjqOHKhI6byBGRIkpfWRvU5LoGPSD85EYkO6w5H5YS-nITii5yhdmkamZgCtvMHd8',
# b_show_user_accounts_features: 1,
# b_browser: 'chrome',
# b_browser_version: '24',
# b_run_loc_ce_update_timer_v2: true,
# et_debug_level: '0',
# et_deprecation_warnings: false,
# icons: '/static/img',
# b_static_images: 'http://t-ec.bstatic.com/images/',
# b_currency_url: '/general.zh-tw.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;tmpl=currency_foldout;cur_currency=TWD;cc1=tw',
# b_languages_url: '/general.zh-tw.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;tmpl=language_foldout',
# b_weekdays: [
# {"b_is_weekend": parseInt( '' ),
# "b_number": parseInt('1'),
# "name": '星期一',
# "short": '週一',
# "shorter": '週一',
# "shortest": '週一'},
# {"b_is_weekend": parseInt( '' ),
# "b_number": parseInt('2'),
# "name": '星期二',
# "short": '週二',
# "shorter": '週二',
# "shortest": '週二'},
# {"b_is_weekend": parseInt( '' ),
# "b_number": parseInt('3'),
# "name": '星期三',
# "short": '週三',
# "shorter": '週三',
# "shortest": '週三'},
# {"b_is_weekend": parseInt( '' ),
# "b_number": parseInt('4'),
# "name": '星期四',
# "short": '週四',
# "shorter": '週四',
# "shortest": '週四'},
# {"b_is_weekend": parseInt( '' ),
# "b_number": parseInt('5'),
# "name": '星期五',
# "short": '週五',
# "shorter": '週五',
# "shortest": '週五'},
# {"b_is_weekend": parseInt( '1' ),
# "b_number": parseInt('6'),
# "name": '星期六',
# "short": '週六',
# "shorter": '週六',
# "shortest": '週六'},
# {"b_is_weekend": parseInt( '1' ),
# "b_number": parseInt('7'),
# "name": '星期日',
# "short": '週日',
# "shorter": '週日',
# "shortest": '週日'},
# {}],
# b_group: [],
# b_simple_weekdays: ['週一','週二','週三','週四','週五','週六','週日'],
# b_simple_weekdays_for_js: ['週一','週二','週三','週四','週五','週六','週日'],
# b_long_weekdays: ['星期一','星期二','星期三','星期四','星期五','星期六','星期日'],
# b_short_months: ['1 月','2 月','3 月','4 月','5 月','6 月','7 月','8 月','9 月','10 月','11 月','12 月'],
# b_short_months_abbr: ['1 月','2 月','3 月','4 月','5 月','6 月','7 月','8 月','9 月','10 月','11 月','12 月'],
# b_year_months: {
# '2017-2': {'name': '2017 年 2 月' },
# '2017-3': {'name': '2017 年 3 月' },
# '2017-4': {'name': '2017 年 4 月' },
# '2017-5': {'name': '2017 年 5 月' },
# '2017-6': {'name': '2017 年 6 月' },
# '2017-7': {'name': '2017 年 7 月' },
# '2017-8': {'name': '2017 年 8 月' },
# '2017-9': {'name': '2017 年 9 月' },
# '2017-10': {'name': '2017 年 10 月' },
# '2017-11': {'name': '2017 年 11 月' },
# '2017-12': {'name': '2017 年 12 月' },
# '2018-1': {'name': '2018 年 1 月' },
# '2018-2': {'name': '2018 年 2 月' },
# '2018-3': {'name': '2018 年 3 月' },
# '2018-4': {'name': '2018 年 4 月' },
# '2018-5': {'name': '2018 年 5 月' }
# },
# b_is_landing : 1,
# b_user_auth_level_is_none: 1,
# b_is_fb_safe: 1,
# b_is_app: 1,
# first_page_of_results: true,
# b_partner_id: '488150',
# b_is_destination_finder_supported: 1,
# b_is_dsf: 0,
# b_pr_param: '',
# /*
# */
# hotelAction: {
# showReviews: parseInt("503", 10),
# minReviews: parseInt("5", 10),
# hotelName: "tai-bei-fa-xian-qing-lu",
# pageLang: "zh-tw",
# hotelCountry: "tw"
# },
# inandaround_more: "更多",
# b_signup_iframe_url: 'https://secure.booking.com' + '/login.html?tmpl=profile/signup_after_subscribe' + '&lang=zh-tw' ,
# b_exclude_lang_firstname: 0,
# view_prices_enter_dates: '請輸入日期以查看房價和空房情況。',
# autocomplete_categories: {
# city: '城市',
# region: '區域',
# airport: '機場',
# hotel: '飯店',
# landmark: '地標',
# country: '國家',
# district: '區',
# theme: '主題'
# },
# autocomplete_skip_suggestions: '搜尋更多選項',
# autocomplete_counter_label: '附近的飯店',
# autocomplete : {
# property_nearby: '家附近的飯店',
# properties_nearby: '家附近的飯店',
# hotel: '住宿',
# hotels: '住宿',
# hotels_nearby: '附近的飯店'
# },
# lists: {
# collection: [
# {
# id: "0",
# name: "我的旅行口袋",
# hotels_count: "0"
# }
# ]
# },
# touch_os: false,
# calendar_days_allowed_number: 350,
# b_search_max_months: 16,
# b_password_strength_msg: ['長度不夠','弱','一般','良好','強','很強'],
# b_passwd_min_length_error: '密碼至少需要8個字符',
# b_password_must_be_numeric: '預訂密碼應為 4 位數字，請重新輸入。',
# b_bkng_nr_must_be_numeric: '訂單編號應為 9 位數字，請重新輸入。',
# b_blank_numeric_pin: '請輸入您的預訂密碼。',
# b_blank_bkng_nr: '請輸入您的訂單編號。',
# password_cant_be_username: '您的密碼不能與郵箱地址相同',
# b_show_passwd: '查看密碼',
# b_passwd_tooltip: '請以大寫字母、特別字符和數字設定密碼以增強密碼安全性',
# account_error_add_password: '請新增密碼',
# password_needs_8: '密碼至少需要8個字符',
# error_sign_up_password_email_combo_01: '請檢查您的電子郵件地址或密碼並重新嘗試。',
# social_plugins_footer: 1,
# b_site_experiment_lazy_load_print_css: 1,
# print_css_href: 'http://t-ec.bstatic.com/static/css/print/8482b8c447a826a23a70d47152c4e86e9f4a5438.css',
# b_hostname_signup: "www.booking.com",
# b_nonsecure_hostname: "http://www.booking.com",
# b_nonsecure_hostname_signup: "http://www.booking.com",
# b_fd_searchresults_url_signup: "",
# translation_customer_service_which_booking_no_specific: '不針對某項預訂',
# stored_past_and_upcoming_bookings: [
# ],
# global_translation_tags: {"rlm":"\u200f","nbsp":"&nbsp;","lrm":"\u200e","line_break":"\u003cbr\u003e"},
# b_photo_pid: (488150).toString(),
# b_wishlist_referrer : '',
# b_reg_user_last_used_wishlist: "",
# b_reg_user_wishlist_remaining: 1,
# is_user_center_bar: 1,
# b_site_experiment_user_center_bar: 1,
# b_reg_user_is_genius : "",
# 'social-connect': [
# {
# state: "",
# provider: "facebook"
# }
# ,
# {
# state: "",
# provider: "google"
# }
# ],
# b_run_social_connect: 1,
# profile_menu: {
# b_site_info: {"is_bookings_owned":1},
# b_site_type: "www",
# b_companyname: "Booking.com",
# b_is_genius_branded: "0",
# b_reg_user_is_genius: "",
# b_genius_dashboard_expiry_destfinder_url: "http://www.booking.com/destinationfinderdeals.zh-tw.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;genius_deals_mode=1&genius_next_weekend=1",
# b_run_bb_pb_reports: "",
# b_reg_user_last_used_wishlist: "",
# b_ge_num_stays: "",
# b_ge_num_stays_left: "",
# b_genius_product_page_url: "http://www.booking.com/genius.zh-tw.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554",
# b_ge_aspiring_profile_menu: "",
# b_ge_aspiring_profile_menu_for_all: "",
# b_ge_is_aspiring_genius_for_all: "",
# b_reg_user_qualify_genius_challenge: "",
# b_reg_user_five_bookings_challenge: "",
# b_ge_is_aspiring_genius: "",
# b_ge_reg_user_personal_details: "",
# b_is_bbtool_admin: "",
# b_is_bbtool_user: "",
# fe_bbtool_permission_can_use_generic_bbtool_features: "",
# fe_bbtool_permission_can_use_admin_bbtool_features: "",
# fe_bbtool_permission_can_use_only_booker_bbtool_features: "",
# fe_bbtool_permission_is_connected_to_bbtool: "",
# fe_bbtool_can_see_tool_promos: "1",
# fe_bbtool_blackout_user: "",
# fe_bbtool_blackout_user_company: "",
# b_reg_user_company_name: "",
# b_reg_user_company_name_escaped: "",
# b_reg_user_companyjoin_url: "",
# b_bbtool_product_page_url: "http://www.booking.com/business.zh-tw.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;stid=934592",
# b_is_ie7: "",
# b_this_url: "/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.zh-tw.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75&",
# b_lang_for_url: "zh-tw",
# b_is_villa_site: 0,
# b_secure_hostname: "https://secure.booking.com",
# b_nonsecure_hostname: "http://www.booking.com",
# b_query_params_with_lang: ".zh-tw.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554",
# b_query_params_delimiter: ";",
# b_reg_user_detail_dashboard_url: "",
# b_is_reg_user_city_guide_in_lang_available: "0",
# b_reg_user_aspiring_data: "",
# b_dummy_var_for_trailing_comma: false,
# b_ip_country: "tw",
# b_guest_country: "tw",
# b_raf_multiple_campaigns: true,
# b_agent_is_no_robot: "1",
# b_page_name : "reviews_hotel",
# b_landingpage_theme_type: "",
# b_messaging_available: "",
# b_messaging_url: "",
# b_messaging_entry_point_data_config: "\n\n",
# },
# accounting_config: {"decimal_separator":{"default":"."},"symbol_position":{"default":"before","CZK":"after","RON":"after","PLN":"after"},"currency_separator":{"default":"&nbsp;","JPY":"","GBP":"","USD":""},"group_separator":{"default":","},"num_decimals":{"XPF":"0","TWD":"0","CLP":"0","BHD":"3","MGA":"0","IDR":"0","VND":"0","IQD":"3","TND":"3","KMF":"0","HUF":"0","OMR":"3","RUB":"0","MZM":"0","LYD":"3","TMM":"0","XOF":"0","JPY":"0","PYG":"0","KWD":"3","BYR":"0","DJF":"0","JOD":"3","ISK":"0","GNF":"0","ECS":"0","COP":"0","VUV":"0","UGX":"0","KRW":"0","LAK":"0","AFA":"0","TJR":"0","default":2,"BIF":"0","RWF":"0","XAF":"0"},"html_symbol":{"PLN":"z&#x0142;","RON":"lei","SGD":"S$","HKD":"HK$","BRL":"R$","CZK":"K&#269;","IDR":"Rp","GBP":"&#163;","JPY":"&#165;","TRY":"TL","ARS":"AR$","EUR":"&#x20AC;","CLP":"CL$","USD":"US$","INR":"Rs.","ILS":"&#x20AA;"}},
# distance_config: "metric",
# b_run_tfl_move_away_from_lightbox: true,
# b_wishlist_singlepage_url: 'https://secure.booking.com/mywishlist.zh-tw.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554',
# is_listview_page: true,
# b_this_weekend_checkin: "",
# b_this_weekend_checkout: "",
# b_next_weekend_checkin: "",
# b_next_weekend_checkout: "",
# b_official_continent: "",
# b_deals_continents : "",
# b_condition_login_with_bn_pin: 1,
# b_site_experiment_login_with_bn_pin: 1,
# b_is_villa_site : 0,
# b_messenger_url: '',
# b_open_messenger: false,
# b_extra_ajax_headers: {},
# b_run_loc_ce_update_timer_v2: true,
# et_debug_level: '0',
# et_deprecation_warnings: false,
# trackExperiment : function () {},
# "error" : {}
# },
# ensureNamespaceExists: function (namespaceString) {
# if (!booking[namespaceString]) {
# booking[namespaceString] = {};
# }
# }, hotel: {}, experiments: {}, startup: {}, experiments_load: {}, startup_load: {}, promotions: {}, timestamp: new Date()};
# function Tip() {};
# (function (scope) {
# booking.env.b_sb_autocomplete_predictions_url = '/autocomplete_2';
# var params = scope.search_autocomplete_params = {};
# params.v = '1';
# params.lang = 'zh-tw';
# params.sid = 'a69dc815b256b32729409bba84f65554';
# params.aid = '397642';
# params.pid = '5b5c4dbbaa1202a3';
# params.stype = '1';
# params.src = 'reviews_hotel';
# params.eb = '4';
# params.e_obj_labels = '1';
# params.at = 1;
# params.e_tclm = 1;
# params.add_themes = '1';
# params.themes_match_start = '1';
# params.include_synonyms = '1';
# })(window.autocomplete_vars || booking.env);
#             </script>
#             <script>
#              var _gaq = _gaq || [];
#             </script>
#             <!--[if IE]> <script> document.createElement('time'); </script> <![endif]-->
#             <script>
#              booking.jset = {"f":{"ZCDSDVCXdUFDeTLbQVAHAbWTKe":1,"OLFYMZTUMKeacWXT":2,"ABbFTOTOOMSYeJBDdKIJRLT":1,"bPSELUXXRePeRBDYeFPbOGeNfRJbRWe":1,"VObLMOLSWFMfaADWe":1,"ZCDFGTOKTfGCfWfecNfdQHT":1,"adUdWHeQZbNLNIfNSBYHe":1,"eRQFFZVAGdSYO":1,"VObLMbNXGDJESWFMacWIVYCFaO":1,"adUdWHYZbIFOWGJNBZAKe":1,"VMKIbEXROEcMCdYIYdETfRdadYO":1,"BIUJLMJIYSaJRbAAPMNUJTKaT":1,"eDUfHbcGRcbQGWRVKaMUHXdRT":1,"fEDSFAHNXKeZKVUNHFAPTPWOGATNSeKdRe":2,"VMKIaYPMSJLdCbHe":1,"eIabKeVBSCOOSHJVYLCBRe":1,"cPJJWEEdJRIcOcNVBUKcKe":1,"BUZdfbGbEESLEcXO":1,"OMHBafWbBMRVDVfdBADWaO":1,"YdVPYKDcdDVfdBNeURJLNFET":1,"BUZdffQBRPXdAOVYJKMOKe":1,"fEJdDBKWeDORadYbeQMIbGNYO":1,"OMOLNYJKAaNCWQeFTZUFPIbYO":2,"ABbFTEOADNBdTZbJIIIKe":1,"VMKIbaeaNVTZHT":1,"bPSELSRSdVRPBfAJdcRAcIaTcDCXe":1,"PYNYeCIObTEcYWRbHJQPYQQZRO":1,"cQZKZJAQPeMFcDcQUAEXcGKCQMWUC":1,"VMKIbVSBBfFHZHT":1,"OMOQUQZWTNJGOaT":1,"ZOBUYLMcITDTbYFcYEHSUeKe":1,"ABbFCFbWeWGVeNBRUDfEQYKe":1,"BKbVZdEYaRBdMFPLT":1,"ZOCDMEOUNMdbDHT":1,"PNHafDcaRDPNZJQAZFO":1,"BUaWODTPZANUOcIScdMbSMATBWe":1,"ZOICXWVYDSfSLdXFNPIIaeaGVfQHO":1,"cPJJWfMOBcMdBfMPSXPKVXFC":1,"ZCDSWSLYDbRbWLKVHFO":1,"NAFQVaPEbBBcfFdHMdeUbLFcLJHO":1,"PYTbJAEcMEdaWNMcdBNTXT":1,"fESCFPNSAJSWXeLDDSC":1,"IZVEEJPVdEPeSMfbHJIYSaWe":1,"dddYIQFIMNWUSUSDRBdFO":1,"YPNBYbIGbUKZTFNefFHe":1,"PNFBfQYZPaIEHBEfIPPSfDcNeC":1,"AEJPMbHAcUVFccSTKe":1,"AEJPCCdQIXYQEBfKCGGORe":1,"VOaNPAJHOHRCTeMIRBPKJXIIKe":1,"ZOdQHYfBQWDVaKbYO":1,"VMKIaHPMSJLRJAXaaO":1,"ZCDSJIJUZIKGYBRAOAcEUC":1,"BIUJLMWeDfBAFFWeVQOSRKAZJScWcDaWe":1,"YPNOKFHMPfQDIbCNKBBO":1,"ZCRAOAcEUJfObCCKSFBIUJLMJIYSaJRKe":1,"AEJPVZMYCMTXbfRSGdePAZZbYHYO":1,"HMeTYUUPJeGdXbVAANLT":1,"OMZOOTVbCOaBdeUfBQWEeJHOWYO":1,"OMZOXTbdBcXOVIWSUPIHPcCJNbKBAcFASVVC":1,"eDdJFHBZYfefbEKSccdZWOJNET":1,"dddYIQFNSebRaTKBGfNaT":1,"adUAABYQKXSPDGXLMdSSHT":1,"bZWOXGBbLPNEVdZBAFQJIHTPBYHe":1,"NAZSNMGEfEDdWQUeWIbUWe":1,"TAeKPWPDSJMDERXDbEbeOWdCNKbdLOLOLMO":1,"adUAAKTVeBKeYEGHKRSLMJUALFLeSXT":1,"OMBUcJHcWCcdbLMaCffZFLWC":1,"PNcbdGBUHaZFdTPeeFGbFC":1,"eRYZYTEDUSANfYO":1,"ABbFTOTdfdPIHAEeUOHSeEDRVOZXQae":1,"OMOQZWKETBUADCLdaWeae":1,"eDUfHbcGRcbQGWRVKaMUPbHe":1,"NAZSNMGdRWSdSdceUPUUHVPHXe":1,"AEJPMbHAcUVFccSTfMPSXWe":1,"VOaNZTZIAESSIBaQcSdVLT":1,"ZCDRSLQKLKfPBDOQSGeFfTTKe":1,"OMOLcbGUEZGZdMIZDHTIYAZae":2,"PYJPOYJRHHaUC":1,"OMBUcFaRdMDAHae":2,"bQEafDeDFCJPUSOYVHFDAUTBaQDfBQJbLTJADUKe":1,"PYGYSOTOFZYHUC":1,"fEJdDBKDTBOPFBPFUZXeUZEUZC":1,"ebcNQKAENeNZdJOVBSbEQWe":1,"fESeCXYWLAMO":1,"cPJJFKeFbAcfWET":1,"ABcLYSIZDVLLITWWCQSLT":1,"AEJPELZHWEYZLPNMQMLZBRYLWcDaWe":1,"cQZVDZOKZdKNWYKe":1,"fESfMRaHVIWVZfC":1,"BfaLEXAGCBKC":1,"OMOQQBFNKPfOZZAWe":2,"PYTbdWGAMWXKYSSTMSBXe":1,"MKMBYNYScXQOVZbObSVHLeNBLLT":1,"ebcOQZWBbLOXNSZBeRe":1,"OMOQHNJFNWSJcCIOSCFGPfECIAaKLWe":1,"OMTLEKXJYINNPaGMYVVPBNaDSKKMfQcUNC":1,"OMaDUIFacYdEKfPBDORe":1,"bPSELVRNQcedZQXbLVReQMMfOROJGcYZVIXe":1,"eWRbceDTANZVCMILDDRNSTNSbZebYZTNSAJeRe":1,"OMZXVKZMSHUTYcbWTNFbUC":1,"VOGcZdZfAWQIAPPeae":1,"OMHBaOMZDBdZRO":1,"ebcOQPIHAdLVBHVJFWJcdHbFeKe":1,"adUAAMVZALOEaJPGAAQeccVT":1,"adUdWHOdDFIMNSdTFJZSdVT":1,"OMbLYAbZZBLQZDC":1,"cPWbVdBceEUVTZHT":2,"AEJPCCKdJMbfdSKfXFNHC":1,"PYNYYNRZYDTeRT":1,"TULQWXSaVbBdPdUVNFBNHC":1,"adUdWHYSdFYHDEFRYEFDVVGcVT":1,"TDXbdFSOefFYATKBTBTC":1,"IZVXOeFWFPWe":1,"OMNHJAWCZdTTXZabGMKZePPGKVT":1,"adUdWHYHNNNAcfQPVYLXC":1,"BIUJLMWeDfBAFGbJdZNVUIRe":1,"PYFGeNBLFEZeaPLeQETC":1,"ABbDSFLFNHDYEaNdNFKGbedJJYDYO":1,"TULQWPRVKaMUHSQFUUPXCYO":1,"BCOELUONCGVKe":2,"adUAVGPJceVccVeCIObTETZHT":1,"PNFOOTXGBUbRSdDaORe":1,"HMeOIEeUefJZPELBOXQDBae":1,"ZCDSSVCHCTeVeNBPOdCLSeRIdeYWe":1,"OMOQRWSENWMeAcKBTC":1,"ZCFRURURYNYeaHbEOTOCacWCcHVHYQC":1,"OMOLUBBCcMZLOAAPCBUKcC":1,"OMHBbOcYSRbKCBZAWe":1,"NVNUdBQMdIKGYBFbUFQLNHNfLae":1,"ZCWPDSDIDeQcJZbLcKTLO":1,"PNFOOTXGBUaRcBNSGffeTRe":1,"PNFBBUIDJGOGdBKe":1,"OMBUNGSEBVEHJebSXT":1,"cPWbVdMFHSUTIcMVNLdcJC":1,"OMNHJAWCZdTTXZabGMKWe":1,"ZOOCeLFdCQFOMOabBTKYbdfdaT":1,"OMHBbOcYaMDfDbfGYYT":1,"bHVNNSTUOIPNBdCMVZAeYAae":1,"OMGWCMcDWe":1,"OMOQJJSVHcOUfFZMfWe":1,"BIUJLMDPBJSGbHT":1,"OMebcOQPBRYZVXVFPWHT":1,"bHVNYTfGTJJGGZJARGPHBGDHT":1,"OMOQSTYRAQFZDDUZeEdaWYO":1,"HBbMWcaWOHVUL ...
# booking.jst = {"ZOMFJQPNLTLLCBRe":0,"beKMDNdEeKe":2,"HMeIFGKSGTaNFOeBDHC":1,"ZOOPRAFGKSGdeUabBeUNSIOYDMdbDHT":0,"eIBbFYLCBLFJYbVAGeMeIKEOYC":0,"AEJPVZMYCVLBQRWSEaEIVDaXe":0,"TAeKPWbVLBQScADDbdEScXQOVWe":0,"HSCQQOcZQPPeae":1,"deeXGKeePPZSeHT":1,"IZGNCAXZQAXVASOWKEOYC":1,"ZOTWOAZBEERFCUbLOLHT":0,"VMKIfaMNfWJfQYZPaXQC":1};
# booking.jsdt = {"HMeIFGKSGTaNFOeBDHC":1,"beKMDNdEeKe":2,"IZGNCAXZQAXVASOWKEOYC":1,"deeXGKeePPZSeHT":1,"HSCQQOcZQPPeae":1};
# booking.env.b_fragment_url_html = "/fragment.zh-tw.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554";
# booking.env.b_fragment_url_json = "/fragment.zh-tw.json?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554";
# booking.ensureNamespaceExists('affiliate');
# booking.affiliate.platform = {
# isHybrid: 0,
# isCobrand: 0
# };
# booking.affiliate.settings = {
# showSignUpPrompt: 0
# };
# booking.affiliate.variables = {
# userLoggedIn: 0
# };
# booking.affiliate.params = {
# destinationFinderSignUpPrompt: 0
# };
#             </script>
#             <title>
#              1057條青年旅舍真實住客點評 - Taipei Discovery Hostel - Booking.com
#             </title>
#             <meta content="閱讀 1057 則入住台北市「台北發現青旅」真實住客評語，Booking.com 顧客評分 9.2（滿分 10）。" name="description">
#              <link href="http://www.booking.com/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.zh-tw.html" rel="next"/>
#              <meta content="width=device-width, initial-scale=1, maximum-scale=2" name="viewport">
#              </meta>
#             </meta>
#            </meta>
#           </meta>
#          </meta>
#         </meta>
#        </meta>
#       </meta>
#      </meta>
#     </meta>
#    </meta>
#   </meta>
#  </head>
#  <body class="bookings2 b2 reviews_hotel zh lang_is_cjk header_reshuffle nobg user_center app_user_center b-sprite-3 lt bigblue_std_sm bigblue_std_lg arial_to_helvetica iconfont_is_loading reviews_new palette-1 " id="b2reviews_hotelPage">
#   <script>
#    (function(){
# 'use strict';
# var stats = window.ttiStats = {};
# var addListener = function (name, fn) {
# if ('addEventListener' in document) {
# document.addEventListener(name, fn);
# } else {
# document.attachEvent('on' + name, fn);
# }
# };
# var removeListener = function (name, fn) {
# if ('removeEventListener' in document) {
# document.removeEventListener(name, fn);
# } else {
# document.detachEvent('on' + name, fn);
# }
# };
# var baseTimeStamp = (new Date()).getTime();
# var onClick = function onClick() {
# stats.click = (new Date()).getTime() - baseTimeStamp;
# removeListener('click', onClick);
# };
# var onScroll = function onScroll() {
# stats.scroll = (new Date()).getTime() - baseTimeStamp;
# removeListener('scroll', onScroll);
# };
# addListener('click', onClick);
# addListener('scroll', onScroll);
# })();
#   </script>
#   <script type="text/javascript">
#    window.utag_data = {
# site: 'bookings2',
# stypeid: '1',
# action: 'reviews_hotel',
# crt: '1',
# trg: '0',
# fbp: '1',
# exp1: '',
# exp2: '0',
# alev: '0',
# atid: '',
# atnm: '',
# biz_s: '0',
# biz_p: '',
# bo: '1',
# browser: 'chrome',
# browser_ver: '24',
# bstage: '',
# clkid: '',
# emksho: '1',
# genis: '',
# genasp: '',
# n_b: '',
# sid: 'a69dc815b256b32729409bba84f65554',
# ui: '',
# hotel_name: '台北發現青旅',
# channel_id: '',
# partner_id: '',
# ai: '',
# adults: '',
# book_window: '',
# children: '',
# district_name: '',
# city_name: '',
# region_name: '',
# country_name: '',
# currency: '',
# date_in: '',
# date_out: '',
# dayofwk: '',
# depth: '',
# dest_type: '',
# dest_id: '',
# dest_cc: '',
# dest_ufi: '',
# dest_name: '',
# hotel_count: '',
# hotel_id: '',
# hotel_id_list: '',
# hr: '',
# i1: '',
# i2: '',
# i3: '',
# isfd: '',
# isnl: '',
# label: '',
# language: '',
# logged_in: '',
# nights: '',
# cv: '',
# ordv: '',
# rooms: '',
# seed: '',
# srord: '',
# sub: '',
# ui_a: '',
# user_location: '',
# wkend: '',
# q1: ''
# };
# (function(a,b,c,d){
# var w = window || {};
# function loadTagContainer(){
# a='//tags.tiqcdn.com/utag/booking.com/main/prod/utag.js';
# b=document;c='script';d=b.createElement(c);d.src=a;d.type='text/java'+c;d.async=true;
# a=b.getElementsByTagName(c)[0];a.parentNode.insertBefore(d,a);
# };
# if(w.addEventListener){
# w.addEventListener('load', loadTagContainer, false);
# } else if(w.attachEvent){
# w.attachEvent('onload', loadTagContainer);
# }
# })();
#   </script>
#   <div class=" clearfix " id="bodyconstraint">
#    <div id="bodyconstraint-inner">
# ...
# <script type="text/javascript">
#  booking.jstmpl('rt_availability_soldout', (function () { var T = ["\n","\n\u003ch4 class=\"rt_availability_soldout__header\"\u003e","\u003c/h4\u003e\n\u003cul class=\"rt_soldout_list\"\u003e\n","\n\u003cli class=\"rt_soldout_list__item\"\u003e\n\u003ca class=\"rt_soldout_list__link js-rt-availability-soldout-link\" href=\"","\" data-component=\"track\" data-track=\"click\" data-hash=\"","\" data-custom-goal=\"1\"\u003e\n\u003cspan class=\"rt_soldout_list__dates\"\u003e"," – ","\u003c/span\u003e\n\u003cspan class=\"rt_soldout_list__price\"\u003e","\u003c/span\u003e\n\u003c/a\u003e\n\u003c/li\u003e\n","\n\u003c/ul\u003e\n"], V = ["ppd_hp_sold_out_next_available","b_data","b_url","b_checkin","b_checkout","b_from_price_text","b_success"], WV, LV, VA; return function (VS) { var s = '', r = this.fn; function hotel_rooms_table_experiment_droom_rt_soldout_date_suggestions_cta_inc1(s) { s += [ '', T[0] ].join( '' ); if (r.MD(V[6])) { s += [ T[1], r.MB(V[0]), T[2] ].join( '' ); { var LA= ( r.MC(V[1]) || [] ); VS.unshift(null); for(var LC=1, LM= LA.length; LC <= LM; LC++) { VS[0]= LA[LC - 1]; s += [ T[3], r.MC(V[2]), T[4], 'BUZdfbGbELSVHJPJCQfUC', T[5], r.MC(V[3]), T[6], r.MC(V[4]), T[7], r.MC(V[5]), T[8] ].join( '' ); } VS.shift(); } s += T[9]; } s += [ T[0], '' ].join( '' ); return s; } s += T[0]; s = hotel_rooms_table_experiment_droom_rt_soldout_date_suggestions_cta_inc1(s); s += T[0]; return s; }; } )());
# </script>
# <script type="text/javascript">
#  booking.jstmpl('bpg_module_overlay', (function () { var T = ["\n","\u003cdiv class=\"bpg-overlay--wrapper\"\u003e\n\u003cdiv class=\"bpg-overlay--content\"\u003e\n\u003ch1\u003e\n","\n\u003c/h1\u003e\n\u003cp\u003e\n","\n\u003c/p\u003e\n\u003ca href=\"javascript:void(0);\" class=\"bpg-overlay--close\"\u003e","/private/close/name","\u003c/a\u003e\n\u003ch2 class=\"hd\"\u003e\n","\n\u003c/h2\u003e\n\u003cul style=\"list-style-type: none;\"\u003e\n\u003cli class=\"first_lev\"\u003e\n","\n\u003c/li\u003e\n\u003cli class=\"first_lev\"\u003e\n","\n\u003c/li\u003e\n\u003cli class=\"first_lev\"\u003e","\u003c/li\u003e\n\u003cli class=\"first_lev\"\u003e\n\u003cul\u003e\n\u003cli class=\"second_lev\"\u003e","\u003c/li\u003e\n\u003cli class=\"second_lev\"\u003e","\u003c/li\u003e\n\u003c/ul\u003e\n\u003c/li\u003e\n\u003cli class=\"first_lev\"\u003e","\u003c/li\u003e\n\u003c/ul\u003e\n\u003cp\u003e","\u003c/p\u003e\n\u003ch2 class=\"hd\"\u003e\n","\n\u003c/h2\u003e\n\u003cul style=\"list-style-type: none;\"\u003e\n\u003cli class=\"first_lev\"\u003e","\u003c/li\u003e\n\u003cli class=\"first_lev\"\u003e","\u003c/li\u003e\n\u003c/ul\u003e\n\u003c/div\u003e\n\u003c/div\u003e\n"], V = ["pp_index_popup_bpg_we_price_match","pp_index_popup_bpg_quick_desc","bpg_terms_popup_03","bpg_terms_popup_04","bpg_terms_popup_05","bpg_terms_popup_06","bpg_terms_popup_07","bpg_terms_popup_08","bpg_terms_popup_09","bpg_terms_popup_10","bpg_terms_popup_11","bpg_terms_popup_12","bpg_terms_popup_13","pdi_index_wpm_popup_cant_claim","bpg_terms_popup_15","bpg_terms_popup_16","bpg_terms_popup_17","bpg_terms_popup_18","bpg_terms_popup_19","bpg_terms_popup_20","bpg_terms_popup_21"], WV, LV, VA; return function (VS) { var s = '', r = this.fn; function bookings2tmpl_inc_bpg_popup_content_inc1(s) { s += [ T[1], r.MB(V[0]), T[2], r.MB(V[1]), T[3], r.ME(T[4], r.MB, r.MN, null), T[5], r.MB(V[2]), T[0], r.MB(V[3]), T[6], r.MB(V[4]), T[7], r.MB(V[5]), T[8], r.MB(V[6]), T[9], r.MB(V[7]), T[10], r.MB(V[8]), T[10], r.MB(V[9]), T[10], r.MB(V[10]), T[11], r.MB(V[11]), T[12], r.MB(V[12]), T[13], r.MB(V[13]), T[14], r.MB(V[14]), T[15], r.MB(V[15]), T[9], r.MB(V[16]), T[10], r.MB(V[17]), T[10], r.MB(V[18]), T[10], r.MB(V[19]), T[11], r.MB(V[20]), T[16] ].join( '' ); return s; } s += T[0]; s = bookings2tmpl_inc_bpg_popup_content_inc1(s); s += T[0]; return s; }; } )());
# </script>
# <script>
#  (function(B){
# var tmp = B._onfly || [], fn;
# for (var i = 0, l = tmp.length; i < l; i++) {
# if (typeof tmp[i] === 'function') tmp[i].call(B);
# }
# B._onfly = null;
# }(booking));
# </script>
# <script>
#  (function(B){
# var jstmpl = B && B.jstmpl,
# translations = jstmpl && jstmpl.translations;
# translations && translations.set && translations.set({"error":{"checkin_date_to_far_in_the_future":{"name":"您的入住日期離現在太久，請重新試訂"},"checkout_date_invalid":{"name":"您的退房日期不存在"},"checkin_date_invalid":{"name":"您的入住日期不存在"}},"private":{"list_dropdown_email_example":"name@example.com.tw; name@example.com.tw","list_show_prices_of_all":"查看所有住宿價格","bbse_pretrip_email_feedback_yes":"送出","filter_hide":"隱藏","deals_deal_of_day_countdown_timer":"{hours_remain}：{minutes_remain}：{seconds_remain}","lists_map_see_more":"查看更多","list_check_availability_of_all":"查看所有住宿的客房供應情況","bpg_terms_popup_16":"2. 您預訂時使用了：","lists_email_success_message":"太棒了！你的訊息已送出","please_enter_your_check_in_date":"請輸入您的入住日期","sxp_calendar_starting_prices_with_dates_error":"選擇日期並點選 {start_bold}搜索{end_bold}以查看價格","my_list_date_button_v2":"套用日期以查看房況","hours":"小時","pb_google_place_convenience_store":"便利商店","review_adj_average_okay":"可以","deals_price_watch6":"開始追蹤","language_exception_bdot_x_rooms_left_urgency_1":"本站僅剩 {num_left} 間客房！","lists_endorsement_perfect_stay":"尋找理想住宿！","dsf_rename_list_dialogue":"為此清單輸入新名稱","pb_google_place_florist":"花店","review_adj_good":"好","pb_google_place_park":"公園","lists_compare_got_it":"知道了，謝謝！","bpg_terms_popup_06":"2. 其他網站的更低價格優惠在我們核查時仍然可以預訂。","destination_finder_theme_endorsements":"{start_style}{num_endorsement_guests}{end_style}位客人將此地標記為{start_style}“{theme_name}”{end_style}","review_helpful_vote_you_and_others_bold":"{start_bold}你和其他 {number_people} 位客人{end_bold}認為此則評論有幫助","list_icon_tooltip_list_view":"清單檢視","ar_islamic_calendar_ramadan":"Ramadan","sbox_dates_num_nights_1":"入住 {num_nights} 晚","name":"姓名","book_button_now":"立即預訂","list_dropdown_email_last_name_example":"周","pb_google_place_art_gallery":"藝廊","list_dropdown_send_button":"傳送","sbox_num_adults":"{num_adults} 位成人，","lists_sign_in_to_see_click_here":"登入","pb_room_disclaimer":"此房型例圖僅供參考，實際狀況視個別客房而定。","book_from_list_select_dates":"選擇入住日期","price_watch_sorry_1":"抱歉，每人最多僅可追蹤 {max_number_properties} 項價格。","top_3_reasons_to_visit":"造訪此地三大理由：{theme_01}、{theme_02}、{theme_03}","language_exception_sbox_num_children_1":"1 位孩童","m_sr_distance_from_centre_city":"距{city_name}中心 {distanceInKmFromCentre}","free_capitals_cancellation":"免費取消","bpg_terms_popup_20":"住宿場所提供的其他類型的獎勵計劃或特別促銷","search_guest_type_children":"兒童","pb_google_place_spa":"SPA 中心","pb_google_place_meal_takeaway":"外帶店","list_my_lists_onbaording_box_save":"儲存","loc_hp_reviews_see_translation":"查看翻譯版本","ppd_hp_rt_filter_non_ref_num":"不可退款 ({num})","ppd_hp_rt_filter_no_prepayment":"無需訂金","clear_urgency_only_x_rooms_left":"本站僅剩 {amountRooms} 間客房！","bpg_terms_popup_18":"常客特價","df_sold_out_hotels_explain":"所選日期內，網站上此住宿的所有空房已售完。","minutes":"分鐘","deals_price_watch5":"檢視範例","pdi_index_wpm_popup_cant_claim":"什麼情況無法申請退差價？","language_exception_clear_urgency_only_x_rooms_left_1":"本站僅剩 {amountRooms} 間客房！","bpg_terms_popup_10":"相同的入住及退房日期","pb_google_place_shopping_mall":"購物中心","vp_hp_growl_recommendation_head":"特別為您推薦{property_name}","ppd_hp_sold_out_next_available":"選擇其他日期：","pb_google_place_night_club":"夜店","ar_islamic_calendar_two_years":"{first_hijri_month} {first_year}/{second_hijri_month} {second_year}","list_dropdown_email_first_name_example":"廷宣","header_my_lists":"我的清單","lists_room_type_lightbox_room":"其他 {number_of_rooms} 種房型","sbox_age_of_child_popup_best_price":"填入此選項，查看團體出遊最優惠房價！","please_take_a_few_seconds":"懇請您花幾分鐘時間在此 {quick_surveyLink}快速問卷調查{endLink}中提出您的寶貴意見。","days":"天","close":"關閉","seo_country_lp_read_more":"顯示全部","list_percent_off_value":"{percent_off_value}% OFF","list_dropdown_header":"你可將住宿分類存入清單","last_chance":"最後機會！","bpg_terms_popup_04":"如果符合下列條件要求，我們將讓您享受相同的價格：","bpg_terms_popup_07":"3. 其他網站的更低價格優惠與您在{b_companyname}預訂的優惠擁有相同的預訂條款，即：","language_exception_ng_map_price_for_x_nights_1":"1 晚房價","lists_undo_option_basic":"還原","msg_entry_meet_assistant_subheader":"Need a parking space, extra bed, different check-in time or just want to ask if your pet can come? I’m here to help.","clear_urgency_list_not_available":"本網站於下 ...
# }(window.booking));
# </script>
# <script>
#  booking.env.priceWatch = {
# b_price_alert_canceled: "",
# b_price_alert_all_canceled: ""
# };
# </script>
# <script>
#  if( window.performance && performance.measure && 'b-post-scripts') { performance.measure('b-post-scripts'); }
# </script>
# <div id="logo-not-document-write" style="display: none;">
# </div>
# <script type="text/javascript">
#  setTimeout(function(){
# var img = new Image(1,1);
# img.src = '/logo?ver=1&sid=a69dc815b256b32729409bba84f65554&t='+1487156599+1;
# },0);
# </script>
# <noscript>
#  <img src="/logo?ver=0&amp;sid=a69dc815b256b32729409bba84f65554&amp;t=1487156599" style="display:none">
#  </img>
# </noscript>
# <script type="text/javascript">
#  (function(){
# window.lightningjs||function(c){function g(b,d){d&&(d+=(/\?/.test(d)?"&":"?")+"lv=1");c[b]||function(){var i=window,h=document,j=b,g=h.location.protocol,l="load",k=0;(function(){function b(){a.P(l);a.w=1;c[j]("_load")}c[j]=function(){function m(){m.id=e;return c[j].apply(m,arguments)}var b,e=++k;b=this&&this!=i?this.id||0:0;(a.s=a.s||[]).push([e,b,arguments]);m.then=function(b,c,h){var d=a.fh[e]=a.fh[e]||[],j=a.eh[e]=a.eh[e]||[],f=a.ph[e]=a.ph[e]||[];b&&d.push(b);c&&j.push(c);h&&f.push(h);return m};return m};var a=c[j]._={};a.fh={};a.eh={};a.ph={};a.l=d?d.replace(/^\/\//,(g=="https:"?g:"http:")+"//"):d;a.p={0:+new Date};a.P=function(b){a.p[b]=new Date-a.p[0]};a.w&&b();i.addEventListener?i.addEventListener(l,b,!1):i.attachEvent("on"+l,b);var q=function(){function b(){return["\u003Chead\u003E\u003C/head\u003E\u003C",c,' onload="var d=',n,";d.getElementsByTagName('head')[0].",d,"(d.",g,"('script')).",i,"='",a.l,"'\"></",c,">"].join("")}var c="body",e=h[c];if(!e)return setTimeout(q,100);a.P(1);var d="appendChild",g="createElement",i="src",k=h[g]("div"),l=k[d](h[g]("div")),f=h[g]("iframe"),n="document",p;k.style.display="none";e.insertBefore(k,e.firstChild).id=o+"-"+j;f.frameBorder="0";f.id=o+"-frame-"+j;/MSIE[ ]+6/.test(navigator.userAgent)&&(f[i]="javascript:false");f.allowTransparency="true";l[d](f);try{f.contentWindow[n].open()}catch(s){a.domain=h.domain,p="javascript:var d="+n+".open();d.domain='"+h.domain+"';",f[i]=p+"void(0);"}try{var r=f.contentWindow[n];r.write(b());r.close()}catch(t){f[i]=p+'d.write("'+b().replace(/"/g,String.fromCharCode(92)+'"')+'");d.close();'}a.P(2)};a.l&&q()})()}();c[b].lv="1";return c[b]}var o="lightningjs",k=window[o]=g(o);k.require=g;k.modules=c}({});
# function preloadUsabilla(){
# window.usabilla_live = lightningjs.require("usabilla_live", "//w.usabilla.com/78826ff9ad8b.js");
# }
# function onUsabillaClick(event){
# B[sNSStartup].lightbox.hide();
# if (event) {
# $(event.target).closest('.user_center_popover').hide()
# event.preventDefault();
# }
# if (!window.usabilla_live) {
# preloadUsabilla();
# }
# window.usabilla_live('data', { custom: { user_id: ""} });
# window.usabilla_live('data', { custom: { action: "reviews_hotel"} });
# window.usabilla_live('click');
# }
# $('.provide_website_feedback').click(onUsabillaClick);
# (booking.eventEmitter || $( window )).bind('uc_popover_showed', function(event, options){
# if (options.id === 'uc_feedbacklink_box') {
# preloadUsabilla();
# }
# });
# }());
# </script>
# <script type="text/javascript">
#  booking.ensureNamespaceExists('env');
# booking.env.google_analytics_tracking_enabled = 1;
# booking.env.b_label = 'gog235jc-index-XX-XX-XX-unspec-tw-com-L:xt-O:abn-B:unk-N:yes-S:bo-U:salo';
# booking.env.b_availability_checked = '';
# booking.env.b_multiple_destinations_found = '';
# if (typeof _gaq == 'object' || (window.ga && typeof window.ga === 'function')) {
# booking.ensureNamespaceExists('google');
# if (typeof booking.google.returnAnalyticsTrackingString != 'undefined') {
# booking.google.analyticsTrackingString = booking.google.returnAnalyticsTrackingString();
# }
# try {
# (function(q,u,i,c,k){window['GoogleAnalyticsObject']=q;
# window[q]=window[q]||function(){(window[q].q=window[q].q||[]).push(arguments)},
# window[q].l=1*new Date();c=i.createElement(u),k=i.getElementsByTagName(u)[0];
# c.async=true;c.src='//www.google-analytics.com/analytics.js';
# k.parentNode.insertBefore(c,k)})('ga','script',document);
# ga('create', 'UA-116109-18' ,{
# 'cookieDomain': '.booking.com'
# });
# ga('set', 'location', String(document.location.href).replace(/(auth_key|bn|pin|reset_hash)([^;&]+.)/gi, ''));
# ga('require', 'displayfeatures');
# ga('set', 'anonymizeIp', true);
# (function(){
# if (booking.env.b_group && booking.env.b_group.length) {
# var group = booking.env.b_group,
# g, i, length = group && group.length,
# value = {
# rooms: 1,
# adults: 0,
# children: 0,
# childrenAges: []
# },
# isGroupPresent = length > 1 || ( length === 1 && ( group[0].guests > 2 || group[0].ages.length > 0 ) ) || booking.env.b_group_rooms_wanted > 1;
# for ( i = 0; i < length; i += 1 ) {
# g = group[i];
# value.adults += parseInt(g.guests, 10);
# if (g.ages) for (var j = 0, jc = g.ages.length; j < jc; j++) value.childrenAges.push(g.ages[j].age);
# }
# value.rooms = booking.env.b_group_rooms_wanted || booking.env.bs_room_num || length;
# value.children = value.childrenAges.length;
# value.childrenAges = value.childrenAges.sort(function(a, b){return a - b;});
# booking.env.sGroupConfig = (value.rooms || '1') + ' rooms | ' + (value.adults || '1') + ' adults | ' + value.children + ' kids' + (
# value.children ? ' (' + value.childrenAges.join(' | ') + ')' : ''
# );
# booking.env.isGroupPresent = isGroupPresent;
# if (value.children || value.childrenAges.length > 0) {
# booking.env.ga_group_string = 'Family';
# } else if (value.adults === 1) {
# booking.env.ga_group_string = 'Solo';
# } else if (value.adults === 2) {
# booking.env.ga_group_string = 'Couple';
# } else {
# booking.env.ga_group_string = 'Group';
# }
# }
# var pageviewInfo = {
# page: booking.google.analyticsTrackingString || '/',
# dimension17: "reviews_hotel|",
# dimension4: "A69DC81",
# dimension5: "397642",
# dimension6: "17",
# dimension7: "488150",
# dimension8: "gog235jc-index-XX-XX-XX-unspec-tw-com-L:xt-O:abn-B:unk-N:yes-S:bo-U:salo",
# dimension44: "",
# dimension9: booking.env.sGroupConfig || '',
# dimension11: "desktop",
# dimension12: "zh-tw",
# dimension10: "0",
# dimension29: "0",
# dimension84: "0",
# dimension31: "unknown",
# dimension45: 'tw->tw',
# dimension37: (booking.env.b_guest_country == booking.env.b_countrycode) ? 'domestic' : 'international',
# dimension61: "0",
# dimension62: "null",
# dimension63: "null",
# dimension64: '',
# dimension66: 0,
# dimension72: "None",
# dimension85: booking.env.ga_group_string || '',
# dimension99: "null"
# }
# setTimeout(function() {
# if (typeof ga !== 'function') return;
# try {
# ga(function(tracker) {
# ga('set', 'dimension60', tracker.get('clientId'));
# });
# ga('send', 'pageview', pageviewInfo);
# } catch (e) {}
# });
# })();
# } catch (err) {
# }
# } else {
# pageTracker = {
# _initData : function () { },
# _trackPageview : function () { },
# _setDomainName : function () { },
# _setAllowLinker : function () { },
# _link : function () { },
# _linkByPost : function () { },
# _addTrans : function () { },
# _addItem : function () { },
# _trackTrans : function () { },
# _addOrganic : function () { },
# _setVar : function () { },
# _setCookiePath : function () { },
# _setClientInfo : function () { },
# _setAllowHash : function () { },
# _setDetectFlash : function () { },
# _setDetectTitle : function () { },
# _setSessionTimeout : function () { },
# _setCookieTimeout : function () { },
# _setCampNameKey : function () { },
# _setCampMediumKey : function () { },
# _setCampSourceKey : function () { },
# _setCampTermKey : function () { },
# _setCampContentKey : function () { },
# _setCampIdKey : function () { },
# _setCampNOKey : function () { },
# _setAllowAnchor : function () { },
# _addIgnoredOrganic : function () { },
# _addIgnoredRef : function () { },
# _setSampleRate : function () { },
# _setLocalRemoteServerMode : function () { }
# };
# }
# </script>
# <span id="req_info" style="display:none;">
#  204727,195650,205682,206395,203107,200864,204536,203303,204321,199447,200087,202861,202861|2,196662,205512,203290,206373,205232,185503,206395|1
# </span>

# %% [markdown]
# ## BeautifulSoup將複雜HTML文檔轉換成一個複雜的樹形結構,每個節點都是Python對象。

# %%
tag = simple_page.div
print(type(tag))
# Out:
# <class 'bs4.element.Tag'>

# %%
print(tag["class"])

print(tag["id"])
# Out:
# ['', 'clearfix', '']
# bodyconstraint

# %%
print(tag)
# Out:
# <div class=" clearfix " id="bodyconstraint"> <div id="bodyconstraint-inner">
# <div id="top" role="banner">
# <a class="js-header__logo" href="http://www.booking.com/index.zh-tw.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;click_from_logo=1" style="text-decoration: none;">
# <img alt="Booking.com：線上訂房專家" class=" " id="logo_no_globe_new_logo" src="http://s-ec.bstatic.com/static/img/b26logo/booking_logo_retina/22615963add19ac6b6d715a97c8d477e8b95b7ea.png"/>
# </a>
# <div class="ticker_space smaller_booking_nr_login user_center_bar" id="user_form">
# <div data-component="track" data-hash="GCaRZEGcCSRPLSGSZKe" data-stage="1" data-track="view"></div>
# <ul class="user_center_nav">
# <li class="user_center_option" id="uc_feedbacklink_box">
# <a class="popover_trigger feedback_link_look" data-component="track" data-custom-goal="1" data-google-track="Click/Action: reviews_hotel/header_feedback_link_box" data-hash="" data-title="&lt;script type='track_copy' data-hash='ZOTWOAZBEERFCUbLOLHT'&gt;&lt;/script&gt;請提供關於我們網站的建議或成為住宿合作夥伴" data-track="click" href="javascript:void(0);" id="enB">
# <i class="b-sprite feedbacklink_questionbubble"></i>
# </a>
# <div class="user_center_popover narrow center_arrow uc_howtobook">
# <div class="uc_top_arrow"></div>
# <div class="popover_content">
# <div class="select_foldout">
# <div class="select_foldout_wrap">
# <ul>
# <li class="menu_feedback">
# <a class="provide_website_feedback" data-component="track" data-hash="deeXGKeePPZSeHT" data-stage="1" data-track="mouseenter" href="#">提供網站相關意見</a>
# </li>
# <li class="menu_help">
# <a href="https://secure.booking.com/content/cs.zh-tw.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554" rel="nofollow" target="_blank">顧客服務</a>
# </li>
# <li class="menu_add_property">
# <a href="https://join.booking.com?lang=zh-tw&amp;aid=397642&amp;label=HeaderInfoMenu;" target="_blank"><span class="plus_character">+</span>成為合作住宿</a>
# </li>
# <li class="menu_extranet_link">
# <a data-ga-track="click:/internallink/partner/header/extranetloginlink/reviews_hotel/zh-tw" href="https://admin.booking.com/hotel/hoteladmin/login.html?lang=zh-tw&amp;aid=304142&amp;label=HeaderInfoMenuExt" target="_blank">
# <i class="bicon bicon-dashboard"></i>
# 合作夥伴資訊主頁
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </li>
# <!-- currency selection -->
# <li class="user_center_option uc_currency " data-id="currency_selector" data-priority="1">
# <input name="selected_currency" type="hidden" value="TWD"/>
# <a class="popover_trigger long_currency_text" data-google-track="Click/Action: reviews_hotel/header_currency_link_box" data-title="選擇您使用的貨幣" href="javascript:void(0);">
# TWD
# </a>
# <div class="user_center_popover narrow center_arrow uc_currency">
# <div class="uc_top_arrow"></div>
# <div class="popover_content" id="current_currency">
# <div style="padding:20px;">
# <img src="http://t-ec.bstatic.com/static/img/uc_ajax_loader/44d20cd12a233cfc196701b40a8c2a86faf03cbf.gif"/>
# <p>加載中</p>
# </div>
# </div>
# <div class="uc_bottom_arrow"></div>
# </div>
# </li>
# <!-- language selection -->
# <li class="user_center_option uc_language js-uc-language " data-priority="1">
# <a class="popover_trigger" data-google-track="Click/Action: reviews_hotel/header_lang_select_link_box" data-title="選擇您使用的語言" href="javascript:void(0);">
# <img src="http://t-ec.bstatic.com/static/img/flags/24/tw/814f389fe6b5d9dd6ee86050534b7643b3c1dbe8.png"/>
# </a>
# <div class="user_center_popover narrow center_arrow">
# <div class="uc_top_arrow"></div>
# <div class="js-uc-language-content popover_content" id="current_language">
# <p class="popover_explain">
# 選擇您想要使用的語言。我們提供繁體中文和其他42種語言的服務。
# </p>
# <div class="select_foldout small_flags_foldout" id="current_language_foldout">
# <div class="select_foldout_wrap">
# <p>臺灣客人最常使用的語言</p>
# <ul class="language_flags">
# <li class="lang_zh-tw selected_country" data-lang="zh-tw">
# <a class="no_target_blank" href="/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.zh-tw.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75;=;lang=zh-tw;lang_click=top;cdl=zh-tw">
# <span class="selsymbol">
# <span class="flag_16 sflag slang-tw"> </span>
# </span>
# <span class="seldescription">
# 繁體中文
# </span>
# <i class="loading_indicator"></i>
# </a>
# </li>
# <li class="lang_zh-cn" data-lang="zh-cn">
# <a class="no_target_blank" href="/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.zh-cn.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75;=;lang=zh-cn;lang_click=top;cdl=zh-tw">
# <span class="selsymbol">
# <span class="flag_16 sflag slang-cn"> </span>
# </span>
# <span class="seldescription">
# 简体中文
# </span>
# <i class="loading_indicator"></i>
# </a>
# </li>
# </ul>
# <ul class="language_flags">
# <li class="lang_en-gb" data-lang="en-gb">
# <a class="no_target_blank" href="/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.en-gb.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75;=;lang=en-gb;lang_click=top;cdl=zh-tw">
# <span class="selsymbol">
# <span class="flag_16 sflag slang-gb"> </span>
# </span>
# <span class="seldescription">
# English (UK)
# </span>
# <i class="loading_indicator"></i>
# </a>
# </li>
# <li class="lang_en-us" data-lang="en-us">
# <a class="no_target_blank" href="/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.en-us.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75;=;lang=en-us;lang_click=top;cdl=zh-tw">
# <span class="selsymbol">
# <span class="flag_16 sflag slang-us"> </span>
# </span>
# <span class="seldescription">
# English (US)
# </span>
# <i class="loading_indicator"></i>
# </a>
# </li>
# </ul>
# <ul class="language_flags">
# <li class="lang_ja" data-lang="ja">
# <a class="no_target_blank" href="/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.ja.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75;=;lang=ja;lang_click=top;cdl=zh-tw">
# <span class="selsymbol">
# <span class="flag_16 sflag slang-jp"> </span>
# </span>
# <span class="seldescription">
# 日本語
# </span>
# <i class="loading_indicator"></i>
# </a>
# </li>
# <li class="lang_ko" data-lang="ko">
# <a class="no_target_blank" href="/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.ko.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75;=;lang=ko;lang_click=top;cdl=zh-tw">
# <span class="selsymbol">
# <span class="flag_16 sflag slang-kr"> </span>
# </span>
# <span class="seldescription">
# 한국어
# </span>
# <i class="loading_indicator"></i>
# </a>
# </li>
# </ul>
# </div>
# <div class="select_foldout_wrap">
# <p>所有語言</p>
# <ul class="language_flags">
# <li class="lang_en-gb" data-lang="en-gb">
# <a class="no_target_blank" href="/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.en-gb.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75;=;lang=en-gb;lang_click=other;cdl=zh-tw">
# <span class="selsymbol">
# <span class="flag_16 sflag slang-gb"> </span>
# </span>
# <span class="seldescription">
# English (UK)
# </span>
# <i class="loading_indicator"></i>
# </a>
# </li>
# <li class="lang_en-us" data-lang="en-us">
# <a class="no_target_blank" href="/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.en-us.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75;=;lang=en-us;lang_click=other;cdl=zh-tw">
# <span class="selsymbol">
# <span class="flag_16 sflag slang-us"> </span>
# </span>
# <span class="seldescription">
# English (US)
# </span>
# <i class="loading_indicator"></i>
# </a>
# </li>
# <li class="lang_de" data-lang="de">
# <a class="no_target_blank" href="/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.de.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75;=;lang=de;lang_click=other;cdl=zh-tw">
# <span class="selsymbol">
# <span class="flag_16 sflag slang-de"> </span>
# </span>
# <span class="seldescription">
# Deutsch
# </span>
# <i class="loading_indicator"></i>
# </a>
# </li>
# <li class="lang_nl" data-lang="nl">
# <a class="no_target_blank" href="/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.nl.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75;=;lang=nl;lang_click=other;cdl=zh-tw">
# <span class="selsymbol">
# <span class="flag_16 sflag slang-nl"> </span>
# </span>
# <span class="seldescription">
# Nederlands
# </span>
# <i class="loading_indicator"></i>
# </a>
# </li>
# <li class="lang_fr" data-lang="fr">
# <a class="no_target_blank" href="/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.fr.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75;=;lang=fr;lang_click=other;cdl=zh-tw">
# <span class="selsymbol">
# <span class="flag_16 sflag slang-fr"> </span>
# </span>
# <span class="seldescription">
# Français
# </span>
# <i class="loading_indicator"></i>
# </a>
# </li>
# <li class="lang_es" data-lang="es">
# <a class="no_target_blank" href="/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.es.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75;=;lang=es;lang_click=other;cdl=zh-tw">
# <span class="selsymbol">
# <span class="flag_16 sflag slang-es"> </span>
# </span>
# <span class="seldescription">
# Español
# </span>
# <i class="loading_indicator"></i>
# </a>
# </li>
# <li class="lang_es-ar" data-lang="es-ar">
# <a class="no_target_blank" href="/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.es-ar.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75;=;lang=es-ar;lang_click=other;cdl=zh-tw">
# <span class="selsymbol">
# <span class="flag_16 sflag slang-ar"> </span>
# </span>
# <span class="seldescription">
# Español (AR)
# </span>
# <i class="loading_indicator"></i>
# </a>
# </li>
# <li class="lang_ca" data-lang="ca">
# <a class="no_target_blank" href="/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.ca.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75;=;lang=ca;lang_click=other;cdl=zh-tw">
# <span class="selsymbol">
# <span class="flag_16 sflag slang-catalonia"> </span>
# </span>
# <span class="seldescription">
# Català
# </span>
# <i class="loading_indicator"></i>
# </a>
# </li>
# <li class="lang_it" data-lang="it">
# <a class="no_target_blank" href="/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.it.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75;=;lang=it;lang_click=other;cdl=zh-tw">
# <span class="selsymbol">
# <span class="flag_16 sflag slang-it"> </span>
# </span>
# <span class="seldescription">
# Italiano
# </span>
# <i class="loading_indicator"></i>
# </a>
# </li>
# <li class="lang_pt-pt" data-lang="pt-pt">
# <a class="no_target_blank" href="/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.pt-pt.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75;=;lang=pt-pt;lang_click=other;cdl=zh-tw">
# <span class="selsymbol">
# <span class="flag_16 sflag slang-pt"> </span>
# </span>
# <span class="seldescription">
# Português (PT)
# </span>
# <i class="loading_indicator"></i>
# </a>
# </li>
# <li class="lang_pt-br" data-lang="pt-br">
# <a class="no_target_blank" href="/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.pt-br.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75;=;lang=pt-br;lang_click=other;cdl=zh-tw">
# <span class="selsymbol">
# <span class="flag_16 sflag slang-br"> </span>
# </span>
# <span class="seldescription">
# Português (BR)
# </span>
# <i class="loading_indicator"></i>
# </a>
# </li>
# <li class="lang_no" data-lang="no">
# <a class="no_target_blank" href="/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.no.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75;=;lang=no;lang_click=other;cdl=zh-tw">
# <span class="selsymbol">
# <span class="flag_16 sflag slang-no"> </span>
# </span>
# <span class="seldescription">
# Norsk
# </span>
# <i class="loading_indicator"></i>
# </a>
# </li>
# <li class="lang_fi" data-lang="fi">
# <a class="no_target_blank" href="/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.fi.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75;=;lang=fi;lang_click=other;cdl=zh-tw">
# <span class="selsymbol">
# <span class="flag_16 sflag slang-fi"> </span>
# </span>
# <span class="seldescription">
# Suomi
# </span>
# <i class="loading_indicator"></i>
# </a>
# </li>
# <li class="lang_sv" data-lang="sv">
# <a class="no_target_blank" href="/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.sv.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75;=;lang=sv;lang_click=other;cdl=zh-tw">
# <span class="selsymbol">
# <span class="flag_16 sflag slang-se"> </span>
# </span>
# <span class="seldescription">
# Svenska
# </span>
# <i class="loading_indicator"></i>
# </a>
# </li>
# <li class="lang_da" data-lang="da">
# <a class="no_target_blank" href="/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.da.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75;=;lang=da;lang_click=other;cdl=zh-tw">
# <span class="selsymbol">
# <span class="flag_16 sflag slang-dk"> </span>
# </span>
# <span class="seldescription">
# Dansk
# </span>
# <i class="loading_indicator"></i>
# </a>
# </li>
# </ul>
# <ul class="language_flags">
# <li class="lang_cs" data-lang="cs">
# <a class="no_target_blank" href="/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.cs.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75;=;lang=cs;lang_click=other;cdl=zh-tw">
# <span class="selsymbol">
# <span class="flag_16 sflag slang-cz"> </span>
# </span>
# <span class="seldescription">
# Čeština
# </span>
# <i class="loading_indicator"></i>
# </a>
# </li>
# <li class="lang_hu" data-lang="hu">
# <a class="no_target_blank" href="/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.hu.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75;=;lang=hu;lang_click=other;cdl=zh-tw">
# <span class="selsymbol">
# <span class="flag_16 sflag slang-hu"> </span>
# </span>
# <span class="seldescription">
# Magyar
# </span>
# <i class="loading_indicator"></i>
# </a>
# </li>
# <li class="lang_ro" data-lang="ro">
# <a class="no_target_blank" href="/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.ro.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75;=;lang=ro;lang_click=other;cdl=zh-tw">
# <span class="selsymbol">
# <span class="flag_16 sflag slang-ro"> </span>
# </span>
# <span class="seldescription">
# Română
# </span>
# <i class="loading_indicator"></i>
# </a>
# </li>
# <li class="lang_ja" data-lang="ja">
# <a class="no_target_blank" href="/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.ja.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75;=;lang=ja;lang_click=other;cdl=zh-tw">
# <span class="selsymbol">
# <span class="flag_16 sflag slang-jp"> </span>
# </span>
# <span class="seldescription">
# 日本語
# </span>
# <i class="loading_indicator"></i>
# </a>
# </li>
# <li class="lang_zh-cn" data-lang="zh-cn">
# <a class="no_target_blank" href="/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.zh-cn.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75;=;lang=zh-cn;lang_click=other;cdl=zh-tw">
# <span class="selsymbol">
# <span class="flag_16 sflag slang-cn"> </span>
# </span>
# <span class="seldescription">
# 简体中文
# </span>
# <i class="loading_indicator"></i>
# </a>
# </li>
# <li class="lang_zh-tw selected_country" data-lang="zh-tw">
# <a class="no_target_blank" href="/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.zh-tw.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75;=;lang=zh-tw;lang_click=other;cdl=zh-tw">
# <span class="selsymbol">
# <span class="flag_16 sflag slang-tw"> </span>
# </span>
# <span class="seldescription">
# 繁體中文
# </span>
# <i class="loading_indicator"></i>
# </a>
# </li>
# <li class="lang_pl" data-lang="pl">
# <a class="no_target_blank" href="/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.pl.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75;=;lang=pl;lang_click=other;cdl=zh-tw">
# <span class="selsymbol">
# <span class="flag_16 sflag slang-pl"> </span>
# </span>
# <span class="seldescription">
# Polski
# </span>
# <i class="loading_indicator"></i>
# </a>
# </li>
# <li class="lang_el" data-lang="el">
# <a class="no_target_blank" href="/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.el.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75;=;lang=el;lang_click=other;cdl=zh-tw">
# <span class="selsymbol">
# <span class="flag_16 sflag slang-gr"> </span>
# </span>
# <span class="seldescription">
# Ελληνικά
# </span>
# <i class="loading_indicator"></i>
# </a>
# </li>
# <li class="lang_ru" data-lang="ru">
# <a class="no_target_blank" href="/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.ru.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75;=;lang=ru;lang_click=other;cdl=zh-tw">
# <span class="selsymbol">
# <span class="flag_16 sflag slang-ru"> </span>
# </span>
# <span class="seldescription">
# Русский
# </span>
# <i class="loading_indicator"></i>
# </a>
# </li>
# <li class="lang_tr" data-lang="tr">
# <a class="no_target_blank" href="/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.tr.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75;=;lang=tr;lang_click=other;cdl=zh-tw">
# <span class="selsymbol">
# <span class="flag_16 sflag slang-tr"> </span>
# </span>
# <span class="seldescription">
# Türkçe
# </span>
# <i class="loading_indicator"></i>
# </a>
# </li>
# <li class="lang_bg" data-lang="bg">
# <a class="no_target_blank" href="/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.bg.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75;=;lang=bg;lang_click=other;cdl=zh-tw">
# <span class="selsymbol">
# <span class="flag_16 sflag slang-bg"> </span>
# </span>
# <span class="seldescription">
# Български
# </span>
# <i class="loading_indicator"></i>
# </a>
# </li>
# <li class="lang_ar" data-lang="ar">
# <a class="no_target_blank" href="/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.ar.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75;=;lang=ar;lang_click=other;cdl=zh-tw">
# <span class="selsymbol">
# <span class="flag_16 sflag slang-sa"> </span>
# </span>
# <span class="seldescription">
# العربية
# </span>
# <i class="loading_indicator"></i>
# </a>
# </li>
# <li class="lang_ko" data-lang="ko">
# <a class="no_target_blank" href="/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.ko.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75;=;lang=ko;lang_click=other;cdl=zh-tw">
# <span class="selsymbol">
# <span class="flag_16 sflag slang-kr"> </span>
# </span>
# <span class="seldescription">
# 한국어
# </span>
# <i class="loading_indicator"></i>
# </a>
# </li>
# <li class="lang_he" data-lang="he">
# <a class="no_target_blank" href="/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.he.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75;=;lang=he;lang_click=other;cdl=zh-tw">
# <span class="selsymbol">
# <span class="flag_16 sflag slang-il"> </span>
# </span>
# <span class="seldescription">
# עברית
# </span>
# <i class="loading_indicator"></i>
# </a>
# </li>
# <li class="lang_lv" data-lang="lv">
# <a class="no_target_blank" href="/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.lv.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75;=;lang=lv;lang_click=other;cdl=zh-tw">
# <span class="selsymbol">
# <span class="flag_16 sflag slang-lv"> </span>
# </span>
# <span class="seldescription">
# Latviski
# </span>
# <i class="loading_indicator"></i>
# </a>
# </li>
# </ul>
# <ul class="language_flags">
# <li class="lang_uk" data-lang="uk">
# <a class="no_target_blank" href="/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.uk.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75;=;lang=uk;lang_click=other;cdl=zh-tw">
# <span class="selsymbol">
# <span class="flag_16 sflag slang-ua"> </span>
# </span>
# <span class="seldescription">
# Українська
# </span>
# <i class="loading_indicator"></i>
# </a>
# </li>
# <li class="lang_id" data-lang="id">
# <a class="no_target_blank" href="/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.id.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75;=;lang=id;lang_click=other;cdl=zh-tw">
# <span class="selsymbol">
# <span class="flag_16 sflag slang-id"> </span>
# </span>
# <span class="seldescription">
# Bahasa Indonesia
# </span>
# <i class="loading_indicator"></i>
# </a>
# </li>
# <li class="lang_ms" data-lang="ms">
# <a class="no_target_blank" href="/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.ms.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75;=;lang=ms;lang_click=other;cdl=zh-tw">
# <span class="selsymbol">
# <span class="flag_16 sflag slang-my"> </span>
# </span>
# <span class="seldescription">
# Bahasa Malaysia
# </span>
# <i class="loading_indicator"></i>
# </a>
# </li>
# <li class="lang_th" data-lang="th">
# <a class="no_target_blank" href="/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.th.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75;=;lang=th;lang_click=other;cdl=zh-tw">
# <span class="selsymbol">
# <span class="flag_16 sflag slang-th"> </span>
# </span>
# <span class="seldescription">
# ภาษาไทย
# </span>
# <i class="loading_indicator"></i>
# </a>
# </li>
# <li class="lang_et" data-lang="et">
# <a class="no_target_blank" href="/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.et.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75;=;lang=et;lang_click=other;cdl=zh-tw">
# <span class="selsymbol">
# <span class="flag_16 sflag slang-ee"> </span>
# </span>
# <span class="seldescription">
# Eesti
# </span>
# <i class="loading_indicator"></i>
# </a>
# </li>
# <li class="lang_hr" data-lang="hr">
# <a class="no_target_blank" href="/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.hr.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75;=;lang=hr;lang_click=other;cdl=zh-tw">
# <span class="selsymbol">
# <span class="flag_16 sflag slang-hr"> </span>
# </span>
# <span class="seldescription">
# Hrvatski
# </span>
# <i class="loading_indicator"></i>
# </a>
# </li>
# <li class="lang_lt" data-lang="lt">
# <a class="no_target_blank" href="/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.lt.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75;=;lang=lt;lang_click=other;cdl=zh-tw">
# <span class="selsymbol">
# <span class="flag_16 sflag slang-lt"> </span>
# </span>
# <span class="seldescription">
# Lietuvių
# </span>
# <i class="loading_indicator"></i>
# </a>
# </li>
# <li class="lang_sk" data-lang="sk">
# <a class="no_target_blank" href="/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.sk.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75;=;lang=sk;lang_click=other;cdl=zh-tw">
# <span class="selsymbol">
# <span class="flag_16 sflag slang-sk"> </span>
# </span>
# <span class="seldescription">
# Slovenčina
# </span>
# <i class="loading_indicator"></i>
# </a>
# </li>
# <li class="lang_sr" data-lang="sr">
# <a class="no_target_blank" href="/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.sr.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75;=;lang=sr;lang_click=other;cdl=zh-tw">
# <span class="selsymbol">
# <span class="flag_16 sflag slang-rs"> </span>
# </span>
# <span class="seldescription">
# Srpski
# </span>
# <i class="loading_indicator"></i>
# </a>
# </li>
# <li class="lang_sl" data-lang="sl">
# <a class="no_target_blank" href="/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.sl.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75;=;lang=sl;lang_click=other;cdl=zh-tw">
# <span class="selsymbol">
# <span class="flag_16 sflag slang-si"> </span>
# </span>
# <span class="seldescription">
# Slovenščina
# </span>
# <i class="loading_indicator"></i>
# </a>
# </li>
# <li class="lang_vi" data-lang="vi">
# <a class="no_target_blank" href="/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.vi.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75;=;lang=vi;lang_click=other;cdl=zh-tw">
# <span class="selsymbol">
# <span class="flag_16 sflag slang-vn"> </span>
# </span>
# <span class="seldescription">
# Tiếng Việt
# </span>
# <i class="loading_indicator"></i>
# </a>
# </li>
# <li class="lang_tl" data-lang="tl">
# <a class="no_target_blank" href="/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.tl.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75;=;lang=tl;lang_click=other;cdl=zh-tw">
# <span class="selsymbol">
# <span class="flag_16 sflag slang-ph"> </span>
# </span>
# <span class="seldescription">
# Filipino
# </span>
# <i class="loading_indicator"></i>
# </a>
# </li>
# <li class="lang_is" data-lang="is">
# <a class="no_target_blank" href="/reviews/tw/hotel/tai-bei-fa-xian-qing-lu.is.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;customer_type=total;hp_nav=0;order=featuredreviews;page=1;r_lang=zh-tw;rows=75;=;lang=is;lang_click=other;cdl=zh-tw">
# <span class="selsymbol">
# <span class="flag_16 sflag slang-is"> </span>
# </span>
# <span class="seldescription">
# Íslenska
# </span>
# <i class="loading_indicator"></i>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="uc_bottom_arrow"></div>
# </div>
# </li>
# <li class="user_center_option uc_wishlists my_list" data-id="wishlists" data-priority="5">
# <div data-component="lists-header-button track">
# <a class=" lists-header-button pill_btn_style_wish_alone js-lists-header-button wishlist-alert js-uc-wishlists-trigger " data-google-track="Click/Action: reviews_hotel/header_wish_lists_link_box" data-title="保存並分享您喜愛的目的地" href="javascript:void(0);" id="uc_wishlists_trigger">
# <i class="lists-header-button__icon bicon-heart"></i>
# 我的清單
# </a>
# <div class=" user_center_popover center_arrow uc_wishlists wishlist_widget js-uc-wishlists-popover ">
# <div class="uc_top_arrow"></div>
# <div class=" popover_content wishlist-list-update js-uc-wishlists-content uc-wishlists-popover-content uc-wishlists-popover-content_wl-for-all lists-popover-message ">
# <div class="wishlists_popover_nohotel">
# <span class="wishlists_popover_nohotel__title">你可將住宿分類存入清單</span>
# <span class="wishlists_popover_nohotel__desc">當發現喜愛的住宿時，你可將其存入清單，方便事後查詢。</span>
# <div class="wishlists_popover_alert">
# 將住宿分類存入清單。或分享清單給朋友，一同規劃行程。
# <a class="close" href="#"> </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="user_center_option header_dsf_link " data-priority="2" id="header_dsf_link">
# <a class="header_link_new_icon popover_trigger" data-component="track" data-custom-goal="1" data-hash="AEJPVZMYCVLBQRWSEaEIVDaXe" data-title="旅遊靈感！" data-track="click" href="http://www.booking.com/destinationfinder.zh-tw.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;dsf_header=1;dsf_source=1" target="_blank"> <img alt="Destination Finder" height="36" src="http://s-ec.bstatic.com/static/img/experiments/dsf_new_icon/328dd1759b1aa40ee77afe32a47c0fde2af14149.png" width="31"/> </a> <div class="user_center_popover center_arrow"> <div class="uc_top_arrow"></div> <div class="noti_popover_content_wrapper popover_content uc-notification-wrap"> <div class="dsf_banner_awareness_index_wrapper clearfix"> <a class="dsf_banner_awareness_index_anchor clearfix" data-component="track" data-custom-goal="2" data-google-track="" data-hash="AEJPVZMYCVLBQRWSEaEIVDaXe" data-track="click" href="http://www.booking.com/destinationfinder.zh-tw.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;dsf_header=1;dsf_source=1;dsf_from_header_cta=1"> <dl class="dsf_banner_awareness_index_content"> <dt class="dsf_banner_awareness_index_title">任何地方都能找到適合自己的選擇</dt> <dd class="dsf_banner_awareness_index_tag">不論你在尋找什麼，旅程從這裡開始</dd> <dd class="dsf_banner_awareness_index_cta">出發！</dd> </dl> </a> </div> </div> </div>
# </li>
# <li class=" user_center_option uc_account " data-priority="2" id="add_property_topbar">
# <a class=" popover_trigger signin_cta profile_menu_trigger js-disable-popover remove_hover_sign_in_btn remove_padding_register_btn_right " data-et-click="customGoal:TAeKPWbVLBQScADDbdEScXQOVWe:1" href="https://join.booking.com/?lang=zh-tw&amp;utm_source=topbar&amp;aid=1194661" target="_blank">
# <div class="sign_in_wrapper sign_in_wrapper-add-property">
# <span>
# 將您的住宿註冊上線
# </span>
# </div>
# </a>
# </li>
# <li class=" user_center_option uc_account uc_account-center-item " data-command="show-auth-lightbox" data-command-params="tab=signup;extraClass=user-access-menu-lightbox--user-center" data-priority="2" id="current_account">
# <a class=" popover_trigger signin_cta profile_menu_trigger js-disable-popover remove_hover_sign_in_btn remove_padding_register_btn_right " data-google-track="Click/Action: reviews_hotel/header_logged_out_link_box" href="https://secure.booking.com/mysettings.zh-tw.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;aru=http%3A%2F%2Fwww.booking.com%2Freviews%2Ftw%2Fhotel%2Ftai-bei-fa-xian-qing-lu.zh-tw.html%3Faid%3D397642%3Blabel%3Dgog235jc-index-XX-XX-XX-unspec-tw-com-L%253Axt-O%253Aabn-B%253Aunk-N%253Ayes-S%253Abo-U%253Asalo%3Bsid%3D83349c9f35261a2ee9abd0d1c30202bc;auth_tab=signup">
# <div class="sign_in_wrapper">
# <span>
# 註冊
# </span>
# </div>
# </a>
# </li>
# <li class=" account_register_option user_center_option uc_account " data-command="show-auth-lightbox" data-command-params="tab=signin;extraClass=user-access-menu-lightbox--user-center" data-priority="2" id="current_account">
# <a class=" popover_trigger signin_cta profile_menu_trigger js-disable-popover remove_hover_sign_in_btn " data-google-track="Click/Action: reviews_hotel/header_logged_out_link_box" href="https://secure.booking.com/mysettings.zh-tw.html?aid=397642;label=gog235jc-index-XX-XX-XX-unspec-tw-com-L%3Axt-O%3Aabn-B%3Aunk-N%3Ayes-S%3Abo-U%3Asalo;sid=a69dc815b256b32729409bba84f65554;aru=http%3A%2F%2Fwww.booking.com%2Freviews%2Ftw%2Fhotel%2Ftai-bei-fa-xian-qing-lu.zh-tw.html%3Faid%3D397642%3Blabel%3Dgog235jc-index-XX-XX-XX-unspec-tw-com-L%253Axt-O%253Aabn-B%253Aunk-N%253Ayes-S%253Abo-U%253Asalo%3Bsid%3D83349c9f35261a2ee9abd0d1c30202bc;auth_tab=signin">
# <div class="sign_in_wrapper">
# <span>
# 登入
# </span>
# </div>
# </a>
# </li>
# </ul>
# </div>
# </div>
# <div class="" id="subheader-wrap" style="">
# </div>
# <div data-block-id="header_survey">
# </div>
# </div> <!-- closing id="bodyconstraint-inner"-->
# </div>

# %%
for string in simple_page.find_all("div",{"id":"review_list_score"}):
    print(string.get_text("\n",strip=True))
# Out:
# 整體評分
# 根據 1057  則青年旅館評語
# 9.2
# 單項評分
# 整潔度
# 9.4
# 舒適程度
# 9.2
# 住宿地點
# 8.9
# 設施
# 9.2
# 員工素質
# 9.2
# 性價比
# 9.2
# 免費 WiFi
# 8.7

# %% [markdown]
# ## 關於.get_text()函數，會把你正在處理的HTML文件中的所有標籤都清除，回傳一個只包含文字的字串。意思便是，如果你的任務中包含要擷取HTML原始碼中的超連結，段落或是標籤之類的訊息，那麼便避免一開始就使用.get_text()函數，通常是要保存純文字數據時，才會在最後使用.get_text()函數。
#
#
# ## BeautifulSoup的 find() 和 find_all() ，這兩個函數可能是我們在BeautifulSoup中最常使用的兩個函數。借助這兩個函數，可以通過標籤的不同屬性輕鬆個過濾HTML頁面。查找一組標籤或是單個標籤。
#
#
#
# ### 嘗試打印出飯店的總評分。

# %%
for string in simple_page.find_all("li",{"class":"review_item clearfix "}):
    try:
        print("日期:"+string.find("p",{"class":"review_item_date"}).get_text("\n",strip=True))
        print("名稱:"+string.find("span",{"itemprop":"name"}).get_text("\n",strip=True))
        print("國籍:"+string.find("span",{"class":"reviewer_country"}).get_text("\n",strip=True))
        print("留言數:"+string.find("div",{"class":"review_item_user_review_count"}).get_text("\n",strip=True))
        print("評分:"+string.find("div",{"class":"review_item_review_score jq_tooltip"}).get_text("\n",strip=True))
        print(string.find_next("div",{"class":"review_item_review_content"}).find("p",{"class":"review_neg"}).get_text("\n",strip=True))
        print(string.find_next("div",{"class":"review_item_review_content"}).find("p",{"class":"review_pos"}).get_text("\n",strip=True))
    except AttributeError:
        print("continue here")
        continue
# Out:
# 日期:2017 年 2 月 2 日
# 名稱:小歡歡
# 國籍:臺灣
# 留言數:1 則評語
# continue here
# 日期:2017 年 1 月 15 日
# 名稱:Wen
# 國籍:臺灣
# 留言數:3 則評語
# 評分:9.2
# 눉
# 小缺點是宿舍房間沒有USB的充電，不過不影響住宿品質
# 눇
# 空間很乾淨，準備早餐的阿姨們人也很好，櫃台的小姐親切有禮，因為是住女生專屬的宿舍房，浴室設備跟之前住過的青旅不同，乾淨衛生，下次會回去住房
# 日期:2017 年 1 月 11 日
# 名稱:匿名
# 國籍:臺灣
# 留言數:6 則評語
# 評分:7.1
# 눉
# 冷氣有點太冷，進出要升降簾幕，不方便使用。兩邊設計是對稱的，會讓人產生錯覺以為對面是倒影，有點嚇人。-
# 눇
# 地點很好，旁邊就是公車站，離捷運也很近，附近也有很多消夜和便利商店可以用餐，離台北車站也不遠。。
# 日期:2017 年 1 月 11 日
# 名稱:Jincos
# 國籍:臺灣
# 留言數:1 則評語
# continue here
# 日期:2016 年 12 月 26 日
# 名稱:Evie
# 國籍:臺灣
# 留言數:2 則評語
# 評分:8.8
# 눉
# 廁所垃圾桶太小地上周圍都是衛生紙，才晚上衛生紙就見底，應適時補充
# 눇
# 溫馨 舒適 安全感
# Check in時服務很親切 近捷運 近小7
# 日期:2016 年 12 月 25 日
# 名稱:David
# 國籍:臺灣
# 留言數:9 則評語
# 評分:7.9
# 눉
# 價格稍微貴一些，物質的品質很不錯，但員工的服務就稍嫌差一點。應該也是可以的。
# 눇
# 床鋪很乾淨，晚上很安靜。
# 日期:2016 年 12 月 16 日
# 名稱:林郁哲
# 國籍:臺灣
# 留言數:2 則評語
# 評分:8.3
# 눉
# 床頭空調口有點吵,離開床位(洗澡)無法充電(3c產品),浴室置物架損毀,早餐頗陽春
# 눇
# 地點很好交通方便
# 日期:2016 年 11 月 27 日
# 名稱:SHU MEI YANG
# 國籍:臺灣
# 留言數:4 則評語
# 評分:9.2
# continue here
# 日期:2016 年 11 月 16 日
# 名稱:Ming
# 國籍:臺灣
# 留言數:1 則評語
# 評分:7.9
# 눉
# 早餐只有吐司,軟法,沖泡咖啡跟奶茶,水果切片...選項有點少。房間空調有點小,室友帶回來吃消夜,味道整晚都一直在
# 눇
# 頂樓開放式廚房,可以提供房客自己煮東西吃,不過只住一兩天的人似乎用不到。浴室乾淨,有免治馬桶(屁屁用水洗~),提供沐浴乳跟洗髮乳,出租毛巾跟浴巾,還有投幣式洗衣機跟免費的脫水機(頂樓可以曬衣服)...機能十足
# 日期:2016 年 11 月 13 日
# 名稱:Betty
# 國籍:臺灣
# 留言數:16 則評語
# continue here
# 日期:2016 年 10 月 30 日
# 名稱:CClin
# 國籍:越南
# 留言數:20 則評語
# continue here
# 日期:2016 年 10 月 19 日
# 名稱:Then
# 國籍:臺灣
# 留言數:1 則評語
# 評分:7.5
# 눉
# 希望以上的建議對你們有幫助，謝謝你們的服務。的話，那這個懲罰也太重了。時的好印象完全打翻。而且整個晚- 上睡的非常不安穩，原先預計7點起床離開，因為你們的這個安排，我們從2點翻來翻去，終於等到天亮，才會選- 擇6點下去盥洗離開。
# 눇
# 整體環境是乾淨舒服的。
# 日期:2016 年 10 月 11 日
# 名稱:Kuo-chuan
# 國籍:臺灣
# 留言數:2 則評語
# continue here
# 日期:2016 年 10 月 1 日
# 名稱:匿名
# 國籍:香港
# 留言數:3 則評語
# continue here
# 日期:2016 年 9 月 25 日
# 名稱:Wu Martha
# 國籍:臺灣
# 留言數:5 則評語
# continue here
# 日期:2016 年 9 月 15 日
# 名稱:ZachYang
# 國籍:臺灣
# 留言數:9 則評語
# continue here
# 日期:2016 年 9 月 10 日
# 名稱:Chia
# 國籍:臺灣
# 留言數:6 則評語
# 評分:9.2
# 눉
# 床頭燈不夠亮.，交誼廳的燈很不舒服，很難閱讀，書籍有點老舊、冷門。
# 눇
# 床舒適，採光良好，男女分樓層，更自在。
# 日期:2016 年 9 月 4 日
# 名稱:Jiahao
# 國籍:臺灣
# 留言數:1 則評語
# 評分:9.2
# 눉
# 飲水機在入住當天壞了沒修理 卻沒提供杯水或礦泉水
# 눇
# 位於住宅區 晚上能好好休息當便利
# 日期:2016 年 9 月 3 日
# 名稱:黃清譽
# 國籍:臺灣
# 留言數:1 則評語
# continue here
# 日期:2016 年 8 月 22 日
# 名稱:Nancy
# 國籍:臺灣
# 留言數:2 則評語
# continue here
# 日期:2016 年 8 月 18 日
# 名稱:Augusta
# 國籍:香港
# 留言數:1 則評語
# continue here
# 日期:2016 年 8 月 14 日
# 名稱:Weni
# 國籍:臺灣
# 留言數:3 則評語
# continue here
# 日期:2016 年 8 月 12 日
# 名稱:匿名
# 國籍:臺灣
# 留言數:3 則評語
# 評分:8.3
# 눉
# 希望有早餐卷～
# 눇
# 很棒。有竹籃可以放，廳的佈置，
# 日期:2016 年 8 月 7 日
# 名稱:Yin
# 國籍:臺灣
# 留言數:2 則評語
# 評分:8.8
# 눉
# 睡到半夜太冷了出風口，蠻吵的，
# 눇
# 很安靜的Hostel，臥室和休閒區不同樓層，不影響睡覺
# 日期:2016 年 8 月 4 日
# 名稱:匿名
# 國籍:臺灣
# 留言數:1 則評語
# 評分:6.7
# 눉
# 靠近公共衛浴的房間，於浴室用水之時，可聽見水聲，雖是不同空間但是有點干擾
# 눇
# 女宿單人空間夠用，門禁管理及置物櫃設計得宜
# 日期:2016 年 7 月 31 日
# 名稱:慈妤
# 國籍:臺灣
# 留言數:2 則評語
# 評分:8.8
# 눉
# 上鋪的樓梯真的很難爬!!!
# 눇
# 離捷運站很近!很棒!
# 日期:2016 年 7 月 27 日
# 名稱:Ya-wang
# 國籍:臺灣
# 留言數:1 則評語
# 評分:7.9
# 눉
# 個人櫃子有時會故障。
# 눇
# 免治馬桶。適。好睡。
# 日期:2016 年 7 月 24 日
# 名稱:Ho
# 國籍:臺灣
# 留言數:1 則評語
# 評分:7.5
# 눉
# 拖鞋穿進房間後有專門放的地方比較不會被別人穿走
# 눇
# 唯一可惜的是真的可以聽見整個房間其他人在做些什麼說些什麼
# 日期:2016 年 7 月 20 日
# 名稱:Pei
# 國籍:臺灣
# 留言數:1 則評語
# 評分:8.8
# 눉
# 忘記有早餐可以吃而錯過了...
# 눇
# 樓下就有便利商店、生活機能好，床舖很舒適、很好睡!!
# 日期:2016 年 7 月 19 日
# 名稱:Lin
# 國籍:臺灣
# 留言數:1 則評語
# 評分:9.2
# 눉
# 希望個人床燈亮度及空調溫度能自行調節之外，其他的都很棒！
# 눇
# 安全隱私性佳，共用設施優，不論單人或團體入住都適合，整體而言相當不錯！
# 日期:2016 年 7 月 19 日
# 名稱:育銘
# 國籍:臺灣
# 留言數:1 則評語
# 評分:8.8
# continue here
# 日期:2016 年 7 月 17 日
# 名稱:Astrid
# 國籍:法國
# 留言數:2 則評語
# continue here
# 日期:2016 年 7 月 17 日
# 名稱:Tracy
# 國籍:臺灣
# 留言數:1 則評語
# 評分:7.1
# 눉
# 冷氣只有走道有，電燈無法調整自己要的角度，而且電燈如開著會很熱
# 눇
# 服務很好，地點離高鐵很近
# 日期:2016 年 7 月 14 日
# 名稱:Wen
# 國籍:臺灣
# 留言數:1 則評語
# 評分:7.9
# 눉
# 淋浴間的水會一直流出來，所以使用洗手檯時，都要踩在水上，還要擔心滑倒
# continue here
# 日期:2016 年 7 月 14 日
# 名稱:Ting
# 國籍:澳洲
# 留言數:1 則評語
# continue here
# 日期:2016 年 7 月 11 日
# 名稱:Taohui
# 國籍:臺灣
# 留言數:3 則評語
# 評分:6.7
# 눉
# 希望將塑膠拖鞋改成只拖鞋,因為有些人拖鞋都拖著走,很吵
# continue here
# 日期:2016 年 7 月 10 日
# 名稱:Howard
# 國籍:香港
# 留言數:1 則評語
# continue here
# 日期:2016 年 7 月 8 日
# 名稱:Unleng
# 國籍:澳門
# 留言數:2 則評語
# continue here
# 日期:2016 年 7 月 6 日
# 名稱:Wei-ruei
# 國籍:臺灣
# 留言數:3 則評語
# continue here
# 日期:2016 年 7 月 2 日
# 名稱:Patrick
# 國籍:香港
# 留言數:1 則評語
# continue here
# 日期:2016 年 6 月 23 日
# 名稱:Lina
# 國籍:香港
# 留言數:4 則評語
# 評分:7.1
# continue here
# 日期:2016 年 6 月 22 日
# 名稱:Chia-ling
# 國籍:臺灣
# 留言數:5 則評語
# 評分:9.2
# continue here
# 日期:2016 年 6 月 21 日
# 名稱:匿名
# 國籍:臺灣
# 留言數:3 則評語
# 評分:6.7
# 눉
# 因有住過，設備新穎，附早餐，床內有電視，燈具齊全，提共更完善的個人衛浴用品，交通位置佳，且價錢比該住- 宿便宜1/3，所以比較挑剔。
# 눇
# 裝潢及設備中上，服務態度不錯，交通方便。
# 日期:2016 年 6 月 19 日
# 名稱:Chenling
# 國籍:臺灣
# 留言數:6 則評語
# continue here
# 日期:2016 年 6 月 16 日
# 名稱:Hiu
# 國籍:香港
# 留言數:3 則評語
# continue here
# 日期:2016 年 6 月 6 日
# 名稱:匿名
# 國籍:澳門
# 留言數:6 則評語
# continue here
# 日期:2016 年 6 月 5 日
# 名稱:Connie
# 國籍:臺灣
# 留言數:2 則評語
# 評分:9.2
# 눉
# 有人把大行李箱放在很小的廁所通道 讓人很困擾 聊天
# 눇
# 地點不錯 離捷運站近人習慣很差少東西
# 日期:2016 年 6 月 5 日
# 名稱:匿名
# 國籍:香港
# 留言數:2 則評語
# continue here
# 日期:2016 年 6 月 5 日
# 名稱:匿名
# 國籍:臺灣
# 留言數:2 則評語
# continue here
# 日期:2016 年 5 月 30 日
# 名稱:Cutedoor
# 國籍:臺灣
# 留言數:9 則評語
# 評分:9
# 눉
# 床單清潔度要再提升一點喲
# 눇
# Location is good you can reach MRT or bus stop just take a few steps. The staff is friendly.
# 日期:2016 年 5 月 29 日
# 名稱:appletw
# 國籍:臺灣
# 留言數:14 則評語
# 評分:7.5
# 눉
# 並不每個人都很有公德心，半夜有人大聲處理行李，但是要住之前就已有心理準備！還可接受 ！買耳塞就對了！希望鎖行李箱的櫃子能放在臥室外！開開關關太吵了！
# 눇
# 離捷運站近，便利性高，窩幾個小時，舒服經濟實惠！服務人員超親切，很棒！
# 日期:2016 年 5 月 25 日
# 名稱:Ai-lin
# 國籍:臺灣
# 留言數:4 則評語
# continue here
# 日期:2016 年 5 月 25 日
# 名稱:ChamomillaW
# 國籍:臺灣
# 留言數:2 則評語
# 評分:8.8
# 눉
# 浴室洗手台及走道上容易有水漬，雖然每個淋浴間門口都放了腳踏墊，但人多時易被旅客採亂，看起來會較不整潔-
# 눇
# 喜歡床腳掛衣服的地方，還有那面牆上的小語把門簾拉起來也不會很悶
# 日期:2016 年 5 月 23 日
# 名稱:Yue
# 國籍:西班牙
# 留言數:16 則評語
# 評分:7.1
# 눉
# 之前晚入住的女生理東西理了一個小時聲音超響。，本來以為可以安靜下來，大半夜三點多還一直有人入住，從來- 沒遇到過十二點以後還允許入住（不是回來是入住）的青年旅社，這是第一次，也不知道老闆怎麼想的。總之如果- 必須安靜下來才能睡著的人還是不要來這邊。
# 눇
# 整個旅社最好的地方就是設施。交易廳很大很舒服，可以上網看書喝茶。女性的盥洗室位子也挺多的，挺乾淨但是還是沒有乾濕分離。
# 日期:2016 年 5 月 23 日
# 名稱:Tingting
# 國籍:臺灣
# 留言數:4 則評語
# 評分:8.8
# 눉
# 沒有
# 눇
# 離捷運站走路約5分鐘、大家都很好、環境整體來說都很棒！
# 日期:2016 年 5 月 21 日
# 名稱:Ting
# 國籍:香港
# 留言數:2 則評語
# 評分:8.8
# 눉
# 比較晚睡的朋友，要打開儲物櫃會有點不便
# 눇
# 有很大空間，包括床位和活動室
# 日期:2016 年 5 月 19 日
# 名稱:Carol
# 國籍:香港
# 留言數:5 則評語
# 評分:9.2
# 눉
# 如果遇到不自律的同房，就比較頭痛
# 눇
# 這間旅店雖然是以出租床位為賣點，但無論是職員或環境清潔等，都絕對不遜色於四、五星級的大飯店，以我有潔癖的人來說都非常滿意，而且完成這次旅程後，已經立即再訂了下一次的房間了。
# 日期:2016 年 5 月 12 日
# 名稱:Xiu
# 國籍:臺灣
# 留言數:4 則評語
# 評分:8.8
# continue here
# 日期:2016 年 5 月 9 日
# 名稱:Wan
# 國籍:香港
# 留言數:7 則評語
# 評分:9.2
# 눉
# 房間需要掃卡進入，雖然很安全但有點麻煩，聲音也比較大，怕吵到別人。
# 눇
# 房間很整潔，衛生間有阿姨定期打掃，進出都要換拖鞋，很乾淨。
# 日期:2016 年 5 月 8 日
# 名稱:Hung-yu
# 國籍:臺灣
# 留言數:4 則評語
# 評分:7.9
# 눉
# 牆壁隔音不佳  浴室旁的床位只要有人使用水聲很大  很難入睡  需要戴耳塞
# 눇
# WIFI很快  床非常舒適  公共區域很整潔
# 日期:2016 年 5 月 3 日
# 名稱:Hsin-yi
# 國籍:臺灣
# 留言數:1 則評語
# continue here
# 日期:2016 年 5 月 2 日
# 名稱:Leon
# 國籍:臺灣
# 留言數:2 則評語
# 評分:7.9
# 눉
# 床頭換氣口出風聲太大，形成噪音。同房旅客於不適當時間交談/發出手機聲響/取放行李碰撞- ，造成噪音干擾。
# 눇
# 乾淨明亮的衛浴空間，舒適的交誼廳環境，及自然的服務人員笑容。
# 日期:2016 年 4 月 22 日
# 名稱:匿名
# 國籍:臺灣
# 留言數:2 則評語
# continue here
# 日期:2016 年 4 月 20 日
# 名稱:Sandra
# 國籍:臺灣
# 留言數:4 則評語
# 評分:8.8
# 눉
# 建議吹風機可更換，若長髮髮量又多，吹乾要很久，風量太小了。床頭燈建議燈泡換亮一點，另外看圖片原以為一- 間房只有６張床，到現場才知道是１２張，建議房間資訊可寫詳細點。
# 눇
# 服務人員態度親切、環境舒適乾淨、距離捷運站也很近、價錢合理。
# 日期:2016 年 4 月 8 日
# 名稱:Kenny
# 國籍:臺灣
# 留言數:3 則評語
# continue here
# 日期:2016 年 3 月 20 日
# 名稱:burstshock
# 國籍:臺灣
# 留言數:8 則評語
# continue here
# 日期:2016 年 3 月 20 日
# 名稱:風雅
# 國籍:臺灣
# 留言數:1 則評語
# continue here
# 日期:2016 年 3 月 15 日
# 名稱:匿名
# 國籍:臺灣
# 留言數:1 則評語
# continue here
# 日期:2016 年 3 月 11 日
# 名稱:品文
# 國籍:臺灣
# 留言數:1 則評語
# continue here
# 日期:2016 年 3 月 7 日
# 名稱:Shing-shan
# 國籍:臺灣
# 留言數:2 則評語
# 評分:9.2
# 눉
# 希望在房間內的梯子能改為斜坡狀，更方便上下床
# 눇
# 很有設計感! 浴廁設備很舒服~的陽台~很放鬆!
# 日期:2016 年 2 月 27 日
# 名稱:Chun
# 國籍:臺灣
# 留言數:4 則評語
# continue here
# 日期:2016 年 2 月 25 日
# 名稱:Chung
# 國籍:臺灣
# 留言數:19 則評語
# 評分:7.1
# 눉
# 這點可惜了清潔...一天一次而已吧！
# continue here
# 日期:2016 年 2 月 25 日
# 名稱:匿名
# 國籍:紐西蘭
# 留言數:1 則評語
# continue here
# 日期:2016 年 2 月 25 日
# 名稱:Yu
# 國籍:臺灣
# 留言數:5 則評語
# 評分:9.2
# 눉
# 浴室不夠多，盥洗時段要碰運氣！
# 눇
# 用餐、買消夜很方便！看！
# 日期:2016 年 2 月 14 日
# 名稱:匿名
# 國籍:臺灣
# 留言數:1 則評語
# continue here
